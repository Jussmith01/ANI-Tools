# %%
import aniensemblestats as aes
import pandas as pd
# Out:
# van Der Waals correction will be unavailable. Please install ased3

# %%
error_store = '/home/jujuman/Scratch/Research/ani2x_testing/2x_error_stats/'
Nnet = 8

mdir = '/home/jujuman/Scratch/Research/ani2x_testing/train_ani_2x/final_cleaned_models/'
wkdir = {#'ANI-2x_v101119_EF2'  : mdir+'model_ani2x_dz_EF-3/',
         'ANI-2x_v101119_EF2'  : mdir+'model_ani2x_dz_EF-3/',
         #'ANI-2x_v101119_E1'   : mdir+'model_ani2x_dz_EF-4-0F/',
        }

# x1dir='/home/jsmith48/scratch/roman_tz_train/test/'
# x2dir='/home/jsmith48/scratch/roman_tz_train/test/'
# h5files = {'MDBenchmark'   : [x1dir+'ani_md_bench.h5'],
#            's66x8'         : [x1dir+'s66x8_wb97x6-31gd.h5'],
#            'TriPep' : [x1dir+'tripeptide_full.h5',
#                                x2dir+'ts_TripeptideS.h5'],
#            'DrugBk' : [x1dir+'drugbank_testset.h5',
#                                   x2dir+'ts_drugbankSFCl.h5'],
#            'GDB-07to09' : [x2dir+'ts_gdb-07.h5',
#                                   x2dir+'ts_gdb-08.h5',
#                                   x2dir+'ts_gdb-09.h5',
#                                   x1dir+'gdb11_07_test500.h5',
#                                   x1dir+'gdb11_08_test500.h5',
#                                   x1dir+'gdb11_09_test500.h5',],
#            'GDB-10to11'     : [x2dir+'ts_gdb-10.h5',
#                                x2dir+'ts_gdb-11.h5',
#                                x1dir+'gdb11_10_test500.h5',
#                                x1dir+'gdb11_11_test500.h5',
#                                x1dir+'gdb13_12_test1000.h5',
#                                x1dir+'gdb13_13_test1000.h5',]
#            }

x1dir='/home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/'
x2dir='/home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/'
# h5files = {'MDBenchmark'   : [x1dir+'ani_md_bench.h5'],
#            's66x8'         : [x1dir+'s66x8_wb97x6-31gd.h5'],
#            'TriPep    (S)' : [x2dir+'ts_TripeptideS.h5'],
#            'TriPep (CHNO)' : [x1dir+'tripeptide_full.h5',],
#            'DrugBk (SFCl)' : [x2dir+'ts_drugbankSFCl.h5'],
#            'DrugBk (CHNO)' : [x1dir+'drugbank_testset.h5'],
#            'GDB-07to09 (SFCl)' : [x2dir+'ts_gdb-07.h5',
#                                   x2dir+'ts_gdb-08.h5',
#                                   x2dir+'ts_gdb-09.h5'],
#            'GDB-10to11 (SFCl)'     : [x2dir+'ts_gdb-10.h5',
#                                       x2dir+'ts_gdb-11.h5'],
#            'GDB-07to09 (CHNO)'  : [x1dir+'gdb11_07_test500.h5',
#                                   x1dir+'gdb11_08_test500.h5',
#                                   x1dir+'gdb11_09_test500.h5',
#                                  ],
#            'GDB-10to13 (CHNO)'  : [x1dir+'gdb11_10_test500.h5',
#                                   x1dir+'gdb11_11_test500.h5',
#                                   x1dir+'gdb13_12_test1000.h5',
#                                   x1dir+'gdb13_13_test1000.h5',
#                                  ],
h5files = {'MDBenchmark'   : [x1dir+'ani_md_bench.h5'],
           's66x8'         : [x1dir+'s66x8_wb97x6-31gd.h5'],
           'TriPep' : [x2dir+'ts_TripeptideS.h5',
                       x1dir+'tripeptide_full.h5',],
           'TriPep (CHNO)' : [x1dir+'tripeptide_full.h5',],
           'DrugBk' : [x2dir+'ts_drugbankSFCl.h5',
                       x1dir+'drugbank_testset.h5'],
           'DrugBk (CHNO)' : [x1dir+'drugbank_testset.h5'],
           'DrugBk (SFCl)' : [x2dir+'ts_drugbankSFCl.h5'],
           'GDB-07to09' : [x2dir+'ts_gdb-07.h5',
                           x2dir+'ts_gdb-08.h5',
                           x2dir+'ts_gdb-09.h5',
                           x1dir+'gdb11_07_test500.h5',
                           x1dir+'gdb11_08_test500.h5',
                           x1dir+'gdb11_09_test500.h5',],
           'GDB-10to11' : [x2dir+'ts_gdb-10.h5',
                           x2dir+'ts_gdb-11.h5',
                           x1dir+'gdb11_10_test500.h5',
                           x1dir+'gdb11_11_test500.h5',],
           'GDB-12to13 (CHNO)'  : [x1dir+'gdb13_12_test1000.h5',
                                   x1dir+'gdb13_13_test1000.h5',],
#            'Complete (CHNO)': [x1dir+'gdb11_07_test500.h5',
#                                x1dir+'gdb11_08_test500.h5',
#                                x1dir+'gdb11_09_test500.h5',
#                                x1dir+'gdb11_10_test500.h5',
#                                x1dir+'gdb11_11_test500.h5',
#                                x1dir+'gdb13_12_test1000.h5',
#                                x1dir+'gdb13_13_test1000.h5',
#                                x1dir+'drugbank_testset.h5',
#                                x1dir+'tripeptide_full.h5',
#                                x1dir+'s66x8_wb97x6-31gd.h5',
#                                x1dir+'ani_md_bench.h5',
#                                ],
#            'Complete (SFCl)': [x1dir+'gdb11_07_test500.h5',
#                                x1dir+'gdb11_08_test500.h5',
#                                x1dir+'gdb11_09_test500.h5',
#                                x1dir+'gdb11_10_test500.h5',
#                                x1dir+'gdb11_11_test500.h5',
#                                x1dir+'gdb13_12_test1000.h5',
#                                x1dir+'gdb13_13_test1000.h5',
#                                x1dir+'drugbank_testset.h5',
#                                x1dir+'tripeptide_full.h5',
#                                x1dir+'s66x8_wb97x6-31gd.h5',
#                                x1dir+'ani_md_bench.h5',
#                                 x2dir+'ts_gdb-07.h5',
#                                 x2dir+'ts_gdb-08.h5',
#                                 x2dir+'ts_gdb-09.h5',
#                                 x2dir+'ts_gdb-10.h5',
#                                 x2dir+'ts_gdb-11.h5',
#                                 x2dir+'ts_drugbankSFCl.h5',
#                                 x2dir+'ts_TripeptideS.h5',
#                                ],
           }

# %%
tlist = [10,30,50,100,150,200,250,300]
# Declare stats generator
for k in wkdir.keys():
#k = list(wkdir.keys())[0]
#k = 'ANI-2x_3'
#for T in tlist:
    netens = {'cns': wkdir[k] + 'rHCNOSFCl-5.2R_16-3.4A_a8-4.params',
              #'cns': wkdir[k] + 'train0/rHCNOSFCl-5.0R_16-3.4A_a4-8.params',
              #'cns': wkdir[k] + 'train0/rHCNOSFCl-5.2R_16-3.8A_a4-8.params',
              #'sae': wkdir[k] + 'train0/sae_wb97x-631gd.dat',
              'sae': wkdir[k] + 'train0/sae_linfit.dat',
              'nnf': wkdir[k] + 'train',
              'nts': Nnet}

    #netens = {'cns': wkdir[k] + 'rHCNO-4.6A_16-3.1A_a4-8.params',
    #          'sae': wkdir[k] + 'sae_6-31gd.dat',
    #          'nnf': wkdir[k] + 'train',
    #          'nts': 5}
    print('Generating data for:',k)
    est = aes.generate_ensemble_data(netens, h5files, gpu=[0])
    #est.generate_stats(forces=True, grad=True, maxe=T)
    est.generate_stats(forces=True, grad=True, maxe=1000.0)
    print('  Storing...')
    #est.store_data(error_store+'tsdata_' + k + '.h5')
    est.store_data(error_store+'tsdata_' + k + '.h5')
# Out:
# Generating data for: ANI-2x_v101119_EF2
#    -Working on MDBenchmark ...
# MDBenchmark /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/ani_md_bench.h5
#    -Working on s66x8 ...
# s66x8 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/s66x8_wb97x6-31gd.h5
#    -Working on TriPep ...
# TriPep /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_TripeptideS.h5
# TriPep /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/tripeptide_full.h5
#    -Working on TriPep (CHNO) ...
# TriPep (CHNO) /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/tripeptide_full.h5
#    -Working on DrugBk ...
# DrugBk /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_drugbankSFCl.h5
# DrugBk /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/drugbank_testset.h5
#    -Working on DrugBk (CHNO) ...
# DrugBk (CHNO) /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/drugbank_testset.h5
#    -Working on DrugBk (SFCl) ...
# DrugBk (SFCl) /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_drugbankSFCl.h5
#    -Working on GDB-07to09 ...
# GDB-07to09 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_gdb-07.h5
# GDB-07to09 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_gdb-08.h5
# GDB-07to09 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_gdb-09.h5
# GDB-07to09 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/gdb11_07_test500.h5
# GDB-07to09 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/gdb11_08_test500.h5
# GDB-07to09 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/gdb11_09_test500.h5
#    -Working on GDB-10to11 ...
# GDB-10to11 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_gdb-10.h5
# GDB-10to11 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v2/benchmarks/ts_gdb-11.h5
# GDB-10to11 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/gdb11_10_test500.h5
# GDB-10to11 /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/gdb11_11_test500.h5
#    -Working on GDB-12to13 (CHNO) ...
# GDB-12to13 (CHNO) /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/gdb13_12_test1000.h5
# GDB-12to13 (CHNO) /home/jujuman/Scratch/Research/extensibility_test_sets/COMP6v1/benchmarks/gdb13_13_test1000.h5
#   Storing...
