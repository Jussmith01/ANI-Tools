# %%
import numpy as np

# %%
print(type(Z[0][0]))
# Out:
# <class 'numpy.int64'>

# %%
R = np.load('/scratch/Research/harmonic_ir/data-SmallAspirinR.npy')

# %%
R
# Out:
# array([[[ 1.22216922, -0.51950949, -0.72939109],
#         [-1.22583571,  2.84190404,  0.35154208],
#         [ 0.76559833,  2.14417619, -0.44293392],
#         ...,
#         [ 4.20884294,  0.04707923,  0.7053499 ],
#         [ 3.02225073,  1.05719377, -0.12575787],
#         [-0.74769068,  3.65345295,  0.44662286]],
#
#        [[ 1.21994141, -0.2994746 , -0.83899165],
#         [-1.54395272,  2.67044173,  0.21717889],
#         [ 0.63706458,  2.25153112, -0.15698213],
#         ...,
#         [ 4.09616186, -0.37967438,  0.78700959],
#         [ 3.39602877,  1.12158623, -0.05705193],
#         [-1.10759123,  3.53343157,  0.19156662]],
#
#        [[ 1.04264815, -0.77762956, -0.66403072],
#         [-0.84982389,  2.85675584,  0.02164057],
#         [ 1.10177216,  1.74153383, -0.15724823],
#         ...,
#         [ 4.16782025, -0.41434293,  0.39822512],
#         [ 3.55527739,  0.3056627 , -1.07035055],
#         [-0.19433616,  3.5594279 , -0.15487641]],
#
#        ...,
#
# ...
