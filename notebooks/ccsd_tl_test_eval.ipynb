# %%
from ase_interface import ANIENS
from ase_interface import ensemblemolecule

import aniensemblestats as aes
import pyaniasetools as aat

import pyanitools as pyt

import numpy as np
import ase

#from ase.neb import NEBtools
from ase.io import read, write

import matplotlib
import matplotlib as mpl
from matplotlib import gridspec 
import matplotlib.pyplot as plt

import hdnntools as hdt

from scipy import stats

import os
# Out:
# van Der Waals correction will be unavailable. Please install ased3
# /usr/local/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
## DFT -> CCSD Transfer learned
ntdir1 = '/home/jsmith48/scratch/auto_dhl_al/modeldhl/ANI-1x-DHL-0000/ANI-1x-DHL-0000.0000/'
cns1 = ntdir1 + 'train0/rHCNO-4.6R_16-3.1A_a4-8.params'
sae1 = ntdir1 + 'train0/sae_linfit.dat'
nnf1 = ntdir1 + 'train'
Nn1 = 8

# ## Full CCSD trained
# ntdir2 = '/home/jsmith48/scratch/ccsd_extrapolation/learning_cases/ful_train/'
# cns2 = ntdir2 + 'rHCNO-4.6R_16-3.1A_a4-8.params'
# sae2 = ntdir2 + 'sae_linfit.dat'
# nnf2 = ntdir2 + 'train'
# Nn2 = 5

## Delta ML DFT -> CCSD
#ntdir1 = '/home/jsmith48/scratch/transfer_learning/it1_models/ccsd_tl_16x_1/'
#cns1 = ntdir1 + 'rHCNO-4.6R_16-3.1A_a4-8.params'
#sae1 = ntdir1 + 'sae_linfit.dat'
#nnf1 = ntdir1 + 'train'
#Nn1 = 1

## Delta ML DFT -> CCSD
ntdir2 = '/home/jsmith48/scratch/transfer_learning/it1_models/ccsd_tl_16x_2/'
cns2 = ntdir2 + 'rHCNO-4.6R_16-3.1A_a4-8.params'
sae2 = ntdir2 + 'sae_linfit.dat'
nnf2 = ntdir2 + 'train'
Nn2 = 5

## Delta ML DFT -> CCSD
ntdir3 = '/home/jsmith48/scratch/transfer_learning/it1_models/ccsd_tl_16x_3/'
cns3 = ntdir3 + 'rHCNO-4.6R_16-3.1A_a4-8.params'
sae3 = ntdir3 + 'sae_linfit.dat'
nnf3 = ntdir3 + 'train'
Nn3 = 16

## Full DFT trained base model
ntdir4 = '/home/jsmith48/scratch/ANI-1x_retrain/train_ens_1/'
cns4 = ntdir4 + 'rHCNO-4.6R_16-3.1A_a4-8.params'
sae4 = ntdir4 + 'sae_linfit.dat'
nnf4 = ntdir4 + 'train'
Nn4 = 5

dftsae = '/home/jsmith48/scratch/ccsd_extrapolation/atomization_files/sae_wb97x-631gd.dat'
ccssae = '/home/jsmith48/scratch/ccsd_extrapolation/atomization_files/ccsd_atmz.dat'

ts = '/home/jsmith48/scratch/ccsd_extrapolation/h5files_holdout_split/testset/r10_ccsd_test.h5'

dftdir = '/home/jsmith48/scratch/ccsd_extrapolation/h5files_holdout_split/testset/xyz/'

ccsd_testset = '/home/jsmith48/scratch/ccsd_extrapolation/learning_cases/dft_DZ_retrain/data/testset/'

# %%
dftfiles = [f for f in os.listdir(dftdir) if f[-4:] == '.dat']
dftdata = dict()
for f in dftfiles:
    data = hdt.readncdatall(dftdir+f)
    dftdata.update({f.rsplit('.',1)[0]:data})

# %%
# Set NC
aens_1 = aat.anicrossvalidationconformer(cns1, sae1, nnf1, Nn1, 0)
aens_2 = aat.anicrossvalidationconformer(cns2, sae2, nnf2, Nn2, 0)
aens_3 = aat.anicrossvalidationconformer(cns3, sae3, nnf3, Nn3, 0)
aens_4 = aat.anicrossvalidationconformer(cns4, sae4, nnf4, Nn4, 0)

# %%
adl = pyt.anidataloader(ts)

# %%
Eal=[]
dEal=[]
Emin=[]

Na = []
for i,data in enumerate(adl):
    #if i  == 100:
    #    break
    if data['path'][1:] in dftdata:
        
        # Get reference data
        X = np.array(data['coordinates'],dtype=np.float32)
        S = data['species']
        E = hdt.hatokcal*data['energies']
        Na.append(len(S))
        
        # Compute SAE lin fit
        Esae= hdt.hatokcal*hdt.compute_sae(file=ccssae,spc=S)
        Esae_dft= hdt.hatokcal*hdt.compute_sae(file=dftsae,spc=S)
        
        # Define Eref
        Eref = E-Esae
        
        # Define DFT comparison
        dft = dftdata[data['path'][1:]]
        Edft = hdt.hatokcal*dft['energies']-Esae_dft

        # Compute energies and forces
        Ea1_t,Fa1_t,Sa1 = aens_1.compute_energyandforce_conformations(X,S)
        Ea2_t,Fa2_t,Sa2 = aens_2.compute_energyandforce_conformations(X,S)
        Ea3_t,Fa3_t,Sa3 = aens_3.compute_energyandforce_conformations(X,S)
        Ea4_t,Fa4_t,Sa4 = aens_4.compute_energyandforce_conformations(X,S)

        idx = np.where(Sa1 < 500.0)
        
        print('Computing:',i,len(S),data['path'],idx[0].size)
        
        if idx[0].size != 0:

            # Define NN shifted energies
            Eal1 = Ea1_t[idx]-Esae # TL
            Eal2 = Ea2_t[idx]-Esae # FULL
            Eal3 = Ea3_t[idx]-Esae # Delta
            Eal4 = Ea4_t[idx]-Esae_dft # DFT

            # Define NN E distmats
            dEal1 = hdt.calculatedmat(Ea1_t[idx])
            dEal2 = hdt.calculatedmat(Ea2_t[idx])
            dEal3 = hdt.calculatedmat(Ea3_t[idx])
            dEal4 = hdt.calculatedmat(Ea4_t[idx])

            # Store E mins
            Emin.append(np.array([[Eref[idx].min(),Eal1.min(),Eal2.min(),Eal3.min(),Eal4.min(),Edft[idx].min()]]))

            # Store E and dE
            Eal.append(np.vstack([Eref[idx],Eal1,Eal2,Eal3,Eal4,Edft[idx]]))
            dEal.append(np.vstack([hdt.calculatedmat(Eref[idx]),dEal1,dEal2,dEal3,dEal4,hdt.calculatedmat(Edft[idx])]))
            #print(dEal[-1].shape)
        
Eal = np.hstack(Eal)
dEal = np.hstack(dEal)
#print(dEal.shape,dEal)
Na = np.array(Na)
Emin=np.vstack(Emin)
# Out:
# Computing: 0 16 /mol_10076 10
# Computing: 1 17 /mol_1008 10
# Computing: 2 20 /mol_10080 10
# Computing: 3 23 /mol_10102 10
# Computing: 4 24 /mol_10110 10
# Computing: 5 22 /mol_10111 10
# Computing: 6 22 /mol_10117 10
# Computing: 7 21 /mol_10124 10
# Computing: 8 20 /mol_10132 10
# Computing: 9 21 /mol_10179 10
# Computing: 10 22 /mol_10190 10
# Computing: 11 20 /mol_10198 10
# Computing: 12 19 /mol_10200 10
# Computing: 13 20 /mol_10223 10
# Computing: 14 18 /mol_10233 10
# Computing: 15 25 /mol_10237 10
# Computing: 16 17 /mol_10238 10
# Computing: 17 21 /mol_10282 10
# Computing: 18 23 /mol_10288 10
# Computing: 19 21 /mol_10344 10
# Computing: 20 25 /mol_10381 10
# Computing: 21 26 /mol_10385 10
# Computing: 22 23 /mol_1039 10
# Computing: 23 20 /mol_10405 10
# Computing: 24 20 /mol_10406 10
# Computing: 25 21 /mol_10410 10
# Computing: 26 21 /mol_10422 10
# Computing: 27 17 /mol_10438 10
# Computing: 28 18 /mol_1049 10
# Computing: 29 16 /mol_1051 10
# Computing: 30 16 /mol_1065 10
# Computing: 31 21 /mol_10678 10
# Computing: 32 18 /mol_1070 10
# Computing: 33 19 /mol_10747 10
# Computing: 34 20 /mol_10760 10
# Computing: 35 20 /mol_10764 10
# Computing: 36 19 /mol_10774 10
# Computing: 37 21 /mol_10781 10
# Computing: 38 22 /mol_10785 10
# Computing: 39 16 /mol_1079 10
# Computing: 40 22 /mol_10825 10
# Computing: 41 17 /mol_10870 10
# Computing: 42 17 /mol_10871 10
# Computing: 43 16 /mol_10949 10
# Computing: 44 16 /mol_10981 10
# Computing: 45 16 /mol_10982 10
# Computing: 46 21 /mol_11013 10
# Computing: 47 18 /mol_11023 10
# Computing: 48 16 /mol_11025 10
# Computing: 49 18 /mol_11047 10
# Computing: 50 17 /mol_11115 10
# Computing: 51 17 /mol_11116 10
# Computing: 52 23 /mol_11158 10
# Computing: 53 19 /mol_11163 10
# Computing: 54 16 /mol_11166 10
# Computing: 55 26 /mol_11167 10
# Computing: 56 20 /mol_11177 10
# Computing: 57 21 /mol_11178 10
# Computing: 58 18 /mol_11181 10
# Computing: 59 20 /mol_11222 10
# Computing: 60 20 /mol_11240 10
# Computing: 61 20 /mol_11243 10
# Computing: 62 19 /mol_11259 10
# Computing: 63 17 /mol_11284 10
# Computing: 64 18 /mol_11299 10
# Computing: 65 21 /mol_11313 10
# Computing: 66 22 /mol_11351 10
# Computing: 67 20 /mol_11357 10
# Computing: 68 25 /mol_11375 10
# Computing: 69 25 /mol_11379 10
# Computing: 70 19 /mol_11411 10
# Computing: 71 19 /mol_11416 10
# Computing: 72 17 /mol_11420 10
# Computing: 73 17 /mol_11430 10
# Computing: 74 17 /mol_11445 10
# Computing: 75 21 /mol_11474 10
# Computing: 76 18 /mol_1148 10
# Computing: 77 20 /mol_11483 10
# Computing: 78 18 /mol_11487 10
# Computing: 79 19 /mol_11493 10
# Computing: 80 18 /mol_11523 10
# Computing: 81 17 /mol_11524 10
# Computing: 82 22 /mol_11549 10
# Computing: 83 20 /mol_11560 10
# Computing: 84 18 /mol_11589 10
# Computing: 85 16 /mol_11613 10
# Computing: 86 20 /mol_11658 10
# Computing: 87 19 /mol_1166 10
# Computing: 88 18 /mol_11688 10
# Computing: 89 17 /mol_11699 10
# Computing: 90 23 /mol_11701 10
# Computing: 91 16 /mol_11711 10
# Computing: 92 17 /mol_11714 10
# Computing: 93 16 /mol_1172 10
# Computing: 94 21 /mol_11740 10
# Computing: 95 17 /mol_11772 10
# Computing: 96 20 /mol_11787 10
# Computing: 97 17 /mol_11803 10
# Computing: 98 22 /mol_11807 10
# Computing: 99 18 /mol_11830 10
# Computing: 100 17 /mol_11900 10
# Computing: 101 18 /mol_11929 10
# Computing: 102 16 /mol_1194 10
# Computing: 103 19 /mol_11964 10
# Computing: 104 21 /mol_11967 10
# Computing: 105 22 /mol_11976 10
# Computing: 106 18 /mol_1198 10
# Computing: 107 19 /mol_12004 10
# Computing: 108 20 /mol_12025 10
# Computing: 109 22 /mol_12027 10
# Computing: 110 20 /mol_12031 10
# Computing: 111 26 /mol_12050 10
# Computing: 112 16 /mol_12057 10
# Computing: 113 20 /mol_12077 10
# Computing: 114 17 /mol_1208 10
# Computing: 115 17 /mol_12094 10
# Computing: 116 18 /mol_12116 10
# Computing: 117 17 /mol_12123 10
# Computing: 118 25 /mol_12147 10
# Computing: 119 16 /mol_12155 10
# Computing: 120 17 /mol_12156 10
# Computing: 121 20 /mol_12185 10
# Computing: 122 17 /mol_12186 10
# Computing: 123 24 /mol_12194 10
# Computing: 124 19 /mol_12206 10
# Computing: 125 17 /mol_12211 10
# Computing: 126 16 /mol_12238 10
# Computing: 127 17 /mol_12245 10
# Computing: 128 20 /mol_12251 10
# Computing: 129 25 /mol_12256 10
# Computing: 130 21 /mol_12257 10
# Computing: 131 19 /mol_12264 10
# Computing: 132 17 /mol_12287 10
# Computing: 133 17 /mol_1230 10
# Computing: 134 20 /mol_12334 10
# Computing: 135 18 /mol_12365 10
# Computing: 136 22 /mol_12396 10
# Computing: 137 23 /mol_12406 10
# Computing: 138 23 /mol_12434 10
# Computing: 139 22 /mol_12435 10
# Computing: 140 18 /mol_12436 10
# Computing: 141 21 /mol_12455 10
# Computing: 142 18 /mol_12456 10
# Computing: 143 17 /mol_12474 10
# Computing: 144 18 /mol_1248 10
# Computing: 145 22 /mol_12489 10
# Computing: 146 17 /mol_12507 10
# Computing: 147 17 /mol_12532 10
# Computing: 148 21 /mol_12534 10
# Computing: 149 18 /mol_12560 10
# Computing: 150 17 /mol_12561 10
# Computing: 151 18 /mol_12563 10
# Computing: 152 17 /mol_12588 10
# Computing: 153 19 /mol_12605 10
# Computing: 154 17 /mol_1261 10
# Computing: 155 23 /mol_12616 10
# Computing: 156 18 /mol_12633 10
# Computing: 157 17 /mol_12635 10
# Computing: 158 17 /mol_12674 10
# Computing: 159 16 /mol_12675 10
# Computing: 160 17 /mol_1268 10
# Computing: 161 20 /mol_12770 10
# Computing: 162 17 /mol_12797 10
# Computing: 163 18 /mol_12816 10
# Computing: 164 18 /mol_12821 10
# Computing: 165 18 /mol_1287 10
# Computing: 166 18 /mol_1288 10
# Computing: 167 17 /mol_12914 10
# Computing: 168 19 /mol_12956 10
# Computing: 169 18 /mol_12958 10
# Computing: 170 18 /mol_12980 10
# Computing: 171 16 /mol_12991 10
# Computing: 172 16 /mol_13083 10
# Computing: 173 22 /mol_13116 10
# Computing: 174 20 /mol_13177 10
# Computing: 175 20 /mol_13241 10
# Computing: 176 18 /mol_1329 10
# Computing: 177 20 /mol_13293 10
# Computing: 178 24 /mol_13299 10
# Computing: 179 18 /mol_13303 10
# Computing: 180 22 /mol_13316 10
# Computing: 181 24 /mol_13320 10
# Computing: 182 22 /mol_13336 10
# Computing: 183 16 /mol_13366 10
# Computing: 184 18 /mol_13384 10
# Computing: 185 23 /mol_13402 10
# Computing: 186 17 /mol_13447 10
# Computing: 187 21 /mol_13464 10
# Computing: 188 20 /mol_13480 10
# Computing: 189 20 /mol_13507 10
# Computing: 190 20 /mol_13566 10
# Computing: 191 18 /mol_13623 10
# Computing: 192 21 /mol_13625 10
# Computing: 193 19 /mol_13627 10
# Computing: 194 22 /mol_13656 10
# Computing: 195 28 /mol_13666 10
# Computing: 196 23 /mol_13668 10
# Computing: 197 22 /mol_13669 10
# Computing: 198 18 /mol_13675 10
# Computing: 199 23 /mol_13679 10
# Computing: 200 16 /mol_1372 10
# Computing: 201 19 /mol_13728 10
# Computing: 202 20 /mol_13746 10
# Computing: 203 22 /mol_13765 10
# Computing: 204 18 /mol_13775 10
# Computing: 205 18 /mol_13801 10
# Computing: 206 20 /mol_13844 10
# Computing: 207 22 /mol_13845 10
# Computing: 208 22 /mol_1389 10
# Computing: 209 22 /mol_1390 10
# Computing: 210 17 /mol_1391 10
# Computing: 211 20 /mol_13934 10
# Computing: 212 19 /mol_13939 10
# Computing: 213 23 /mol_13971 10
# Computing: 214 24 /mol_14007 10
# Computing: 215 18 /mol_14059 10
# Computing: 216 19 /mol_14101 10
# Computing: 217 21 /mol_14112 10
# Computing: 218 21 /mol_14119 10
# Computing: 219 16 /mol_14122 10
# Computing: 220 20 /mol_14130 10
# Computing: 221 22 /mol_14167 10
# Computing: 222 18 /mol_14193 10
# Computing: 223 21 /mol_14200 10
# Computing: 224 17 /mol_1422 10
# Computing: 225 21 /mol_14222 10
# Computing: 226 18 /mol_14247 10
# Computing: 227 22 /mol_14253 10
# Computing: 228 22 /mol_14263 10
# Computing: 229 26 /mol_14280 10
# Computing: 230 21 /mol_14331 10
# Computing: 231 18 /mol_14357 10
# Computing: 232 18 /mol_14358 10
# Computing: 233 22 /mol_14364 10
# Computing: 234 21 /mol_14409 10
# Computing: 235 16 /mol_14474 10
# Computing: 236 21 /mol_14483 10
# Computing: 237 25 /mol_14531 10
# Computing: 238 21 /mol_14544 10
# Computing: 239 20 /mol_14678 10
# Computing: 240 21 /mol_14749 10
# Computing: 241 21 /mol_14789 10
# Computing: 242 16 /mol_14827 10
# Computing: 243 16 /mol_14847 10
# Computing: 244 16 /mol_1487 10
# Computing: 245 16 /mol_1491 10
# Computing: 246 18 /mol_14955 10
# Computing: 247 18 /mol_15024 10
# Computing: 248 23 /mol_15026 10
# Computing: 249 16 /mol_15027 10
# Computing: 250 17 /mol_15036 10
# Computing: 251 21 /mol_15077 10
# Computing: 252 24 /mol_15084 10
# Computing: 253 16 /mol_15107 10
# Computing: 254 18 /mol_15133 10
# Computing: 255 24 /mol_15134 10
# Computing: 256 24 /mol_15195 10
# Computing: 257 18 /mol_1521 10
# Computing: 258 18 /mol_15252 10
# Computing: 259 17 /mol_15290 10
# Computing: 260 18 /mol_15296 10
# Computing: 261 19 /mol_15303 10
# Computing: 262 24 /mol_15305 10
# Computing: 263 27 /mol_15323 10
# Computing: 264 25 /mol_15335 10
# Computing: 265 16 /mol_1535 10
# Computing: 266 22 /mol_15368 10
# Computing: 267 18 /mol_15369 10
# Computing: 268 18 /mol_15383 10
# Computing: 269 22 /mol_15387 10
# Computing: 270 16 /mol_15404 10
# Computing: 271 18 /mol_15405 10
# Computing: 272 21 /mol_1541 10
# Computing: 273 18 /mol_1542 10
# Computing: 274 23 /mol_15433 10
# Computing: 275 22 /mol_15444 10
# Computing: 276 17 /mol_15445 10
# Computing: 277 20 /mol_15446 10
# Computing: 278 23 /mol_15448 10
# Computing: 279 20 /mol_15450 10
# Computing: 280 16 /mol_1549 10
# Computing: 281 19 /mol_15527 10
# Computing: 282 19 /mol_15589 10
# Computing: 283 19 /mol_15608 10
# Computing: 284 22 /mol_15632 10
# Computing: 285 18 /mol_15656 10
# Computing: 286 20 /mol_15659 10
# Computing: 287 18 /mol_15690 10
# Computing: 288 18 /mol_15726 10
# Computing: 289 23 /mol_15738 10
# Computing: 290 21 /mol_15744 10
# Computing: 291 17 /mol_15778 10
# Computing: 292 24 /mol_15797 10
# Computing: 293 17 /mol_15798 10
# Computing: 294 22 /mol_15806 10
# Computing: 295 21 /mol_15816 10
# Computing: 296 20 /mol_15818 10
# Computing: 297 17 /mol_15832 10
# Computing: 298 16 /mol_15835 10
# Computing: 299 21 /mol_15837 10
# Computing: 300 26 /mol_15844 10
# Computing: 301 24 /mol_15851 10
# Computing: 302 23 /mol_15853 10
# Computing: 303 27 /mol_15859 10
# Computing: 304 23 /mol_15864 10
# Computing: 305 20 /mol_15871 10
# Computing: 306 25 /mol_15877 10
# Computing: 307 24 /mol_15896 10
# Computing: 308 23 /mol_15916 10
# Computing: 309 18 /mol_15931 10
# Computing: 310 18 /mol_15989 10
# Computing: 311 24 /mol_15999 10
# Computing: 312 17 /mol_16006 10
# Computing: 313 19 /mol_16063 10
# Computing: 314 18 /mol_16068 10
# Computing: 315 22 /mol_16071 10
# Computing: 316 16 /mol_16152 10
# Computing: 317 22 /mol_16155 10
# Computing: 318 16 /mol_16228 10
# Computing: 319 17 /mol_16285 10
# Computing: 320 16 /mol_16295 10
# Computing: 321 17 /mol_16297 10
# Computing: 322 16 /mol_16298 10
# Computing: 323 17 /mol_16333 10
# Computing: 324 16 /mol_16398 10
# Computing: 325 16 /mol_16407 10
# Computing: 326 20 /mol_1641 10
# Computing: 327 19 /mol_16458 10
# Computing: 328 18 /mol_1646 10
# Computing: 329 22 /mol_16467 10
# Computing: 330 16 /mol_16495 10
# Computing: 331 18 /mol_16534 10
# Computing: 332 23 /mol_16537 10
# Computing: 333 26 /mol_16556 10
# Computing: 334 21 /mol_16633 10
# Computing: 335 22 /mol_16638 10
# Computing: 336 26 /mol_16641 10
# Computing: 337 18 /mol_16692 10
# Computing: 338 23 /mol_16713 10
# Computing: 339 21 /mol_16717 10
# Computing: 340 19 /mol_16722 10
# Computing: 341 22 /mol_16738 10
# Computing: 342 18 /mol_1674 10
# Computing: 343 25 /mol_16740 10
# Computing: 344 25 /mol_16782 10
# Computing: 345 24 /mol_16789 10
# Computing: 346 20 /mol_16790 10
# Computing: 347 22 /mol_16791 10
# Computing: 348 19 /mol_16826 10
# Computing: 349 23 /mol_16834 10
# Computing: 350 18 /mol_16835 10
# Computing: 351 18 /mol_16859 10
# Computing: 352 20 /mol_16863 10
# Computing: 353 22 /mol_16874 10
# Computing: 354 19 /mol_16923 10
# Computing: 355 16 /mol_1693 10
# Computing: 356 18 /mol_17036 10
# Computing: 357 20 /mol_17042 10
# Computing: 358 20 /mol_17051 10
# Computing: 359 23 /mol_17055 10
# Computing: 360 18 /mol_1706 10
# Computing: 361 21 /mol_17079 10
# Computing: 362 21 /mol_17122 10
# Computing: 363 23 /mol_17154 10
# Computing: 364 17 /mol_1718 10
# Computing: 365 23 /mol_17182 10
# Computing: 366 24 /mol_17219 10
# Computing: 367 26 /mol_17233 10
# Computing: 368 27 /mol_17239 10
# Computing: 369 25 /mol_17252 10
# Computing: 370 23 /mol_17259 10
# Computing: 371 18 /mol_17268 10
# Computing: 372 21 /mol_17269 10
# Computing: 373 21 /mol_17278 10
# Computing: 374 21 /mol_17295 10
# Computing: 375 21 /mol_17297 10
# Computing: 376 19 /mol_17312 10
# Computing: 377 20 /mol_1734 10
# Computing: 378 19 /mol_17340 10
# Computing: 379 24 /mol_17370 10
# Computing: 380 26 /mol_17371 10
# Computing: 381 20 /mol_17374 10
# Computing: 382 24 /mol_17380 10
# Computing: 383 22 /mol_17383 10
# Computing: 384 21 /mol_17463 10
# Computing: 385 17 /mol_17472 10
# Computing: 386 20 /mol_17480 10
# Computing: 387 22 /mol_1759 10
# Computing: 388 21 /mol_17659 10
# Computing: 389 19 /mol_17688 10
# Computing: 390 20 /mol_17713 10
# Computing: 391 20 /mol_17717 10
# Computing: 392 20 /mol_17729 10
# Computing: 393 20 /mol_1779 10
# Computing: 394 18 /mol_17791 10
# Computing: 395 17 /mol_17792 10
# Computing: 396 25 /mol_17814 10
# Computing: 397 17 /mol_17817 10
# Computing: 398 22 /mol_17831 10
# Computing: 399 19 /mol_17878 10
# Computing: 400 18 /mol_17883 10
# Computing: 401 23 /mol_17896 10
# Computing: 402 16 /mol_1791 10
# Computing: 403 21 /mol_17921 10
# Computing: 404 19 /mol_1794 10
# Computing: 405 20 /mol_17956 10
# Computing: 406 16 /mol_17992 10
# Computing: 407 22 /mol_17995 10
# Computing: 408 29 /mol_17997 10
# Computing: 409 21 /mol_18000 10
# Computing: 410 24 /mol_18013 10
# Computing: 411 20 /mol_18014 10
# Computing: 412 19 /mol_18031 10
# Computing: 413 23 /mol_18032 10
# Computing: 414 25 /mol_18044 10
# Computing: 415 22 /mol_18109 10
# Computing: 416 20 /mol_1812 10
# Computing: 417 20 /mol_18145 10
# Computing: 418 18 /mol_18173 10
# Computing: 419 18 /mol_18215 10
# Computing: 420 18 /mol_18263 10
# Computing: 421 20 /mol_1829 10
# Computing: 422 16 /mol_1831 10
# Computing: 423 16 /mol_18320 10
# Computing: 424 24 /mol_18329 10
# Computing: 425 22 /mol_18362 10
# Computing: 426 17 /mol_18373 10
# Computing: 427 18 /mol_18439 10
# Computing: 428 24 /mol_18450 10
# Computing: 429 23 /mol_18467 10
# Computing: 430 18 /mol_18473 10
# Computing: 431 17 /mol_18586 10
# Computing: 432 19 /mol_1861 10
# Computing: 433 19 /mol_1863 10
# Computing: 434 18 /mol_18673 10
# Computing: 435 16 /mol_18705 10
# Computing: 436 16 /mol_18709 10
# Computing: 437 21 /mol_18746 10
# Computing: 438 21 /mol_18761 10
# Computing: 439 18 /mol_1877 10
# Computing: 440 27 /mol_18771 10
# Computing: 441 19 /mol_18823 10
# Computing: 442 22 /mol_18864 10
# Computing: 443 24 /mol_18888 10
# Computing: 444 20 /mol_18889 10
# Computing: 445 22 /mol_18927 10
# Computing: 446 17 /mol_18956 10
# Computing: 447 20 /mol_19003 10
# Computing: 448 22 /mol_19004 10
# Computing: 449 20 /mol_19012 10
# Computing: 450 20 /mol_19014 10
# Computing: 451 24 /mol_19016 10
# Computing: 452 19 /mol_19157 10
# Computing: 453 25 /mol_19162 10
# Computing: 454 20 /mol_19163 10
# Computing: 455 16 /mol_19225 10
# Computing: 456 19 /mol_19231 10
# Computing: 457 29 /mol_19233 10
# Computing: 458 21 /mol_1924 10
# Computing: 459 19 /mol_19297 10
# Computing: 460 16 /mol_19305 10
# Computing: 461 22 /mol_19322 10
# Computing: 462 22 /mol_19324 10
# Computing: 463 20 /mol_19353 10
# Computing: 464 17 /mol_19360 10
# Computing: 465 20 /mol_19361 10
# Computing: 466 28 /mol_19363 10
# Computing: 467 19 /mol_1937 10
# Computing: 468 16 /mol_19419 10
# Computing: 469 21 /mol_19521 10
# Computing: 470 18 /mol_19530 10
# Computing: 471 19 /mol_19542 10
# Computing: 472 18 /mol_1958 10
# Computing: 473 24 /mol_19625 10
# Computing: 474 19 /mol_19628 10
# Computing: 475 26 /mol_19632 10
# Computing: 476 17 /mol_19680 10
# Computing: 477 26 /mol_19685 10
# Computing: 478 19 /mol_1969 10
# Computing: 479 23 /mol_19715 10
# Computing: 480 25 /mol_19726 10
# Computing: 481 20 /mol_19766 10
# Computing: 482 22 /mol_19781 10
# Computing: 483 22 /mol_19788 10
# Computing: 484 19 /mol_19821 10
# Computing: 485 21 /mol_19935 10
# Computing: 486 18 /mol_1996 10
# Computing: 487 22 /mol_19993 10
# Computing: 488 21 /mol_20014 10
# Computing: 489 19 /mol_20016 10
# Computing: 490 19 /mol_20039 10
# Computing: 491 19 /mol_20061 10
# Computing: 492 26 /mol_20062 10
# Computing: 493 23 /mol_20077 10
# Computing: 494 18 /mol_20106 10
# Computing: 495 22 /mol_20138 10
# Computing: 496 24 /mol_20191 10
# Computing: 497 21 /mol_20220 10
# Computing: 498 22 /mol_20239 10
# Computing: 499 24 /mol_20301 10
# Computing: 500 20 /mol_20312 10
# Computing: 501 26 /mol_20324 10
# Computing: 502 20 /mol_20356 10
# Computing: 503 22 /mol_20425 10
# Computing: 504 20 /mol_20426 10
# Computing: 505 26 /mol_20458 10
# Computing: 506 17 /mol_205 10
# Computing: 507 20 /mol_20529 10
# Computing: 508 21 /mol_20532 10
# Computing: 509 16 /mol_20627 10
# Computing: 510 19 /mol_2070 10
# Computing: 511 22 /mol_20714 10
# Computing: 512 23 /mol_20738 10
# Computing: 513 19 /mol_20741 10
# Computing: 514 20 /mol_20743 10
# Computing: 515 21 /mol_20785 10
# Computing: 516 24 /mol_20793 10
# Computing: 517 18 /mol_20811 10
# Computing: 518 23 /mol_20820 10
# Computing: 519 17 /mol_20835 10
# Computing: 520 26 /mol_20850 10
# Computing: 521 21 /mol_20855 10
# Computing: 522 20 /mol_20860 10
# Computing: 523 20 /mol_20870 10
# Computing: 524 23 /mol_20898 10
# Computing: 525 20 /mol_20906 10
# Computing: 526 19 /mol_20933 10
# Computing: 527 24 /mol_20986 10
# Computing: 528 26 /mol_21003 10
# Computing: 529 20 /mol_21007 10
# Computing: 530 22 /mol_21010 10
# Computing: 531 23 /mol_21041 10
# Computing: 532 21 /mol_21063 10
# Computing: 533 20 /mol_21070 10
# Computing: 534 22 /mol_21078 10
# Computing: 535 17 /mol_2109 10
# Computing: 536 21 /mol_21091 10
# Computing: 537 20 /mol_21120 10
# Computing: 538 17 /mol_2114 10
# Computing: 539 26 /mol_21161 10
# Computing: 540 25 /mol_21169 10
# Computing: 541 18 /mol_21181 10
# Computing: 542 23 /mol_21182 10
# Computing: 543 16 /mol_21241 10
# Computing: 544 25 /mol_21270 10
# Computing: 545 22 /mol_21304 10
# Computing: 546 21 /mol_21341 10
# Computing: 547 23 /mol_21354 10
# Computing: 548 21 /mol_21355 10
# Computing: 549 20 /mol_21371 10
# Computing: 550 22 /mol_21384 10
# Computing: 551 20 /mol_21386 10
# Computing: 552 16 /mol_2145 10
# Computing: 553 22 /mol_21459 10
# Computing: 554 24 /mol_21479 10
# Computing: 555 18 /mol_21493 10
# Computing: 556 20 /mol_21514 10
# Computing: 557 20 /mol_21517 10
# Computing: 558 17 /mol_21670 10
# Computing: 559 18 /mol_21694 10
# Computing: 560 25 /mol_21720 10
# Computing: 561 20 /mol_21730 10
# Computing: 562 26 /mol_21774 10
# Computing: 563 19 /mol_21868 10
# Computing: 564 22 /mol_21875 10
# Computing: 565 22 /mol_21890 10
# Computing: 566 23 /mol_21903 10
# Computing: 567 21 /mol_2193 10
# Computing: 568 19 /mol_2194 10
# Computing: 569 21 /mol_2235 10
# Computing: 570 18 /mol_2238 10
# Computing: 571 19 /mol_2261 10
# Computing: 572 18 /mol_2277 10
# Computing: 573 18 /mol_2282 10
# Computing: 574 16 /mol_234 10
# Computing: 575 17 /mol_2350 10
# Computing: 576 20 /mol_2365 10
# Computing: 577 21 /mol_2371 10
# Computing: 578 18 /mol_2408 10
# Computing: 579 20 /mol_2418 10
# Computing: 580 21 /mol_2429 10
# Computing: 581 16 /mol_2433 10
# Computing: 582 22 /mol_2440 10
# Computing: 583 18 /mol_2468 10
# Computing: 584 19 /mol_2498 10
# Computing: 585 17 /mol_2511 10
# Computing: 586 24 /mol_2519 10
# Computing: 587 23 /mol_2521 10
# Computing: 588 19 /mol_2529 10
# Computing: 589 22 /mol_2534 10
# Computing: 590 24 /mol_2606 10
# Computing: 591 23 /mol_2653 10
# Computing: 592 18 /mol_2699 10
# Computing: 593 18 /mol_2726 10
# Computing: 594 23 /mol_2730 10
# Computing: 595 21 /mol_2733 10
# Computing: 596 21 /mol_2776 10
# Computing: 597 23 /mol_2777 10
# Computing: 598 19 /mol_2787 10
# Computing: 599 23 /mol_2834 10
# Computing: 600 18 /mol_2842 10
# Computing: 601 16 /mol_2847 10
# Computing: 602 17 /mol_2860 10
# Computing: 603 16 /mol_2869 10
# Computing: 604 21 /mol_2875 10
# Computing: 605 18 /mol_2886 10
# Computing: 606 18 /mol_2914 10
# Computing: 607 22 /mol_2933 10
# Computing: 608 18 /mol_2941 10
# Computing: 609 17 /mol_2957 10
# Computing: 610 17 /mol_2960 10
# Computing: 611 17 /mol_2961 10
# Computing: 612 17 /mol_2962 10
# Computing: 613 17 /mol_2963 10
# Computing: 614 17 /mol_2972 10
# Computing: 615 22 /mol_2989 10
# Computing: 616 19 /mol_300 10
# Computing: 617 21 /mol_3003 10
# Computing: 618 21 /mol_3023 10
# Computing: 619 26 /mol_3025 10
# Computing: 620 16 /mol_3053 10
# Computing: 621 17 /mol_3057 10
# Computing: 622 17 /mol_3073 10
# Computing: 623 22 /mol_3082 10
# Computing: 624 16 /mol_3089 10
# Computing: 625 17 /mol_3102 10
# Computing: 626 19 /mol_3112 10
# Computing: 627 16 /mol_3170 10
# Computing: 628 18 /mol_3180 10
# Computing: 629 16 /mol_3253 10
# Computing: 630 16 /mol_3264 10
# Computing: 631 19 /mol_3402 10
# Computing: 632 20 /mol_3428 10
# Computing: 633 16 /mol_3437 10
# Computing: 634 19 /mol_3439 10
# Computing: 635 19 /mol_3441 10
# Computing: 636 19 /mol_346 10
# Computing: 637 18 /mol_3468 10
# Computing: 638 20 /mol_3495 10
# Computing: 639 20 /mol_3550 10
# Computing: 640 19 /mol_3570 10
# Computing: 641 18 /mol_3586 10
# Computing: 642 20 /mol_3604 10
# Computing: 643 25 /mol_3661 10
# Computing: 644 17 /mol_3687 10
# Computing: 645 19 /mol_3729 10
# Computing: 646 24 /mol_3736 10
# Computing: 647 17 /mol_3786 10
# Computing: 648 18 /mol_3811 10
# Computing: 649 18 /mol_3819 10
# Computing: 650 18 /mol_3829 10
# Computing: 651 18 /mol_3882 10
# Computing: 652 18 /mol_3904 10
# Computing: 653 17 /mol_3931 10
# Computing: 654 20 /mol_3933 10
# Computing: 655 19 /mol_3945 10
# Computing: 656 18 /mol_3980 10
# Computing: 657 20 /mol_3987 10
# Computing: 658 20 /mol_3988 10
# Computing: 659 25 /mol_3989 10
# Computing: 660 16 /mol_3997 10
# Computing: 661 20 /mol_4033 10
# Computing: 662 21 /mol_4086 10
# Computing: 663 20 /mol_4160 10
# Computing: 664 24 /mol_4163 10
# Computing: 665 18 /mol_4169 10
# Computing: 666 19 /mol_417 10
# Computing: 667 19 /mol_4176 10
# Computing: 668 18 /mol_4204 10
# Computing: 669 22 /mol_4232 10
# Computing: 670 19 /mol_4244 10
# Computing: 671 16 /mol_4267 10
# Computing: 672 17 /mol_4268 10
# Computing: 673 22 /mol_4289 10
# Computing: 674 20 /mol_4330 10
# Computing: 675 17 /mol_4339 10
# Computing: 676 18 /mol_4349 10
# Computing: 677 21 /mol_4376 10
# Computing: 678 18 /mol_4408 10
# Computing: 679 19 /mol_4455 10
# Computing: 680 18 /mol_4464 10
# Computing: 681 18 /mol_4468 10
# Computing: 682 17 /mol_4473 10
# Computing: 683 19 /mol_4479 10
# Computing: 684 24 /mol_4508 10
# Computing: 685 17 /mol_4541 10
# Computing: 686 18 /mol_4573 10
# Computing: 687 19 /mol_4602 10
# Computing: 688 18 /mol_4618 10
# Computing: 689 18 /mol_4619 10
# Computing: 690 17 /mol_4718 10
# Computing: 691 19 /mol_4751 10
# Computing: 692 19 /mol_4752 10
# Computing: 693 18 /mol_4853 10
# Computing: 694 19 /mol_4869 10
# Computing: 695 17 /mol_4900 10
# Computing: 696 18 /mol_4901 10
# Computing: 697 21 /mol_4928 10
# Computing: 698 16 /mol_4949 10
# Computing: 699 21 /mol_4959 10
# Computing: 700 20 /mol_4967 10
# Computing: 701 22 /mol_4990 10
# Computing: 702 20 /mol_5036 10
# Computing: 703 24 /mol_5038 10
# Computing: 704 16 /mol_5042 10
# Computing: 705 19 /mol_5045 10
# Computing: 706 17 /mol_5057 10
# Computing: 707 22 /mol_5074 10
# Computing: 708 16 /mol_5084 10
# Computing: 709 23 /mol_5119 10
# Computing: 710 23 /mol_5132 10
# Computing: 711 26 /mol_5136 10
# Computing: 712 18 /mol_5140 10
# Computing: 713 21 /mol_5144 10
# Computing: 714 17 /mol_5150 10
# Computing: 715 21 /mol_5154 10
# Computing: 716 22 /mol_5155 10
# Computing: 717 22 /mol_5188 10
# Computing: 718 25 /mol_5196 10
# Computing: 719 17 /mol_5200 10
# Computing: 720 22 /mol_5223 10
# Computing: 721 17 /mol_523 10
# Computing: 722 17 /mol_5233 10
# Computing: 723 17 /mol_5234 10
# Computing: 724 19 /mol_5255 10
# Computing: 725 17 /mol_5285 10
# Computing: 726 20 /mol_5288 10
# Computing: 727 22 /mol_5318 10
# Computing: 728 16 /mol_5320 10
# Computing: 729 19 /mol_5321 10
# Computing: 730 22 /mol_5323 10
# Computing: 731 20 /mol_5330 10
# Computing: 732 19 /mol_5372 10
# Computing: 733 21 /mol_5439 10
# Computing: 734 21 /mol_5470 10
# Computing: 735 24 /mol_5471 10
# Computing: 736 18 /mol_5475 10
# Computing: 737 16 /mol_5484 10
# Computing: 738 21 /mol_5528 10
# Computing: 739 21 /mol_5529 10
# Computing: 740 21 /mol_5532 10
# Computing: 741 20 /mol_5535 10
# Computing: 742 18 /mol_5540 10
# Computing: 743 22 /mol_5546 10
# Computing: 744 21 /mol_5569 10
# Computing: 745 20 /mol_5570 10
# Computing: 746 18 /mol_5575 10
# Computing: 747 16 /mol_5584 10
# Computing: 748 16 /mol_5600 10
# Computing: 749 18 /mol_5623 10
# Computing: 750 20 /mol_5625 10
# Computing: 751 22 /mol_5636 10
# Computing: 752 17 /mol_5643 10
# Computing: 753 16 /mol_5644 10
# Computing: 754 19 /mol_5648 10
# Computing: 755 23 /mol_5693 10
# Computing: 756 22 /mol_5694 10
# Computing: 757 16 /mol_57 10
# Computing: 758 17 /mol_570 10
# Computing: 759 19 /mol_5713 10
# Computing: 760 20 /mol_5717 10
# Computing: 761 21 /mol_5722 10
# Computing: 762 20 /mol_5733 10
# Computing: 763 20 /mol_5739 10
# Computing: 764 21 /mol_5772 10
# Computing: 765 17 /mol_5796 10
# Computing: 766 20 /mol_5800 10
# Computing: 767 20 /mol_5804 10
# Computing: 768 16 /mol_5806 10
# Computing: 769 21 /mol_5823 10
# Computing: 770 17 /mol_5884 10
# Computing: 771 23 /mol_5886 10
# Computing: 772 17 /mol_5893 10
# Computing: 773 16 /mol_5905 10
# Computing: 774 24 /mol_5921 10
# Computing: 775 22 /mol_5934 10
# Computing: 776 17 /mol_5941 10
# Computing: 777 21 /mol_5979 10
# Computing: 778 19 /mol_5990 10
# Computing: 779 21 /mol_6033 10
# Computing: 780 16 /mol_6037 10
# Computing: 781 21 /mol_6077 10
# Computing: 782 18 /mol_6096 10
# Computing: 783 22 /mol_6101 10
# Computing: 784 23 /mol_6110 10
# Computing: 785 21 /mol_6118 10
# Computing: 786 19 /mol_6133 10
# Computing: 787 20 /mol_6159 10
# Computing: 788 20 /mol_6167 10
# Computing: 789 17 /mol_6184 10
# Computing: 790 16 /mol_6263 10
# Computing: 791 20 /mol_6281 10
# Computing: 792 21 /mol_6282 10
# Computing: 793 16 /mol_630 10
# Computing: 794 19 /mol_6304 10
# Computing: 795 21 /mol_6338 10
# Computing: 796 20 /mol_6348 10
# Computing: 797 21 /mol_6353 10
# Computing: 798 21 /mol_6361 10
# Computing: 799 21 /mol_6366 10
# Computing: 800 21 /mol_6380 10
# Computing: 801 18 /mol_6396 10
# Computing: 802 17 /mol_6443 10
# Computing: 803 20 /mol_6446 10
# Computing: 804 21 /mol_6457 10
# Computing: 805 18 /mol_6475 10
# Computing: 806 18 /mol_6478 10
# Computing: 807 17 /mol_654 10
# Computing: 808 19 /mol_6548 10
# Computing: 809 19 /mol_6565 10
# Computing: 810 21 /mol_6588 10
# Computing: 811 21 /mol_6618 10
# Computing: 812 25 /mol_6620 10
# Computing: 813 19 /mol_6769 10
# Computing: 814 17 /mol_679 10
# Computing: 815 19 /mol_6804 10
# Computing: 816 20 /mol_6863 10
# Computing: 817 19 /mol_6926 10
# Computing: 818 18 /mol_6938 10
# Computing: 819 20 /mol_6962 10
# Computing: 820 20 /mol_697 10
# Computing: 821 24 /mol_6977 10
# Computing: 822 24 /mol_6993 10
# Computing: 823 16 /mol_700 10
# Computing: 824 18 /mol_7006 10
# Computing: 825 17 /mol_7024 10
# Computing: 826 18 /mol_7028 10
# Computing: 827 18 /mol_7032 10
# Computing: 828 21 /mol_7034 10
# Computing: 829 24 /mol_7037 10
# Computing: 830 18 /mol_7042 10
# Computing: 831 18 /mol_705 10
# Computing: 832 16 /mol_7051 10
# Computing: 833 22 /mol_7119 10
# Computing: 834 18 /mol_7126 10
# Computing: 835 22 /mol_7131 10
# Computing: 836 22 /mol_7150 10
# Computing: 837 19 /mol_7153 10
# Computing: 838 18 /mol_7160 10
# Computing: 839 21 /mol_7161 10
# Computing: 840 23 /mol_7172 10
# Computing: 841 20 /mol_7196 10
# Computing: 842 18 /mol_7256 10
# Computing: 843 22 /mol_7290 10
# Computing: 844 17 /mol_7293 10
# Computing: 845 20 /mol_7308 10
# Computing: 846 21 /mol_7317 10
# Computing: 847 20 /mol_7331 10
# Computing: 848 27 /mol_7337 10
# Computing: 849 17 /mol_7367 10
# Computing: 850 16 /mol_7372 10
# Computing: 851 19 /mol_7439 10
# Computing: 852 20 /mol_748 10
# Computing: 853 17 /mol_7490 10
# Computing: 854 18 /mol_7503 10
# Computing: 855 18 /mol_7513 10
# Computing: 856 21 /mol_7553 10
# Computing: 857 18 /mol_7556 10
# Computing: 858 19 /mol_7557 10
# Computing: 859 20 /mol_7587 10
# Computing: 860 22 /mol_7622 10
# Computing: 861 26 /mol_7626 10
# Computing: 862 26 /mol_7627 10
# Computing: 863 18 /mol_7635 10
# Computing: 864 19 /mol_7648 10
# Computing: 865 19 /mol_7649 10
# Computing: 866 19 /mol_7651 10
# Computing: 867 18 /mol_7716 10
# Computing: 868 26 /mol_7751 10
# Computing: 869 19 /mol_7787 10
# Computing: 870 21 /mol_7823 10
# Computing: 871 25 /mol_7847 10
# Computing: 872 20 /mol_785 10
# Computing: 873 20 /mol_7850 10
# Computing: 874 21 /mol_7852 10
# Computing: 875 20 /mol_7854 10
# Computing: 876 19 /mol_7875 10
# Computing: 877 16 /mol_7876 10
# Computing: 878 19 /mol_790 10
# Computing: 879 18 /mol_7921 10
# Computing: 880 21 /mol_7949 10
# Computing: 881 16 /mol_7960 10
# Computing: 882 23 /mol_7968 10
# Computing: 883 19 /mol_7977 10
# Computing: 884 21 /mol_7984 10
# Computing: 885 19 /mol_7997 10
# Computing: 886 23 /mol_8004 10
# Computing: 887 21 /mol_8015 10
# Computing: 888 17 /mol_8024 10
# Computing: 889 27 /mol_8033 10
# Computing: 890 18 /mol_8041 10
# Computing: 891 19 /mol_8049 10
# Computing: 892 19 /mol_8064 10
# Computing: 893 18 /mol_8065 10
# Computing: 894 19 /mol_8077 10
# Computing: 895 24 /mol_8085 10
# Computing: 896 18 /mol_8122 10
# Computing: 897 19 /mol_8134 10
# Computing: 898 23 /mol_8171 10
# Computing: 899 19 /mol_8173 10
# Computing: 900 16 /mol_8181 10
# Computing: 901 21 /mol_830 10
# Computing: 902 20 /mol_832 10
# Computing: 903 19 /mol_8375 10
# Computing: 904 18 /mol_8384 10
# Computing: 905 24 /mol_8425 10
# Computing: 906 17 /mol_844 10
# Computing: 907 17 /mol_8476 10
# Computing: 908 18 /mol_8517 10
# Computing: 909 20 /mol_8530 10
# Computing: 910 21 /mol_8531 10
# Computing: 911 22 /mol_8626 10
# Computing: 912 16 /mol_8629 10
# Computing: 913 18 /mol_8699 10
# Computing: 914 16 /mol_8700 10
# Computing: 915 17 /mol_8705 10
# Computing: 916 18 /mol_8706 10
# Computing: 917 18 /mol_8755 10
# Computing: 918 17 /mol_8770 10
# Computing: 919 18 /mol_8796 10
# Computing: 920 19 /mol_884 10
# Computing: 921 16 /mol_8877 10
# Computing: 922 17 /mol_8882 10
# Computing: 923 19 /mol_8917 10
# Computing: 924 20 /mol_8957 10
# Computing: 925 23 /mol_8976 10
# Computing: 926 23 /mol_8980 10
# Computing: 927 20 /mol_8981 10
# Computing: 928 20 /mol_8985 10
# Computing: 929 23 /mol_8990 10
# Computing: 930 23 /mol_8993 10
# Computing: 931 22 /mol_9037 10
# Computing: 932 16 /mol_9049 10
# Computing: 933 23 /mol_9065 10
# Computing: 934 18 /mol_9084 10
# Computing: 935 18 /mol_910 10
# Computing: 936 21 /mol_9112 10
# Computing: 937 18 /mol_9115 10
# Computing: 938 23 /mol_9116 10
# Computing: 939 18 /mol_912 10
# Computing: 940 24 /mol_9123 10
# Computing: 941 19 /mol_9126 10
# Computing: 942 31 /mol_9130 10
# Computing: 943 21 /mol_9133 10
# Computing: 944 20 /mol_9146 10
# Computing: 945 24 /mol_9155 10
# Computing: 946 21 /mol_9165 10
# Computing: 947 21 /mol_9196 10
# Computing: 948 16 /mol_9205 10
# Computing: 949 16 /mol_9233 10
# Computing: 950 25 /mol_9282 10
# Computing: 951 23 /mol_9296 10
# Computing: 952 16 /mol_9306 10
# Computing: 953 21 /mol_9308 10
# Computing: 954 29 /mol_9318 10
# Computing: 955 21 /mol_9335 10
# Computing: 956 22 /mol_9379 10
# Computing: 957 17 /mol_9430 10
# Computing: 958 17 /mol_9433 10
# Computing: 959 16 /mol_9434 10
# Computing: 960 20 /mol_9439 10
# Computing: 961 22 /mol_9444 10
# Computing: 962 21 /mol_9452 10
# Computing: 963 16 /mol_9465 10
# Computing: 964 16 /mol_9467 10
# Computing: 965 19 /mol_9496 10
# Computing: 966 17 /mol_9501 10
# Computing: 967 21 /mol_9521 10
# Computing: 968 16 /mol_9530 10
# Computing: 969 20 /mol_957 10
# Computing: 970 23 /mol_9589 10
# Computing: 971 20 /mol_9595 10
# Computing: 972 23 /mol_9597 10
# Computing: 973 18 /mol_9601 10
# Computing: 974 23 /mol_9608 10
# Computing: 975 23 /mol_9615 10
# Computing: 976 20 /mol_9641 10
# Computing: 977 22 /mol_9652 10
# Computing: 978 22 /mol_9653 10
# Computing: 979 22 /mol_9661 10
# Computing: 980 19 /mol_9675 10
# Computing: 981 21 /mol_9701 10
# Computing: 982 17 /mol_975 10
# Computing: 983 17 /mol_9763 10
# Computing: 984 21 /mol_9803 10
# Computing: 985 25 /mol_9805 10
# Computing: 986 26 /mol_9851 10
# Computing: 987 21 /mol_9871 10
# Computing: 988 18 /mol_9878 10
# Computing: 989 22 /mol_9933 10
# Computing: 990 16 /mol_9940 10
# Computing: 991 21 /mol_9949 10
# Computing: 992 22 /mol_9956 10
# Computing: 993 21 /mol_9963 10
# Computing: 994 19 /mol_9966 10
# Computing: 995 22 /mol_9973 10
# Computing: 996 20 /mol_9982 10
# Computing: 997 23 /mol_9994 10
# Computing: 998 23 /mol_9996 10
# Computing: 999 21 /mol_9999 10

# %%
#print(Eal1.shape,len(Edl))
print(Emin[:,0].min(),Emin[:,1].min(),Emin[:,2].min(),Emin[:,3].min(),Emin[:,4].min())
# Out:
# -2995.627898971841 -2996.2502487755846 -2995.6028266790963 -2994.7556864047365 -2940.8929011664295

# %%
print('E error')
rms = hdt.calculaterootmeansqrerror(Eal[1,:],Eal[0,:])
mae = hdt.calculatemeanabserror(Eal[1,:],Eal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(Eal[2,:],Eal[0,:])
mae = hdt.calculatemeanabserror(Eal[2,:],Eal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(Eal[3,:],Eal[0,:])
mae = hdt.calculatemeanabserror(Eal[3,:],Eal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(Eal[4,:],Eal[0,:])
mae = hdt.calculatemeanabserror(Eal[4,:],Eal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(Eal[5,:],Eal[0,:])
mae = hdt.calculatemeanabserror(Eal[5,:],Eal[0,:])
print(mae,rms)
# Out:
# E error
# 1.5780285319632938 2.5388394070881777
# 1.2918619078890887 2.1326761991749614
# 1.2646463917143833 1.9518837091991543
# 40.258460851509156 42.20243911999541
# 39.87861784512873 41.81666777899067

# %%
print('dE error')
rms = hdt.calculaterootmeansqrerror(dEal[1,:],dEal[0,:])
mae = hdt.calculatemeanabserror(dEal[1,:],dEal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(dEal[2,:],dEal[0,:])
mae = hdt.calculatemeanabserror(dEal[2,:],dEal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(dEal[3,:],dEal[0,:])
mae = hdt.calculatemeanabserror(dEal[3,:],dEal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(dEal[4,:],dEal[0,:])
mae = hdt.calculatemeanabserror(dEal[4,:],dEal[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(dEal[5,:],dEal[0,:])
mae = hdt.calculatemeanabserror(dEal[5,:],dEal[0,:])
print(mae,rms)
# Out:
# dE error
# 0.8793447660659446 1.1675974874151547
# 0.6928571528967891 0.9180629904125021
# 0.6527106805862293 0.8663360780811689
# 0.8479049137800551 1.124343706277912
# 0.4444078806404183 0.5649388324719895

# %%
#dft_shift = Edl.mean()-Eal3.mean()

aes.plot_corr_dist(dEal[1,:],dEal[0,:],xlabel=r'$E_{CCSD} (kcal \times mol^{-1})$',ylabel=r'$E_{ANI} (kcal \times mol^{-1})$')
aes.plot_corr_dist(dEal[2,:],dEal[0,:],xlabel=r'$E_{CCSD} (kcal \times mol^{-1})$',ylabel=r'$E_{ANI} (kcal \times mol^{-1})$')
aes.plot_corr_dist(dEal[3,:],dEal[0,:],xlabel=r'$E_{CCSD} (kcal \times mol^{-1})$',ylabel=r'$E_{DFT} (kcal \times mol^{-1})$')
aes.plot_corr_dist(dEal[4,:],dEal[0,:],xlabel=r'$E_{CCSD} (kcal \times mol^{-1})$',ylabel=r'$E_{DFT} (kcal \times mol^{-1})$')
aes.plot_corr_dist(dEal[4,:],dEal[5,:],xlabel=r'$E_{CCSD} (kcal \times mol^{-1})$',ylabel=r'$E_{DFT} (kcal \times mol^{-1})$')
aes.plot_corr_dist(dEal[5,:],dEal[0,:],xlabel=r'$E_{CCSD} (kcal \times mol^{-1})$',ylabel=r'$E_{DFT} (kcal \times mol^{-1})$')

# %%
f = plt.subplots(figsize=[24,18])
gs  = gridspec.GridSpec(2, 2, width_ratios=[.6, .6])
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])
ax4 = plt.subplot(gs[3])

print((Eal[0,:]-Eal[4,:]).mean(),(Eal[0,:]-Eal[5,:]).mean())

bin1 = aes.plot_corr_dist_axes(ax1,Eal[0,:],Eal[1,:],labelx=r'$\Delta E_{at}^{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{at}^{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T)/CBS Transfer NN',cmap=mpl.cm.viridis)
bin2 = aes.plot_corr_dist_axes(ax2,Eal[0,:],Eal[2,:],labelx=r'$\Delta E_{at}^{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{at}^{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T)/CBS Trained NN',cmap=mpl.cm.viridis)
bin3 = aes.plot_corr_dist_axes(ax3,Eal[0,:],Eal[3,:],labelx=r'$\Delta E_{at}^{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{at}^{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T)/CBS DeltaML NN',cmap=mpl.cm.viridis)
bin4 = aes.plot_corr_dist_axes(ax4,Eal[0,:],Eal[5,:]+(Eal[0,:]-Eal[5,:]).mean(),labelx=r'$\Delta E_{at}^{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{at}^{DFT} (kcal \times mol^{-1})$',plabel='DFT/DZ QM',cmap=mpl.cm.viridis)

f[0].subplots_adjust(right=0.8)
cbar_ax = f[0].add_axes([0.825, 0.15, 0.025, 0.7])
cb1 = f[0].colorbar(bin1[-1], cmap=mpl.cm.viridis, cax=cbar_ax)

cb1.set_label('Count', fontsize=20)
plt.show()
#plt.savefig('/home/jsmith48/scratch/ccsd_extrapolation/image_results/atomization_compare.png')
# Out:
# -40.258460851509156 -39.87861784512873

# %%
#slope, intercept, r_value, p_value, std_err = stats.linregress(hdt.hatokcal*(Edl),hdt.hatokcal*(Eal2))
#print(r_value**2)

# %%
f = plt.subplots(figsize=[23,18])
gs  = gridspec.GridSpec(2, 2, width_ratios=[.85, .85])
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])
ax4 = plt.subplot(gs[3])

bin1 = aes.plot_corr_dist_axes(ax1,dEal[0,:],dEal[1,:],labelx=r'$\Delta E_{CCSD(T)/CBS}(kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T) Transfer NN',cmap=mpl.cm.viridis)
bin2 = aes.plot_corr_dist_axes(ax2,dEal[0,:],dEal[2,:],labelx=r'$\Delta E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T) Trained NN',cmap=mpl.cm.viridis)
bin3 = aes.plot_corr_dist_axes(ax3,dEal[0,:],dEal[3,:],labelx=r'$\Delta E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T) DeltaML NN',cmap=mpl.cm.viridis)
bin4 = aes.plot_corr_dist_axes(ax4,dEal[0,:],dEal[5,:],labelx=r'$\Delta E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{DFT/DZ} (kcal \times mol^{-1})$',plabel='DFT/DZ QM',cmap=mpl.cm.viridis)

f[0].subplots_adjust(right=0.8)
cbar_ax = f[0].add_axes([0.82, 0.15, 0.025, 0.7])
cb1 = f[0].colorbar(bin4[-1], cmap=mpl.cm.viridis, cax=cbar_ax)

cb1.set_label('Count', fontsize=20)
plt.show()

#plt.savefig('/home/jsmith48/scratch/ccsd_extrapolation/image_results/relative_compare.png')

# %%
f = plt.subplots(figsize=[32,10])
gs  = gridspec.GridSpec(1, 3, width_ratios=[.85, .85, 1.0])
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])

Emin_ref = hdt.calculatedmat(Emin[:,0])

bin1 = aes.plot_corr_dist_axes(ax1,hdt.calculatedmat(Emin[:,1]),Emin_ref,labelx=r'$\Delta E_{CCSD(T)/CBS}(kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T) from DFT/DZ',cmap=mpl.cm.viridis)
bin2 = aes.plot_corr_dist_axes(ax2,hdt.calculatedmat(Emin[:,2]),Emin_ref,labelx=r'$\Delta E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T) Only',cmap=mpl.cm.viridis)
bin3 = aes.plot_corr_dist_axes(ax3,hdt.calculatedmat(Emin[:,3]),Emin_ref,labelx=r'$\Delta E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='DFT/DZ',cmap=mpl.cm.viridis)
cb1 = f[0].colorbar(bin1[-1], cmap=mpl.cm.viridis)
cb1.set_label('Count', fontsize=20)
plt.show()

# %%
tsfiles = os.listdir(ccsd_testset)
tsfiles = sorted(tsfiles)
Eccsd = []
Eacc1 = []
Eacc2 = []
msize = []
for nid,ts in enumerate(tsfiles):
    print('Working on:',ts)
    adl = pyt.anidataloader(ccsd_testset+ts)
    for data in adl:
        S = data['species']
        X = data['coordinates']
        
        Esae = hdt.hatokcal*hdt.compute_sae(file=sae1,spc=S)
        
        Eccsd.append( hdt.hatokcal*data['energies'] - Esae)
        
        Eacc1.append( aens_1.compute_energy_conformations_net(X,S,nid) - Esae )
        Eacc2.append( aens_2.compute_energy_conformations_net(X,S,nid) - Esae )
        
        msize.append(len(S))
        
Eacc1 = np.concatenate(Eacc1)
Eacc2 = np.concatenate(Eacc2)
Eccsd = np.concatenate(Eccsd)
msize = np.array(msize)
# Out:
# Working on: testset0.h5
# Working on: testset1.h5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-7b978f0096b7> in <module>()
#      16         Eccsd.append( hdt.hatokcal*data['energies'] - Esae)
#      17
# ---> 18         Eacc1.append( aens_1.compute_energy_conformations_net(X,S,nid) - Esae )
#      19         Eacc2.append( aens_2.compute_energy_conformations_net(X,S,nid) - Esae )
#      20
#
# ~/Gits/ANI-Tools/lib/pyaniasetools.py in compute_energy_conformations_net(self, X, S, netid)
#     183         shift = 0
#     184         for j,x in enumerate(X_split):
# --> 185             self.ncl[netid].setConformers(confs=x,types=list(S))
#     186             E = self.ncl[netid].energy().copy()
#     187             energies[j+shift:j+shift+E.shape[0]] = E
#
# IndexError: list index out of range

# %%
f = plt.subplots(figsize=[24,10])
gs  = gridspec.GridSpec(1, 2, width_ratios=[.85, 1.0])
ax1 = plt.subplot(gs[0])

#ax1.hist(Eacc1-Eccsd,bins=75, range=[-15,15], edgecolor='black', linewidth=1.2, ls='dashed', fc=(0, 0, 1, 0.4),label='Transfer Learned')
ax1.hist(Eacc2-Eccsd,bins=75, range=[-15,15], edgecolor='black', linewidth=1.2, ls='dashed', fc=(1, 0, 0, 0.4),label='Trained only to CCSD(T)')
ax1.hist(Eacc1-Eccsd,bins=75, range=[-15,15], edgecolor='black', linewidth=1.2, ls='dashed', fc=(0, 0, 1, 0.3),label='Transfer Learned')
ax1.set_title('Error Distributions - ANI vs. ', fontsize=24)
ax1.legend(fontsize=16)
ax1.set_xlabel(r'$\Delta E$ ($kcal \times mol^{-1}$)',fontsize=20)
ax1.set_ylabel('Count',fontsize=20)

ax2 = plt.subplot(gs[1])
ax2.hist(msize,bins=16, ls='dashed', edgecolor='black', linewidth=1.2, fc=(1, 0, 0, 0.4))
ax2.set_title('System sizes', fontsize=24)
ax2.set_xlabel('Number of atoms',fontsize=20)

#plt.show()
plt.savefig('/home/jsmith48/scratch/ccsd_extrapolation/image_results/testset_errors.png')

# %%
f = plt.subplots(figsize=[24,10])
gs  = gridspec.GridSpec(1, 2, width_ratios=[1.0, 1.0])
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

Emin_ref = hdt.calculatedmat(Emin[:,0])

bin1 = aes.plot_corr_dist_axes(ax1,Eccsd,Eacc1,labelx=r'$\Delta E_{CCSD(T)/CBS}(kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T) from DFT/DZ',cmap=mpl.cm.viridis)
bin2 = aes.plot_corr_dist_axes(ax2,Eccsd,Eacc2,labelx=r'$\Delta E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$\Delta E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T) Only',cmap=mpl.cm.viridis)
#cb1 = f[0].colorbar(bin1[-1], cmap=mpl.cm.viridis)
#cb1.set_label('Count', fontsize=20)
f[0].subplots_adjust(right=0.8)
cbar_ax = f[0].add_axes([0.825, 0.15, 0.025, 0.7])
cb1 = f[0].colorbar(bin1[-1], cmap=mpl.cm.viridis, cax=cbar_ax)
#plt.show()
plt.savefig('/home/jsmith48/scratch/ccsd_extrapolation/image_results/testset_correlation.png')

# %%
plt.hist(Na, bins=16, edgecolor='black', linewidth=1.2, ls='dashed' ,color='r')
plt.xlabel('Number of atoms')
plt.ylabel('Count')
plt.title('1000x NMS CCSD held out molecules')
#plt.show()
plt.savefig('/home/jsmith48/scratch/ccsd_extrapolation/image_results/heldoutts_dist.png')

# %%
# f = plt.subplots(figsize=[24,10])
# gs  = gridspec.GridSpec(1, 2, width_ratios=[.85, 1.0])
# ax1 = plt.subplot(gs[0])

# ax1.hist(dEdl-dEal1,bins=75, range=[-10,10], edgecolor='black', linewidth=1.2, ls='dashed', fc=(0, 0, 1, 0.4),label='Layer 1 and 3 frozen')
# ax1.hist(dEdl-dEal2,bins=75, range=[-10,10], edgecolor='black', linewidth=1.2, ls='dashed', fc=(1, 0, 0, 0.4),label='Full model retrained')
# ax1.set_title('Error Distributions', fontsize=24)
# ax1.legend(fontsize=16)
# ax1.set_xlabel(r'$\Delta E$ ($kcal \times mol^{-1}$)',fontsize=20)
# ax1.set_ylabel('Count',fontsize=20)

# ax2 = plt.subplot(gs[1])
# ax2.hist(Na,bins=16, ls='dashed', edgecolor='black', linewidth=1.2, fc=(1, 0, 0, 0.4))
# ax2.set_title('System sizes', fontsize=24)
# ax2.set_xlabel('Numer of atoms',fontsize=20)

# plt.show()

# %%
adl = pyt.anidataloader('/home/jsmith48/scratch/extensibility_test_sets/COMP6v1/s66x8/s66x8_wb97x6-31gd.h5')

# %%
sdir = '/home/jsmith48/scratch/extensibility_test_sets/COMP6v1/s66x8/xyz_splits/'

# %%
ani_opt1 = aat.anienscomputetool(cns1, sae1, nnf1, Nn1, 2)
ani_opt2 = aat.anienscomputetool(cns2, sae2, nnf2, Nn2, 2)
ani_opt3 = aat.anienscomputetool(cns3, sae3, nnf3, Nn3, 2)

# %%
ccsd = open('/home/jsmith48/scratch/extensibility_test_sets/COMP6v1/s66x8/ccsd_t_energies.dat')
R = [0.9, 0.95, 1.0, 1.05, 1.1, 1.25, 1.5, 2.0]
Es66 = []
for j,data in enumerate(adl):
    print(data['path'])
    
    if j < 23:

        Ecc = np.zeros(8,dtype=np.float64)
        for i in range(8):
            Ecc[i] = float(ccsd.readline().split()[-1])

        S = data['species']
        X = data['coordinates']
        Edft = hdt.hatokcal*data['energies']

        # Compute SAE lin fit
        Esae_ccs= hdt.hatokcal*hdt.compute_sae(file=ccssae,spc=S)
        Esae_dft= hdt.hatokcal*hdt.compute_sae(file=dftsae,spc=S)
        
        #print(Edft-Edft.min(),Ecc-Ecc.min())

        Ea1_t,Fa1_t,Sa1 = aens_1.compute_energyandforce_conformations(X,S)
        Ea2_t,Fa2_t,Sa2 = aens_2.compute_energyandforce_conformations(X,S)
        Ea3_t,Fa3_t,Sa3 = aens_3.compute_energyandforce_conformations(X,S)

        #print(os.listdir(sdir))
        
        
        X1,S1,Na1,C1 = hdt.readxyz2(sdir+'s66x8_'+str(j).zfill(2)+'-1.xyz')
        #X1o,CNV = ani_opt1.optimize_molecule(X1[0],S1,fmax=0.0001)
        print(X1)
        Ea1s1_t,Fa1s1_t,Sas11 = aens_1.compute_energyandforce_conformations(X1,S1)
        #X1o,CNV = ani_opt2.optimize_molecule(X1[0],S1,fmax=0.0001)
        Ea2s1_t,Fa2s1_t,Sas12 = aens_2.compute_energyandforce_conformations(X1,S1)
        #X1o,CNV = ani_opt3.optimize_molecule(X1[0],S1,fmax=0.0001)
        Ea3s1_t,Fa3s1_t,Sas13 = aens_3.compute_energyandforce_conformations(X1,S1)

        X2,S2,Na2,C2 = hdt.readxyz2(sdir+'s66x8_'+str(j).zfill(2)+'-2.xyz')
        #X2o,CNV = ani_opt1.optimize_molecule(X2[0],S2,fmax=0.0001)
        Ea1s2_t,Fa1s2_t,Sas21 = aens_1.compute_energyandforce_conformations(X2,S2)
        #X2o,CNV = ani_opt1.optimize_molecule(X2[0],S2,fmax=0.0001)
        Ea2s2_t,Fa2s2_t,Sas22 = aens_2.compute_energyandforce_conformations(X2,S2)
        #X2o,CNV = ani_opt1.optimize_molecule(X2[0],S2,fmax=0.0001)
        Ea3s2_t,Fa3s2_t,Sas23 = aens_3.compute_energyandforce_conformations(X2,S2)
        
        Ea1s = Ea1s1_t + Ea1s2_t
        Ea2s = Ea2s1_t + Ea2s2_t
        Ea3s = Ea3s1_t + Ea3s2_t
        
        print(Ea1_t,Ea1s)
        
        #plt.plot(Edft,label='DFT/DZ')
        plt.plot(R,Ecc,label='CCSD(T)')
        plt.plot(R,Ea1_t-Ea1s,label='ANI TL')
        plt.plot(R,Ea2_t-Ea2s,label='ANI CC')
        plt.plot(R,Ea3_t-Ea3s,label='ANI DT')
        
        Es66.append(np.array([Ecc-Ecc.mean(),Ea1_t-Ea1_t.mean(),Ea2_t-Ea2_t.mean(),Ea3_t-Ea3_t.mean(),Edft-Edft.min()]))

        plt.legend()
        plt.show()
Es66 = np.hstack(Es66)
# Out:
# /s66x8/mol00
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-a7e02fb34a57> in <module>()
#      21         #print(Edft-Edft.min(),Ecc-Ecc.min())
#      22
# ---> 23         Ea1_t,Fa1_t,Sa1 = aens_1.compute_energyandforce_conformations(X,S)
#      24         Ea2_t,Fa2_t,Sa2 = aens_2.compute_energyandforce_conformations(X,S)
#      25         Ea3_t,Fa3_t,Sa3 = aens_3.compute_energyandforce_conformations(X,S)
#
# ~/Gits/ANI-Tools/lib/pyaniasetools.py in compute_energyandforce_conformations(self, X, S, ensemble)
#     145         for i,nc in enumerate(self.ncl):
#     146             nc.setConformers(confs=np.array(X,dtype=np.float32),types=list(S))
# --> 147             energy[i] = nc.energy().copy()
#     148             forces[i] = nc.force().copy()
#     149
#
# RuntimeError: unidentifiable C++ exception

# %%
print('E error -- s66x8 hydrogen bonding error')
print('        MAE               RMSE')
rms = hdt.calculaterootmeansqrerror(Es66[1,:],Es66[0,:])
mae = hdt.calculatemeanabserror(Es66[1,:],Es66[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(Es66[2,:],Es66[0,:])
mae = hdt.calculatemeanabserror(Es66[2,:],Es66[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(Es66[3,:],Es66[0,:])
mae = hdt.calculatemeanabserror(Es66[3,:],Es66[0,:])
print(mae,rms)
rms = hdt.calculaterootmeansqrerror(Es66[4,:],Es66[0,:])
mae = hdt.calculatemeanabserror(Es66[4,:],Es66[0,:])
print(mae,rms)

# %%
f = plt.subplots(figsize=[20,15])
gs  = gridspec.GridSpec(2, 2, width_ratios=[.85, .85])
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])
ax4 = plt.subplot(gs[3])

bin1 = aes.plot_corr_dist_axes(ax1,Es66[0,:],Es66[1,:],labelx=r'$E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T)/CBS Transfer NN',cmap=mpl.cm.viridis)
bin2 = aes.plot_corr_dist_axes(ax2,Es66[0,:],Es66[2,:],labelx=r'$E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$E_{ANI} (kcal \times mol^{-1})$',plabel='CCSD(T)/CBS Trained NN',cmap=mpl.cm.viridis)
bin3 = aes.plot_corr_dist_axes(ax3,Es66[0,:],Es66[3,:],labelx=r'$E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$E_{ANI} (kcal \times mol^{-1})$',plabel='DFT/DZ Trained NN',cmap=mpl.cm.viridis)
bin4 = aes.plot_corr_dist_axes(ax4,Es66[0,:],Es66[4,:],labelx=r'$E_{CCSD(T)/CBS} (kcal \times mol^{-1})$',labely=r'$E_{DFT} (kcal \times mol^{-1})$',plabel='DFT/DZ QM',cmap=mpl.cm.viridis)

f[0].subplots_adjust(right=0.8)
cbar_ax = f[0].add_axes([0.825, 0.15, 0.025, 0.7])
cb1 = f[0].colorbar(bin1[-1], cmap=mpl.cm.viridis, cax=cbar_ax)

cb1.set_label('Count', fontsize=20)
plt.show()
