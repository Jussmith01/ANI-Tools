# %%
import pyanitools as pyt
import numpy as np
import os

import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.manifold import TSNE

# %%
h5dir = '/home/jsmith48/scratch/qm9/h5files/'
h5out = '/home/jsmith48/scratch/qm9/qm9_comb.h5'

# %%
files = [f for f in os.listdir(h5dir) if '.h5' in f]

# %%
files
# Out:
# ['qm9_data.h5']

# %%
isomers = dict()
total_groups=0
for i,f in enumerate(files): 
    print ('Working on file:',i,f)
    adl = pyt.anidataloader(h5dir+f)
    for j,data in enumerate(adl):
        #print(data.keys())
        S = data['species']
        
        unique, counts = np.unique(S, return_counts=True)

        idx = np.argsort(unique)
        #print(unique[idx], counts[idx])

        ep = ""
        for u,c in zip(unique[idx],counts[idx]):
            ep+=u+str(c).zfill(2)
        #print(ep)

        if 'energies' not in data and 'extrapE' not in data:
            print(f, data.keys())

        total_groups+=1

        if ep in isomers:
            isomers[ep].append(data)
        else:
            isomers[ep] = [data]
# Out:
# Working on file: 0 qm9_data.h5

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d8e8fca2dc0f> in <module>()
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
print(total_groups,'->',len(isomers))
iso_len = []
for k in isomers.keys():
    N = 0
    for data in isomers[k]:
        if 'energies' not in data:
            if 'extrapE' in data:
                N+=data['extrapE'].size
            print(k,data.keys())
        else:
            N+=data['energies'].size
    iso_len.append(N)
print(np.where(np.array(iso_len) < 5)[0].size)
# Out:
# 353667 -> 13413
# 6535

# %%
tdata_count = 0
cluster_count = 0
toss_count = 0
dpack = pyt.datapacker(h5out)
for cnt,k in enumerate(isomers.keys()):
    X=[]
    E=[]
    F=[]
    C=[]
    print('count:',cnt)
    for data in isomers[k]:
        
        if data['coordinates'].size != 0:
            S = data['species']
            if '' not in S:
                Na = len(S)
                sidx = np.argsort(S)

                S = np.array(S)[sidx]

                #print(data['coordinates'].shape,sidx,S)
                X.append(data['coordinates'][:,sidx,:])
                if 'energies' not in data:
                    E.append(data['extrapE'])
                    #print('Energies:',data['extrapE'].shape)
                else:
                    E.append(data['energies'])
                    #print('Energies',data['energies'].shape)
                    
                #if 'CM5' not in data:
                    #C.append(data['cm5'][:,0:Na][:,sidx])
                    #print('1',data['cm5'])
                    #print('Charges:',data['cm5'][0:Na].shape,data['coordinates'].shape,Na)
                #else:
                    #C.append(data['CM5'][:,0:Na][:,sidx])
                    #print('2',data['CM5'])
                    #print('Charges:',data['CM5'][0:Na].shape,data['coordinates'].shape,Na)
                
                #F.append(data['forces'][:,sidx,:])
                F.append(0.0*data['coordinates'][:,sidx,:])
            else:
                toss_count += 1
                print(len(data['species']),data['coordinates'].shape[1],len(S) == data['coordinates'].shape[1])
            
    if len(E) > 0:
        #print('ITERATIONS')
        data = {'species':S,
                'coordinates':np.vstack(X),
                'energies':np.concatenate(E),
                'forces':np.vstack(F),
                #'CM5':np.vstack(C),
                }
        
        print('Working on isomers:',k,'Total data:',data['energies'].size)

        # If N data is less than 5 just skip 
        if data['energies'].size <= 500000:
            print('  -Storing '+k+', no clustering, less than 5 data. DATA:',data['energies'].size)
            data.update({'cluster_mask':np.zeros(data['energies'].size,dtype=np.int)})
            data['species'] = list(data['species'])
            
            tdata_count += data['energies'].size
            dpack.store_data('/'+k+'/clust-'+str(0).zfill(3),**data)        
        else: # Else cluster
            # Compute distances
            d = np.zeros((data['energies'].size,int(S.size*(S.size-1)/2)),dtype=np.float64)
            it=0
            for i in range(0,S.size):
                for j in range(i+1,S.size):
                    d[:,it] = np.linalg.norm(data['coordinates'][:,i,:]-data['coordinates'][:,j,:],axis=1)
                    it+=1

            range_n_clusters = np.arange(2,100)
            silhouette_test = -1.0
            prev_cluster_labels = None
            for n_clusters in range_n_clusters:

                # Initialize the clusterer with n_clusters value
                pre_comp = data['energies'].size < 15000
                clusterer = KMeans(n_clusters=n_clusters, precompute_distances=pre_comp, algorithm='elkan')
                cluster_labels = clusterer.fit_predict(d)

                silhouette_avg = silhouette_score(d, cluster_labels,metric="manhattan")
                print("  For n_clusters =", n_clusters,
                      "The average silhouette_score is :", silhouette_avg)

                if silhouette_avg > silhouette_test:
                    silhouette_test = silhouette_avg
                    prev_cluster_labels = cluster_labels
                else:
                    break
            print('  Converged to', n_clusters-1,'clusters.')
            cluster_count += n_clusters-1

            tdata_count += data['energies'].size
            dpack.store_data('/'+k,
                             coordinates=data['coordinates'],
                             species=list(data['species']),
                             energies=data['energies'],
                             #CM5=data['CM5'],
                             forces=data['forces'],
                             cluster_mask=prev_cluster_labels,)
        
#         tsne = TSNE(n_components=2, verbose=0, perplexity=50, n_iter=300)
#         tsne_results = tsne.fit_transform(d)

#         for cid in range(n_clusters-1):
#             idx = np.where(prev_cluster_labels == cid)
#             print(' -Storing Cluster:',cid,' n_elements=',idx[0].size)

#             plt.scatter(tsne_results[idx,0],tsne_results[idx,1])
#         plt.show()

dpack.cleanup()
print(toss_count, tdata_count)
# Out:
# count: 0
# Working on isomers: C01H04 Total data: 1
#   -Storing C01H04, no clustering, less than 5 data. DATA: 1
# count: 1
# Working on isomers: H03N01 Total data: 1
#   -Storing H03N01, no clustering, less than 5 data. DATA: 1
# count: 2
# Working on isomers: H02O01 Total data: 1
#   -Storing H02O01, no clustering, less than 5 data. DATA: 1
# count: 3
# Working on isomers: C02H02 Total data: 1
#   -Storing C02H02, no clustering, less than 5 data. DATA: 1
# count: 4
# Working on isomers: C01H01N01 Total data: 1
#   -Storing C01H01N01, no clustering, less than 5 data. DATA: 1
# count: 5
# Working on isomers: C01H02O01 Total data: 1
#   -Storing C01H02O01, no clustering, less than 5 data. DATA: 1
# count: 6
# Working on isomers: C02H06 Total data: 1
#   -Storing C02H06, no clustering, less than 5 data. DATA: 1
# count: 7
# Working on isomers: C01H04O01 Total data: 1
#   -Storing C01H04O01, no clustering, less than 5 data. DATA: 1
# count: 8
# Working on isomers: C03H04 Total data: 1
#   -Storing C03H04, no clustering, less than 5 data. DATA: 1
# count: 9
# Working on isomers: C02H03N01 Total data: 1
#   -Storing C02H03N01, no clustering, less than 5 data. DATA: 1
# count: 10
# Working on isomers: C02H04O01 Total data: 2
#   -Storing C02H04O01, no clustering, less than 5 data. DATA: 2
# count: 11
# Working on isomers: C01H03N01O01 Total data: 1
#   -Storing C01H03N01O01, no clustering, less than 5 data. DATA: 1
# count: 12
# Working on isomers: C03H08 Total data: 1
#   -Storing C03H08, no clustering, less than 5 data. DATA: 1
# count: 13
# Working on isomers: C02H06O01 Total data: 2
#   -Storing C02H06O01, no clustering, less than 5 data. DATA: 2
# count: 14
# Working on isomers: C03H06 Total data: 1
#   -Storing C03H06, no clustering, less than 5 data. DATA: 1
# count: 15
# Working on isomers: C03H06O01 Total data: 5
#   -Storing C03H06O01, no clustering, less than 5 data. DATA: 5
# count: 16
# Working on isomers: C02H05N01O01 Total data: 2
#   -Storing C02H05N01O01, no clustering, less than 5 data. DATA: 2
# count: 17
# Working on isomers: C01H04N02O01 Total data: 1
#   -Storing C01H04N02O01, no clustering, less than 5 data. DATA: 1
# count: 18
# Working on isomers: C04H10 Total data: 2
#   -Storing C04H10, no clustering, less than 5 data. DATA: 2
# count: 19
# Working on isomers: C03H08O01 Total data: 3
#   -Storing C03H08O01, no clustering, less than 5 data. DATA: 3
# count: 20
# Working on isomers: C04H02 Total data: 1
#   -Storing C04H02, no clustering, less than 5 data. DATA: 1
# count: 21
# Working on isomers: C03H01N01 Total data: 1
#   -Storing C03H01N01, no clustering, less than 5 data. DATA: 1
# count: 22
# Working on isomers: C02N02 Total data: 1
#   -Storing C02N02, no clustering, less than 5 data. DATA: 1
# count: 23
# Working on isomers: C03H02O01 Total data: 1
#   -Storing C03H02O01, no clustering, less than 5 data. DATA: 1
# count: 24
# Working on isomers: C02H01N01O01 Total data: 1
#   -Storing C02H01N01O01, no clustering, less than 5 data. DATA: 1
# count: 25
# Working on isomers: C02H02O02 Total data: 1
#   -Storing C02H02O02, no clustering, less than 5 data. DATA: 1
# count: 26
# Working on isomers: C04H06 Total data: 2
#   -Storing C04H06, no clustering, less than 5 data. DATA: 2
# count: 27
# Working on isomers: C03H05N01 Total data: 1
#   -Storing C03H05N01, no clustering, less than 5 data. DATA: 1
# count: 28
# Working on isomers: C02H04N02 Total data: 1
#   -Storing C02H04N02, no clustering, less than 5 data. DATA: 1
# count: 29
# Working on isomers: C03H04O01 Total data: 1
#   -Storing C03H04O01, no clustering, less than 5 data. DATA: 1
# count: 30
# Working on isomers: C02H03N01O01 Total data: 1
#   -Storing C02H03N01O01, no clustering, less than 5 data. DATA: 1
# count: 31
# Working on isomers: C02H04O02 Total data: 2
#   -Storing C02H04O02, no clustering, less than 5 data. DATA: 2
# count: 32
# Working on isomers: C02H06O02 Total data: 1
#   -Storing C02H06O02, no clustering, less than 5 data. DATA: 1
# count: 33
# Working on isomers: C04H08 Total data: 2
#   -Storing C04H08, no clustering, less than 5 data. DATA: 2
# count: 34
# Working on isomers: C03H07N01 Total data: 1
#   -Storing C03H07N01, no clustering, less than 5 data. DATA: 1
# count: 35
# Working on isomers: C03H07N01O01 Total data: 8
#   -Storing C03H07N01O01, no clustering, less than 5 data. DATA: 8
# count: 36
# Working on isomers: C04H05N01 Total data: 3
#   -Storing C04H05N01, no clustering, less than 5 data. DATA: 3
# count: 37
# Working on isomers: C03H04N02 Total data: 3
#   -Storing C03H04N02, no clustering, less than 5 data. DATA: 3
# count: 38
# Working on isomers: C04H04O01 Total data: 5
#   -Storing C04H04O01, no clustering, less than 5 data. DATA: 5
# count: 39
# Working on isomers: C03H03N01O01 Total data: 6
#   -Storing C03H03N01O01, no clustering, less than 5 data. DATA: 6
# count: 40
# Working on isomers: C05H12 Total data: 3
#   -Storing C05H12, no clustering, less than 5 data. DATA: 3
# count: 41
# Working on isomers: C04H10O01 Total data: 7
#   -Storing C04H10O01, no clustering, less than 5 data. DATA: 7
# count: 42
# Working on isomers: C02H03N03 Total data: 5
#   -Storing C02H03N03, no clustering, less than 5 data. DATA: 5
# count: 43
# Working on isomers: C03H04O02 Total data: 4
#   -Storing C03H04O02, no clustering, less than 5 data. DATA: 4
# count: 44
# Working on isomers: C02H04N02O01 Total data: 2
#   -Storing C02H04N02O01, no clustering, less than 5 data. DATA: 2
# count: 45
# Working on isomers: C02H03N01O02 Total data: 3
#   -Storing C02H03N01O02, no clustering, less than 5 data. DATA: 3
# count: 46
# Working on isomers: C05H08 Total data: 6
#   -Storing C05H08, no clustering, less than 5 data. DATA: 6
# count: 47
# Working on isomers: C04H07N01 Total data: 2
#   -Storing C04H07N01, no clustering, less than 5 data. DATA: 2
# count: 48
# Working on isomers: C03H06N02 Total data: 2
#   -Storing C03H06N02, no clustering, less than 5 data. DATA: 2
# count: 49
# Working on isomers: C04H06O01 Total data: 10
#   -Storing C04H06O01, no clustering, less than 5 data. DATA: 10
# count: 50
# Working on isomers: C03H05N01O01 Total data: 9
#   -Storing C03H05N01O01, no clustering, less than 5 data. DATA: 9
# count: 51
# Working on isomers: C04H08O01 Total data: 14
#   -Storing C04H08O01, no clustering, less than 5 data. DATA: 14
# count: 52
# Working on isomers: C03H06O02 Total data: 10
#   -Storing C03H06O02, no clustering, less than 5 data. DATA: 10
# count: 53
# Working on isomers: C02H06N02O01 Total data: 1
#   -Storing C02H06N02O01, no clustering, less than 5 data. DATA: 1
# count: 54
# Working on isomers: C02H05N01O02 Total data: 3
#   -Storing C02H05N01O02, no clustering, less than 5 data. DATA: 3
# count: 55
# Working on isomers: C03H08O02 Total data: 3
#   -Storing C03H08O02, no clustering, less than 5 data. DATA: 3
# count: 56
# Working on isomers: C05H10 Total data: 5
#   -Storing C05H10, no clustering, less than 5 data. DATA: 5
# count: 57
# Working on isomers: C04H09N01 Total data: 2
#   -Storing C04H09N01, no clustering, less than 5 data. DATA: 2
# count: 58
# Working on isomers: C05H04 Total data: 2
#   -Storing C05H04, no clustering, less than 5 data. DATA: 2
# count: 59
# Working on isomers: C04H03N01 Total data: 2
#   -Storing C04H03N01, no clustering, less than 5 data. DATA: 2
# count: 60
# Working on isomers: C03H02N02 Total data: 1
#   -Storing C03H02N02, no clustering, less than 5 data. DATA: 1
# count: 61
# Working on isomers: C05H06 Total data: 1
#   -Storing C05H06, no clustering, less than 5 data. DATA: 1
# count: 62
# Working on isomers: C02H02N02O01 Total data: 4
#   -Storing C02H02N02O01, no clustering, less than 5 data. DATA: 4
# count: 63
# Working on isomers: C01H01N03O01 Total data: 2
#   -Storing C01H01N03O01, no clustering, less than 5 data. DATA: 2
# count: 64
# Working on isomers: N04O01 Total data: 1
#   -Storing N04O01, no clustering, less than 5 data. DATA: 1
# count: 65
# Working on isomers: C04H05N01O01 Total data: 38
#   -Storing C04H05N01O01, no clustering, less than 5 data. DATA: 38
# count: 66
# Working on isomers: C03H07N01O02 Total data: 13
#   -Storing C03H07N01O02, no clustering, less than 5 data. DATA: 13
# count: 67
# Working on isomers: C04H09N01O01 Total data: 20
#   -Storing C04H09N01O01, no clustering, less than 5 data. DATA: 20
# count: 68
# Working on isomers: C04H07N01O01 Total data: 41
#   -Storing C04H07N01O01, no clustering, less than 5 data. DATA: 41
# count: 69
# Working on isomers: C03H06N02O01 Total data: 14
#   -Storing C03H06N02O01, no clustering, less than 5 data. DATA: 14
# count: 70
# Working on isomers: C03H05N01O02 Total data: 19
#   -Storing C03H05N01O02, no clustering, less than 5 data. DATA: 19
# count: 71
# Working on isomers: C01F04 Total data: 1
#   -Storing C01F04, no clustering, less than 5 data. DATA: 1
# count: 72
# Working on isomers: C03H04N02O01 Total data: 23
#   -Storing C03H04N02O01, no clustering, less than 5 data. DATA: 23
# count: 73
# Working on isomers: C03H03N01O02 Total data: 9
#   -Storing C03H03N01O02, no clustering, less than 5 data. DATA: 9
# count: 74
# Working on isomers: C03H02O03 Total data: 2
#   -Storing C03H02O03, no clustering, less than 5 data. DATA: 2
# count: 75
# Working on isomers: C05H07N01 Total data: 19
#   -Storing C05H07N01, no clustering, less than 5 data. DATA: 19
# count: 76
# Working on isomers: C05H06O01 Total data: 25
#   -Storing C05H06O01, no clustering, less than 5 data. DATA: 25
# count: 77
# Working on isomers: C04H06N02 Total data: 17
#   -Storing C04H06N02, no clustering, less than 5 data. DATA: 17
# count: 78
# Working on isomers: C03H05N03 Total data: 16
#   -Storing C03H05N03, no clustering, less than 5 data. DATA: 16
# count: 79
# Working on isomers: C06H06 Total data: 7
#   -Storing C06H06, no clustering, less than 5 data. DATA: 7
# count: 80
# Working on isomers: C05H05N01 Total data: 6
#   -Storing C05H05N01, no clustering, less than 5 data. DATA: 6
# count: 81
# Working on isomers: C04H04N02 Total data: 6
#   -Storing C04H04N02, no clustering, less than 5 data. DATA: 6
# count: 82
# Working on isomers: C03H03N03 Total data: 3
#   -Storing C03H03N03, no clustering, less than 5 data. DATA: 3
# count: 83
# Working on isomers: C06H10 Total data: 21
#   -Storing C06H10, no clustering, less than 5 data. DATA: 21
# count: 84
# Working on isomers: C05H09N01 Total data: 6
#   -Storing C05H09N01, no clustering, less than 5 data. DATA: 6
# count: 85
# Working on isomers: C04H08N02 Total data: 6
#   -Storing C04H08N02, no clustering, less than 5 data. DATA: 6
# count: 86
# Working on isomers: C05H08O01 Total data: 48
#   -Storing C05H08O01, no clustering, less than 5 data. DATA: 48
# count: 87
# Working on isomers: C05H10O01 Total data: 40
#   -Storing C05H10O01, no clustering, less than 5 data. DATA: 40
# count: 88
# Working on isomers: C04H08O02 Total data: 38
#   -Storing C04H08O02, no clustering, less than 5 data. DATA: 38
# count: 89
# Working on isomers: C05H12O01 Total data: 14
#   -Storing C05H12O01, no clustering, less than 5 data. DATA: 14
# count: 90
# Working on isomers: C04H10O02 Total data: 11
#   -Storing C04H10O02, no clustering, less than 5 data. DATA: 11
# count: 91
# Working on isomers: C06H14 Total data: 5
#   -Storing C06H14, no clustering, less than 5 data. DATA: 5
# count: 92
# Working on isomers: C04H06O02 Total data: 32
#   -Storing C04H06O02, no clustering, less than 5 data. DATA: 32
# count: 93
# Working on isomers: C02H05N03O01 Total data: 2
#   -Storing C02H05N03O01, no clustering, less than 5 data. DATA: 2
# count: 94
# Working on isomers: C02H04N02O02 Total data: 4
#   -Storing C02H04N02O02, no clustering, less than 5 data. DATA: 4
# count: 95
# Working on isomers: C03H08N02O01 Total data: 3
#   -Storing C03H08N02O01, no clustering, less than 5 data. DATA: 3
# count: 96
# Working on isomers: C06H12 Total data: 12
#   -Storing C06H12, no clustering, less than 5 data. DATA: 12
# count: 97
# Working on isomers: C05H11N01 Total data: 6
#   -Storing C05H11N01, no clustering, less than 5 data. DATA: 6
# count: 98
# Working on isomers: C05H02O01 Total data: 2
#   -Storing C05H02O01, no clustering, less than 5 data. DATA: 2
# count: 99
# Working on isomers: C04H01N01O01 Total data: 2
#   -Storing C04H01N01O01, no clustering, less than 5 data. DATA: 2
# count: 100
# Working on isomers: C03N02O01 Total data: 1
#   -Storing C03N02O01, no clustering, less than 5 data. DATA: 1
# count: 101
# Working on isomers: C04H02O02 Total data: 2
#   -Storing C04H02O02, no clustering, less than 5 data. DATA: 2
# count: 102
# Working on isomers: C03H01N01O02 Total data: 1
#   -Storing C03H01N01O02, no clustering, less than 5 data. DATA: 1
# count: 103
# Working on isomers: C05H04O01 Total data: 2
#   -Storing C05H04O01, no clustering, less than 5 data. DATA: 2
# count: 104
# Working on isomers: C04H03N01O01 Total data: 2
#   -Storing C04H03N01O01, no clustering, less than 5 data. DATA: 2
# count: 105
# Working on isomers: C03H02N02O01 Total data: 1
#   -Storing C03H02N02O01, no clustering, less than 5 data. DATA: 1
# count: 106
# Working on isomers: C04H04O02 Total data: 9
#   -Storing C04H04O02, no clustering, less than 5 data. DATA: 9
# count: 107
# Working on isomers: C03H04O03 Total data: 7
#   -Storing C03H04O03, no clustering, less than 5 data. DATA: 7
# count: 108
# Working on isomers: C03H06O03 Total data: 5
#   -Storing C03H06O03, no clustering, less than 5 data. DATA: 5
# count: 109
# Working on isomers: C03H07N03 Total data: 1
#   -Storing C03H07N03, no clustering, less than 5 data. DATA: 1
# count: 110
# Working on isomers: C03H08O03 Total data: 1
#   -Storing C03H08O03, no clustering, less than 5 data. DATA: 1
# count: 111
# Working on isomers: C06H08 Total data: 10
#   -Storing C06H08, no clustering, less than 5 data. DATA: 10
# count: 112
# Working on isomers: C06H02 Total data: 1
#   -Storing C06H02, no clustering, less than 5 data. DATA: 1
# count: 113
# Working on isomers: C05H01N01 Total data: 1
#   -Storing C05H01N01, no clustering, less than 5 data. DATA: 1
# count: 114
# Working on isomers: C04N02 Total data: 1
#   -Storing C04N02, no clustering, less than 5 data. DATA: 1
# count: 115
# Working on isomers: C02H02N04 Total data: 3
#   -Storing C02H02N04, no clustering, less than 5 data. DATA: 3
# count: 116
# Working on isomers: C02H04N04 Total data: 8
#   -Storing C02H04N04, no clustering, less than 5 data. DATA: 8
# count: 117
# Working on isomers: C02H03N03O01 Total data: 12
#   -Storing C02H03N03O01, no clustering, less than 5 data. DATA: 12
# count: 118
# Working on isomers: C01H03N05 Total data: 3
#   -Storing C01H03N05, no clustering, less than 5 data. DATA: 3
# count: 119
# Working on isomers: C02H02N02O02 Total data: 3
#   -Storing C02H02N02O02, no clustering, less than 5 data. DATA: 3
# count: 120
# Working on isomers: C01H01N03O02 Total data: 3
#   -Storing C01H01N03O02, no clustering, less than 5 data. DATA: 3
# count: 121
# Working on isomers: C01H02N04O01 Total data: 3
#   -Storing C01H02N04O01, no clustering, less than 5 data. DATA: 3
# count: 122
# Working on isomers: C02H01N01O03 Total data: 1
#   -Storing C02H01N01O03, no clustering, less than 5 data. DATA: 1
# count: 123
# Working on isomers: C01N02O03 Total data: 1
#   -Storing C01N02O03, no clustering, less than 5 data. DATA: 1
# count: 124
# Working on isomers: C05H07N01O01 Total data: 225
#   -Storing C05H07N01O01, no clustering, less than 5 data. DATA: 225
# count: 125
# Working on isomers: C04H06N02O01 Total data: 137
#   -Storing C04H06N02O01, no clustering, less than 5 data. DATA: 137
# count: 126
# Working on isomers: C04H07N01O02 Total data: 119
#   -Storing C04H07N01O02, no clustering, less than 5 data. DATA: 119
# count: 127
# Working on isomers: C04H09N01O02 Total data: 54
#   -Storing C04H09N01O02, no clustering, less than 5 data. DATA: 54
# count: 128
# Working on isomers: C05H11N01O01 Total data: 53
#   -Storing C05H11N01O01, no clustering, less than 5 data. DATA: 53
# count: 129
# Working on isomers: C04H08N02O02 Total data: 132
#   -Storing C04H08N02O02, no clustering, less than 5 data. DATA: 132
# count: 130
# Working on isomers: C03H06N02O02 Total data: 25
#   -Storing C03H06N02O02, no clustering, less than 5 data. DATA: 25
# count: 131
# Working on isomers: C05H09N01O01 Total data: 169
#   -Storing C05H09N01O01, no clustering, less than 5 data. DATA: 169
# count: 132
# Working on isomers: C04H08N02O01 Total data: 50
#   -Storing C04H08N02O01, no clustering, less than 5 data. DATA: 50
# count: 133
# Working on isomers: C05H03N01O01 Total data: 20
#   -Storing C05H03N01O01, no clustering, less than 5 data. DATA: 20
# count: 134
# Working on isomers: C04H05N01O02 Total data: 112
#   -Storing C04H05N01O02, no clustering, less than 5 data. DATA: 112
# count: 135
# Working on isomers: C03F03H01 Total data: 1
#   -Storing C03F03H01, no clustering, less than 5 data. DATA: 1
# count: 136
# Working on isomers: C02F03N01 Total data: 1
#   -Storing C02F03N01, no clustering, less than 5 data. DATA: 1
# count: 137
# Working on isomers: C02F03H01O01 Total data: 1
#   -Storing C02F03H01O01, no clustering, less than 5 data. DATA: 1
# count: 138
# Working on isomers: C02F03H04N01 Total data: 1
#   -Storing C02F03H04N01, no clustering, less than 5 data. DATA: 1
# count: 139
# Working on isomers: C02F03H03O01 Total data: 1
#   -Storing C02F03H03O01, no clustering, less than 5 data. DATA: 1
# count: 140
# Working on isomers: C03F03H05 Total data: 1
#   -Storing C03F03H05, no clustering, less than 5 data. DATA: 1
# count: 141
# Working on isomers: C06H09N01 Total data: 81
#   -Storing C06H09N01, no clustering, less than 5 data. DATA: 81
# count: 142
# Working on isomers: C06H08O01 Total data: 160
#   -Storing C06H08O01, no clustering, less than 5 data. DATA: 160
# count: 143
# Working on isomers: C05H08N02 Total data: 63
#   -Storing C05H08N02, no clustering, less than 5 data. DATA: 63
# count: 144
# Working on isomers: C05H06O02 Total data: 116
#   -Storing C05H06O02, no clustering, less than 5 data. DATA: 116
# count: 145
# Working on isomers: C04H07N03 Total data: 49
#   -Storing C04H07N03, no clustering, less than 5 data. DATA: 49
# count: 146
# Working on isomers: C03H05N03O01 Total data: 62
#   -Storing C03H05N03O01, no clustering, less than 5 data. DATA: 62
# count: 147
# Working on isomers: C03H04N02O02 Total data: 45
#   -Storing C03H04N02O02, no clustering, less than 5 data. DATA: 45
# count: 148
# Working on isomers: C04H04O03 Total data: 17
#   -Storing C04H04O03, no clustering, less than 5 data. DATA: 17
# count: 149
# Working on isomers: C03H03N01O03 Total data: 11
#   -Storing C03H03N01O03, no clustering, less than 5 data. DATA: 11
# count: 150
# Working on isomers: C03H02O04 Total data: 2
#   -Storing C03H02O04, no clustering, less than 5 data. DATA: 2
# count: 151
# Working on isomers: C04H04N02O01 Total data: 45
#   -Storing C04H04N02O01, no clustering, less than 5 data. DATA: 45
# count: 152
# Working on isomers: C03H04N04 Total data: 15
#   -Storing C03H04N04, no clustering, less than 5 data. DATA: 15
# count: 153
# Working on isomers: C03H03N03O01 Total data: 23
#   -Storing C03H03N03O01, no clustering, less than 5 data. DATA: 23
# count: 154
# Working on isomers: C05H05N01O01 Total data: 59
#   -Storing C05H05N01O01, no clustering, less than 5 data. DATA: 59
# count: 155
# Working on isomers: C05H04O02 Total data: 22
#   -Storing C05H04O02, no clustering, less than 5 data. DATA: 22
# count: 156
# Working on isomers: C04H03N01O02 Total data: 28
#   -Storing C04H03N01O02, no clustering, less than 5 data. DATA: 28
# count: 157
# Working on isomers: C03H02N02O02 Total data: 15
#   -Storing C03H02N02O02, no clustering, less than 5 data. DATA: 15
# count: 158
# Working on isomers: C07H08 Total data: 28
#   -Storing C07H08, no clustering, less than 5 data. DATA: 28
# count: 159
# Working on isomers: C06H07N01 Total data: 40
#   -Storing C06H07N01, no clustering, less than 5 data. DATA: 40
# count: 160
# Working on isomers: C05H06N02 Total data: 34
#   -Storing C05H06N02, no clustering, less than 5 data. DATA: 34
# count: 161
# Working on isomers: C04H05N03 Total data: 20
#   -Storing C04H05N03, no clustering, less than 5 data. DATA: 20
# count: 162
# Working on isomers: C06H06O01 Total data: 37
#   -Storing C06H06O01, no clustering, less than 5 data. DATA: 37
# count: 163
# Working on isomers: C06H05N01 Total data: 8
#   -Storing C06H05N01, no clustering, less than 5 data. DATA: 8
# count: 164
# Working on isomers: C06H04O01 Total data: 12
#   -Storing C06H04O01, no clustering, less than 5 data. DATA: 12
# count: 165
# Working on isomers: C05H04N02 Total data: 13
#   -Storing C05H04N02, no clustering, less than 5 data. DATA: 13
# count: 166
# Working on isomers: C04H03N03 Total data: 12
#   -Storing C04H03N03, no clustering, less than 5 data. DATA: 12
# count: 167
# Working on isomers: C04H02N02O01 Total data: 16
#   -Storing C04H02N02O01, no clustering, less than 5 data. DATA: 16
# count: 168
# Working on isomers: C07H12 Total data: 68
#   -Storing C07H12, no clustering, less than 5 data. DATA: 68
# count: 169
# Working on isomers: C06H10O01 Total data: 213
#   -Storing C06H10O01, no clustering, less than 5 data. DATA: 213
# count: 170
# Working on isomers: C06H11N01 Total data: 19
#   -Storing C06H11N01, no clustering, less than 5 data. DATA: 19
# count: 171
# Working on isomers: C06H12O01 Total data: 116
#   -Storing C06H12O01, no clustering, less than 5 data. DATA: 116
# count: 172
# Working on isomers: C05H10O02 Total data: 139
#   -Storing C05H10O02, no clustering, less than 5 data. DATA: 139
# count: 173
# Working on isomers: C06H14O01 Total data: 32
#   -Storing C06H14O01, no clustering, less than 5 data. DATA: 32
# count: 174
# Working on isomers: C05H12O02 Total data: 31
#   -Storing C05H12O02, no clustering, less than 5 data. DATA: 31
# count: 175
# Working on isomers: C07H16 Total data: 9
#   -Storing C07H16, no clustering, less than 5 data. DATA: 9
# count: 176
# Working on isomers: C03H07N03O01 Total data: 8
#   -Storing C03H07N03O01, no clustering, less than 5 data. DATA: 8
# count: 177
# Working on isomers: C05H08O02 Total data: 190
#   -Storing C05H08O02, no clustering, less than 5 data. DATA: 190
# count: 178
# Working on isomers: C02H05N03O02 Total data: 1
#   -Storing C02H05N03O02, no clustering, less than 5 data. DATA: 1
# count: 179
# Working on isomers: C04H10N02O01 Total data: 5
#   -Storing C04H10N02O01, no clustering, less than 5 data. DATA: 5
# count: 180
# Working on isomers: C07H14 Total data: 29
#   -Storing C07H14, no clustering, less than 5 data. DATA: 29
# count: 181
# Working on isomers: C04H06O03 Total data: 54
#   -Storing C04H06O03, no clustering, less than 5 data. DATA: 54
# count: 182
# Working on isomers: C04H09N03 Total data: 3
#   -Storing C04H09N03, no clustering, less than 5 data. DATA: 3
# count: 183
# Working on isomers: C05H10N02 Total data: 16
#   -Storing C05H10N02, no clustering, less than 5 data. DATA: 16
# count: 184
# Working on isomers: C04H08O03 Total data: 35
#   -Storing C04H08O03, no clustering, less than 5 data. DATA: 35
# count: 185
# Working on isomers: C04H10O03 Total data: 7
#   -Storing C04H10O03, no clustering, less than 5 data. DATA: 7
# count: 186
# Working on isomers: C03H05N01O03 Total data: 8
#   -Storing C03H05N01O03, no clustering, less than 5 data. DATA: 8
# count: 187
# Working on isomers: C03H08N02O02 Total data: 2
#   -Storing C03H08N02O02, no clustering, less than 5 data. DATA: 2
# count: 188
# Working on isomers: C03H07N01O03 Total data: 4
#   -Storing C03H07N01O03, no clustering, less than 5 data. DATA: 4
# count: 189
# Working on isomers: C07H10 Total data: 56
#   -Storing C07H10, no clustering, less than 5 data. DATA: 56
# count: 190
# Working on isomers: C06H13N01 Total data: 13
#   -Storing C06H13N01, no clustering, less than 5 data. DATA: 13
# count: 191
# Working on isomers: C07H04 Total data: 3
#   -Storing C07H04, no clustering, less than 5 data. DATA: 3
# count: 192
# Working on isomers: C06H03N01 Total data: 4
#   -Storing C06H03N01, no clustering, less than 5 data. DATA: 4
# count: 193
# Working on isomers: C03H06N04 Total data: 23
#   -Storing C03H06N04, no clustering, less than 5 data. DATA: 23
# count: 194
# Working on isomers: C07H06 Total data: 3
#   -Storing C07H06, no clustering, less than 5 data. DATA: 3
# count: 195
# Working on isomers: C05H02N02 Total data: 1
#   -Storing C05H02N02, no clustering, less than 5 data. DATA: 1
# count: 196
# Working on isomers: C03H02N04 Total data: 4
#   -Storing C03H02N04, no clustering, less than 5 data. DATA: 4
# count: 197
# Working on isomers: C03H01N03O01 Total data: 6
#   -Storing C03H01N03O01, no clustering, less than 5 data. DATA: 6
# count: 198
# Working on isomers: C02H05N05 Total data: 10
#   -Storing C02H05N05, no clustering, less than 5 data. DATA: 10
# count: 199
# Working on isomers: C02H04N04O01 Total data: 18
#   -Storing C02H04N04O01, no clustering, less than 5 data. DATA: 18
# count: 200
# Working on isomers: C02H03N03O02 Total data: 13
#   -Storing C02H03N03O02, no clustering, less than 5 data. DATA: 13
# count: 201
# Working on isomers: C02N04O01 Total data: 1
#   -Storing C02N04O01, no clustering, less than 5 data. DATA: 1
# count: 202
# Working on isomers: C02H03N05 Total data: 5
#   -Storing C02H03N05, no clustering, less than 5 data. DATA: 5
# count: 203
# Working on isomers: C02H02N04O01 Total data: 8
#   -Storing C02H02N04O01, no clustering, less than 5 data. DATA: 8
# count: 204
# Working on isomers: C01H02N06 Total data: 1
#   -Storing C01H02N06, no clustering, less than 5 data. DATA: 1
# count: 205
# Working on isomers: C01H01N05O01 Total data: 2
#   -Storing C01H01N05O01, no clustering, less than 5 data. DATA: 2
# count: 206
# Working on isomers: C02H02N02O03 Total data: 3
#   -Storing C02H02N02O03, no clustering, less than 5 data. DATA: 3
# count: 207
# Working on isomers: C02H01N03O02 Total data: 4
#   -Storing C02H01N03O02, no clustering, less than 5 data. DATA: 4
# count: 208
# Working on isomers: C01N04O02 Total data: 1
#   -Storing C01N04O02, no clustering, less than 5 data. DATA: 1
# count: 209
# Working on isomers: C02H01N01O04 Total data: 1
#   -Storing C02H01N01O04, no clustering, less than 5 data. DATA: 1
# count: 210
# Working on isomers: C05H06N02O01 Total data: 484
#   -Storing C05H06N02O01, no clustering, less than 5 data. DATA: 484
# count: 211
# Working on isomers: C05H05N01O02 Total data: 353
#   -Storing C05H05N01O02, no clustering, less than 5 data. DATA: 353
# count: 212
# Working on isomers: C04H05N03O01 Total data: 273
#   -Storing C04H05N03O01, no clustering, less than 5 data. DATA: 273
# count: 213
# Working on isomers: C04H04N02O02 Total data: 193
#   -Storing C04H04N02O02, no clustering, less than 5 data. DATA: 193
# count: 214
# Working on isomers: C03H03N03O02 Total data: 81
#   -Storing C03H03N03O02, no clustering, less than 5 data. DATA: 81
# count: 215
# Working on isomers: C06H13N01O01 Total data: 146
#   -Storing C06H13N01O01, no clustering, less than 5 data. DATA: 146
# count: 216
# Working on isomers: C05H11N01O02 Total data: 179
#   -Storing C05H11N01O02, no clustering, less than 5 data. DATA: 179
# count: 217
# Working on isomers: C05H09N01O02 Total data: 632
#   -Storing C05H09N01O02, no clustering, less than 5 data. DATA: 632
# count: 218
# Working on isomers: C05H10N02O02 Total data: 671
#   -Storing C05H10N02O02, no clustering, less than 5 data. DATA: 671
# count: 219
# Working on isomers: C06H11N01O01 Total data: 647
#   -Storing C06H11N01O01, no clustering, less than 5 data. DATA: 647
# count: 220
# Working on isomers: C06H09N01O01 Total data: 1223
#   -Storing C06H09N01O01, no clustering, less than 5 data. DATA: 1223
# count: 221
# Working on isomers: C06H05N01O01 Total data: 201
#   -Storing C06H05N01O01, no clustering, less than 5 data. DATA: 201
# count: 222
# Working on isomers: C05H04N02O01 Total data: 151
#   -Storing C05H04N02O01, no clustering, less than 5 data. DATA: 151
# count: 223
# Working on isomers: C05H08N02O01 Total data: 634
#   -Storing C05H08N02O01, no clustering, less than 5 data. DATA: 634
# count: 224
# Working on isomers: C04H07N01O03 Total data: 111
#   -Storing C04H07N01O03, no clustering, less than 5 data. DATA: 111
# count: 225
# Working on isomers: C05H07N01O02 Total data: 878
#   -Storing C05H07N01O02, no clustering, less than 5 data. DATA: 878
# count: 226
# Working on isomers: C05H10N02O01 Total data: 178
#   -Storing C05H10N02O01, no clustering, less than 5 data. DATA: 178
# count: 227
# Working on isomers: C04H10N02O02 Total data: 12
#   -Storing C04H10N02O02, no clustering, less than 5 data. DATA: 12
# count: 228
# Working on isomers: C04H09N01O03 Total data: 39
#   -Storing C04H09N01O03, no clustering, less than 5 data. DATA: 39
# count: 229
# Working on isomers: C05H06N02O02 Total data: 1956
#   -Storing C05H06N02O02, no clustering, less than 5 data. DATA: 1956
# count: 230
# Working on isomers: C03H04N04O01 Total data: 103
#   -Storing C03H04N04O01, no clustering, less than 5 data. DATA: 103
# count: 231
# Working on isomers: C03H05N03O02 Total data: 74
#   -Storing C03H05N03O02, no clustering, less than 5 data. DATA: 74
# count: 232
# Working on isomers: C03H07N03O02 Total data: 13
#   -Storing C03H07N03O02, no clustering, less than 5 data. DATA: 13
# count: 233
# Working on isomers: C04H06N02O02 Total data: 312
#   -Storing C04H06N02O02, no clustering, less than 5 data. DATA: 312
# count: 234
# Working on isomers: C05H08N02O02 Total data: 2008
#   -Storing C05H08N02O02, no clustering, less than 5 data. DATA: 2008
# count: 235
# Working on isomers: C04H05N01O03 Total data: 120
#   -Storing C04H05N01O03, no clustering, less than 5 data. DATA: 120
# count: 236
# Working on isomers: C06H07N01O01 Total data: 645
#   -Storing C06H07N01O01, no clustering, less than 5 data. DATA: 645
# count: 237
# Working on isomers: C04H07N03O02 Total data: 423
#   -Storing C04H07N03O02, no clustering, less than 5 data. DATA: 423
# count: 238
# Working on isomers: C04H06N02O03 Total data: 253
#   -Storing C04H06N02O03, no clustering, less than 5 data. DATA: 253
# count: 239
# Working on isomers: C04H07N03O01 Total data: 265
#   -Storing C04H07N03O01, no clustering, less than 5 data. DATA: 265
# count: 240
# Working on isomers: C06F01H05 Total data: 1
#   -Storing C06F01H05, no clustering, less than 5 data. DATA: 1
# count: 241
# Working on isomers: C05F01H04N01 Total data: 3
#   -Storing C05F01H04N01, no clustering, less than 5 data. DATA: 3
# count: 242
# Working on isomers: C04F01H03N02 Total data: 5
#   -Storing C04F01H03N02, no clustering, less than 5 data. DATA: 5
# count: 243
# Working on isomers: C03F01H02N03 Total data: 4
#   -Storing C03F01H02N03, no clustering, less than 5 data. DATA: 4
# count: 244
# Working on isomers: C02F01H01N04 Total data: 2
#   -Storing C02F01H01N04, no clustering, less than 5 data. DATA: 2
# count: 245
# Working on isomers: C04F03H03 Total data: 2
#   -Storing C04F03H03, no clustering, less than 5 data. DATA: 2
# count: 246
# Working on isomers: C03F03H02N01 Total data: 1
#   -Storing C03F03H02N01, no clustering, less than 5 data. DATA: 1
# count: 247
# Working on isomers: C03F03H03O01 Total data: 3
#   -Storing C03F03H03O01, no clustering, less than 5 data. DATA: 3
# count: 248
# Working on isomers: C03F03H05O01 Total data: 3
#   -Storing C03F03H05O01, no clustering, less than 5 data. DATA: 3
# count: 249
# Working on isomers: C04F03H07 Total data: 2
#   -Storing C04F03H07, no clustering, less than 5 data. DATA: 2
# count: 250
# Working on isomers: C03F03H06N01 Total data: 2
#   -Storing C03F03H06N01, no clustering, less than 5 data. DATA: 2
# count: 251
# Working on isomers: C02F03H03N02 Total data: 1
#   -Storing C02F03H03N02, no clustering, less than 5 data. DATA: 1
# count: 252
# Working on isomers: C04F03H05 Total data: 1
#   -Storing C04F03H05, no clustering, less than 5 data. DATA: 1
# count: 253
# Working on isomers: C03F03H04N01 Total data: 1
#   -Storing C03F03H04N01, no clustering, less than 5 data. DATA: 1
# count: 254
# Working on isomers: C04H03N01O03 Total data: 52
#   -Storing C04H03N01O03, no clustering, less than 5 data. DATA: 52
# count: 255
# Working on isomers: C03H02N02O03 Total data: 32
#   -Storing C03H02N02O03, no clustering, less than 5 data. DATA: 32
# count: 256
# Working on isomers: C05H07N03 Total data: 136
#   -Storing C05H07N03, no clustering, less than 5 data. DATA: 136
# count: 257
# Working on isomers: C06H06O02 Total data: 278
#   -Storing C06H06O02, no clustering, less than 5 data. DATA: 278
# count: 258
# Working on isomers: C04H06N04 Total data: 88
#   -Storing C04H06N04, no clustering, less than 5 data. DATA: 88
# count: 259
# Working on isomers: C03H05N05 Total data: 40
#   -Storing C03H05N05, no clustering, less than 5 data. DATA: 40
# count: 260
# Working on isomers: C05H04O03 Total data: 53
#   -Storing C05H04O03, no clustering, less than 5 data. DATA: 53
# count: 261
# Working on isomers: C08H10 Total data: 178
#   -Storing C08H10, no clustering, less than 5 data. DATA: 178
# count: 262
# Working on isomers: C07H09N01 Total data: 252
#   -Storing C07H09N01, no clustering, less than 5 data. DATA: 252
# count: 263
# Working on isomers: C06H08N02 Total data: 225
#   -Storing C06H08N02, no clustering, less than 5 data. DATA: 225
# count: 264
# Working on isomers: C07H08O01 Total data: 377
#   -Storing C07H08O01, no clustering, less than 5 data. DATA: 377
# count: 265
# Working on isomers: C05H06O03 Total data: 256
#   -Storing C05H06O03, no clustering, less than 5 data. DATA: 256
# count: 266
# Working on isomers: C03H06N04O01 Total data: 71
#   -Storing C03H06N04O01, no clustering, less than 5 data. DATA: 71
# count: 267
# Working on isomers: C03H04N02O03 Total data: 29
#   -Storing C03H04N02O03, no clustering, less than 5 data. DATA: 29
# count: 268
# Working on isomers: C03H03N01O04 Total data: 3
#   -Storing C03H03N01O04, no clustering, less than 5 data. DATA: 3
# count: 269
# Working on isomers: C06H10N02 Total data: 223
#   -Storing C06H10N02, no clustering, less than 5 data. DATA: 223
# count: 270
# Working on isomers: C05H09N03 Total data: 140
#   -Storing C05H09N03, no clustering, less than 5 data. DATA: 140
# count: 271
# Working on isomers: C07H11N01 Total data: 282
#   -Storing C07H11N01, no clustering, less than 5 data. DATA: 282
# count: 272
# Working on isomers: C07H10O01 Total data: 933
#   -Storing C07H10O01, no clustering, less than 5 data. DATA: 933
# count: 273
# Working on isomers: C06H08O02 Total data: 915
#   -Storing C06H08O02, no clustering, less than 5 data. DATA: 915
# count: 274
# Working on isomers: C04H03N03O01 Total data: 58
#   -Storing C04H03N03O01, no clustering, less than 5 data. DATA: 58
# count: 275
# Working on isomers: C05H03N01O02 Total data: 37
#   -Storing C05H03N01O02, no clustering, less than 5 data. DATA: 37
# count: 276
# Working on isomers: C04H02N02O02 Total data: 21
#   -Storing C04H02N02O02, no clustering, less than 5 data. DATA: 21
# count: 277
# Working on isomers: C05H02O03 Total data: 3
#   -Storing C05H02O03, no clustering, less than 5 data. DATA: 3
# count: 278
# Working on isomers: C04H01N01O03 Total data: 3
#   -Storing C04H01N01O03, no clustering, less than 5 data. DATA: 3
# count: 279
# Working on isomers: C04H02O04 Total data: 3
#   -Storing C04H02O04, no clustering, less than 5 data. DATA: 3
# count: 280
# Working on isomers: C07H07N01 Total data: 123
#   -Storing C07H07N01, no clustering, less than 5 data. DATA: 123
# count: 281
# Working on isomers: C06H06N02 Total data: 161
#   -Storing C06H06N02, no clustering, less than 5 data. DATA: 161
# count: 282
# Working on isomers: C07H06O01 Total data: 101
#   -Storing C07H06O01, no clustering, less than 5 data. DATA: 101
# count: 283
# Working on isomers: C05H05N03 Total data: 119
#   -Storing C05H05N03, no clustering, less than 5 data. DATA: 119
# count: 284
# Working on isomers: C04H04N04 Total data: 59
#   -Storing C04H04N04, no clustering, less than 5 data. DATA: 59
# count: 285
# Working on isomers: C04H04O04 Total data: 21
#   -Storing C04H04O04, no clustering, less than 5 data. DATA: 21
# count: 286
# Working on isomers: C08H06 Total data: 12
#   -Storing C08H06, no clustering, less than 5 data. DATA: 12
# count: 287
# Working on isomers: C07H05N01 Total data: 21
#   -Storing C07H05N01, no clustering, less than 5 data. DATA: 21
# count: 288
# Working on isomers: C06H04N02 Total data: 20
#   -Storing C06H04N02, no clustering, less than 5 data. DATA: 20
# count: 289
# Working on isomers: C05H03N03 Total data: 12
#   -Storing C05H03N03, no clustering, less than 5 data. DATA: 12
# count: 290
# Working on isomers: C04H02N04 Total data: 7
#   -Storing C04H02N04, no clustering, less than 5 data. DATA: 7
# count: 291
# Working on isomers: C04H08N04 Total data: 60
#   -Storing C04H08N04, no clustering, less than 5 data. DATA: 60
# count: 292
# Working on isomers: C06H04O02 Total data: 25
#   -Storing C06H04O02, no clustering, less than 5 data. DATA: 25
# count: 293
# Working on isomers: C07H14O01 Total data: 334
#   -Storing C07H14O01, no clustering, less than 5 data. DATA: 334
# count: 294
# Working on isomers: C06H12O02 Total data: 490
#   -Storing C06H12O02, no clustering, less than 5 data. DATA: 490
# count: 295
# Working on isomers: C05H12N02O01 Total data: 13
#   -Storing C05H12N02O01, no clustering, less than 5 data. DATA: 13
# count: 296
# Working on isomers: C08H18 Total data: 18
#   -Storing C08H18, no clustering, less than 5 data. DATA: 18
# count: 297
# Working on isomers: C07H16O01 Total data: 72
#   -Storing C07H16O01, no clustering, less than 5 data. DATA: 72
# count: 298
# Working on isomers: C06H14O02 Total data: 93
#   -Storing C06H14O02, no clustering, less than 5 data. DATA: 93
# count: 299
# Working on isomers: C08H16 Total data: 73
#   -Storing C08H16, no clustering, less than 5 data. DATA: 73
# count: 300
# Working on isomers: C08H14 Total data: 221
#   -Storing C08H14, no clustering, less than 5 data. DATA: 221
# count: 301
# Working on isomers: C07H12O01 Total data: 839
#   -Storing C07H12O01, no clustering, less than 5 data. DATA: 839
# count: 302
# Working on isomers: C07H13N01 Total data: 58
#   -Storing C07H13N01, no clustering, less than 5 data. DATA: 58
# count: 303
# Working on isomers: C06H12N02 Total data: 46
#   -Storing C06H12N02, no clustering, less than 5 data. DATA: 46
# count: 304
# Working on isomers: C06H10O02 Total data: 992
#   -Storing C06H10O02, no clustering, less than 5 data. DATA: 992
# count: 305
# Working on isomers: C05H08O03 Total data: 376
#   -Storing C05H08O03, no clustering, less than 5 data. DATA: 376
# count: 306
# Working on isomers: C05H10O03 Total data: 196
#   -Storing C05H10O03, no clustering, less than 5 data. DATA: 196
# count: 307
# Working on isomers: C05H12O03 Total data: 31
#   -Storing C05H12O03, no clustering, less than 5 data. DATA: 31
# count: 308
# Working on isomers: C05H11N03 Total data: 9
#   -Storing C05H11N03, no clustering, less than 5 data. DATA: 9
# count: 309
# Working on isomers: C03H06N02O03 Total data: 7
#   -Storing C03H06N02O03, no clustering, less than 5 data. DATA: 7
# count: 310
# Working on isomers: C08H12 Total data: 284
#   -Storing C08H12, no clustering, less than 5 data. DATA: 284
# count: 311
# Working on isomers: C07H15N01 Total data: 25
#   -Storing C07H15N01, no clustering, less than 5 data. DATA: 25
# count: 312
# Working on isomers: C04H09N03O01 Total data: 27
#   -Storing C04H09N03O01, no clustering, less than 5 data. DATA: 27
# count: 313
# Working on isomers: C07H04O01 Total data: 3
#   -Storing C07H04O01, no clustering, less than 5 data. DATA: 3
# count: 314
# Working on isomers: C06H03N01O01 Total data: 4
#   -Storing C06H03N01O01, no clustering, less than 5 data. DATA: 4
# count: 315
# Working on isomers: C05H02N02O01 Total data: 2
#   -Storing C05H02N02O01, no clustering, less than 5 data. DATA: 2
# count: 316
# Working on isomers: C04H06O04 Total data: 28
#   -Storing C04H06O04, no clustering, less than 5 data. DATA: 28
# count: 317
# Working on isomers: C04H10N04 Total data: 1
#   -Storing C04H10N04, no clustering, less than 5 data. DATA: 1
# count: 318
# Working on isomers: C04H08O04 Total data: 9
#   -Storing C04H08O04, no clustering, less than 5 data. DATA: 9
# count: 319
# Working on isomers: C04H10O04 Total data: 2
#   -Storing C04H10O04, no clustering, less than 5 data. DATA: 2
# count: 320
# Working on isomers: C06H02O02 Total data: 4
#   -Storing C06H02O02, no clustering, less than 5 data. DATA: 4
# count: 321
# Working on isomers: C05H01N01O02 Total data: 3
#   -Storing C05H01N01O02, no clustering, less than 5 data. DATA: 3
# count: 322
# Working on isomers: C04N02O02 Total data: 1
#   -Storing C04N02O02, no clustering, less than 5 data. DATA: 1
# count: 323
# Working on isomers: C07H02O01 Total data: 2
#   -Storing C07H02O01, no clustering, less than 5 data. DATA: 2
# count: 324
# Working on isomers: C06H01N01O01 Total data: 3
#   -Storing C06H01N01O01, no clustering, less than 5 data. DATA: 3
# count: 325
# Working on isomers: C05N02O01 Total data: 1
#   -Storing C05N02O01, no clustering, less than 5 data. DATA: 1
# count: 326
# Working on isomers: C08H08 Total data: 46
#   -Storing C08H08, no clustering, less than 5 data. DATA: 46
# count: 327
# Working on isomers: C08H02 Total data: 1
#   -Storing C08H02, no clustering, less than 5 data. DATA: 1
# count: 328
# Working on isomers: C07H01N01 Total data: 1
#   -Storing C07H01N01, no clustering, less than 5 data. DATA: 1
# count: 329
# Working on isomers: C06N02 Total data: 1
#   -Storing C06N02, no clustering, less than 5 data. DATA: 1
# count: 330
# Working on isomers: C03H03N05 Total data: 22
#   -Storing C03H03N05, no clustering, less than 5 data. DATA: 22
# count: 331
# Working on isomers: C02H03N05O01 Total data: 23
#   -Storing C02H03N05O01, no clustering, less than 5 data. DATA: 23
# count: 332
# Working on isomers: C03H07N05 Total data: 21
#   -Storing C03H07N05, no clustering, less than 5 data. DATA: 21
# count: 333
# Working on isomers: C02H04N06 Total data: 10
#   -Storing C02H04N06, no clustering, less than 5 data. DATA: 10
# count: 334
# Working on isomers: C03H01N05 Total data: 2
#   -Storing C03H01N05, no clustering, less than 5 data. DATA: 2
# count: 335
# Working on isomers: C03H02N04O01 Total data: 24
#   -Storing C03H02N04O01, no clustering, less than 5 data. DATA: 24
# count: 336
# Working on isomers: C02H02N06 Total data: 6
#   -Storing C02H02N06, no clustering, less than 5 data. DATA: 6
# count: 337
# Working on isomers: C02H02N04O02 Total data: 21
#   -Storing C02H02N04O02, no clustering, less than 5 data. DATA: 21
# count: 338
# Working on isomers: C02H01N03O03 Total data: 11
#   -Storing C02H01N03O03, no clustering, less than 5 data. DATA: 11
# count: 339
# Working on isomers: C03H01N03O02 Total data: 9
#   -Storing C03H01N03O02, no clustering, less than 5 data. DATA: 9
# count: 340
# Working on isomers: C01H03N07 Total data: 1
#   -Storing C01H03N07, no clustering, less than 5 data. DATA: 1
# count: 341
# Working on isomers: C01H02N06O01 Total data: 1
#   -Storing C01H02N06O01, no clustering, less than 5 data. DATA: 1
# count: 342
# Working on isomers: C02H01N05O01 Total data: 4
#   -Storing C02H01N05O01, no clustering, less than 5 data. DATA: 4
# count: 343
# Working on isomers: C02N04O02 Total data: 3
#   -Storing C02N04O02, no clustering, less than 5 data. DATA: 3
# count: 344
# Working on isomers: C01N06O01 Total data: 1
#   -Storing C01N06O01, no clustering, less than 5 data. DATA: 1
# count: 345
# Working on isomers: C03H01N01O04 Total data: 2
#   -Storing C03H01N01O04, no clustering, less than 5 data. DATA: 2
# count: 346
# Working on isomers: C03N02O03 Total data: 1
#   -Storing C03N02O03, no clustering, less than 5 data. DATA: 1
# count: 347
# Working on isomers: C02N02O04 Total data: 1
#   -Storing C02N02O04, no clustering, less than 5 data. DATA: 1
# count: 348
# Working on isomers: C02H05N05O01 Total data: 1
#   -Storing C02H05N05O01, no clustering, less than 5 data. DATA: 1
# count: 349
# Working on isomers: C01N04O03 Total data: 1
#   -Storing C01N04O03, no clustering, less than 5 data. DATA: 1
# count: 350
# Working on isomers: C06H08N02O01 Total data: 3593
#   -Storing C06H08N02O01, no clustering, less than 5 data. DATA: 3593
# count: 351
# Working on isomers: C06H07N01O02 Total data: 3929
#   -Storing C06H07N01O02, no clustering, less than 5 data. DATA: 3929
# count: 352
# Working on isomers: C05H07N03O01 Total data: 1784
#   -Storing C05H07N03O01, no clustering, less than 5 data. DATA: 1784
# count: 353
# Working on isomers: C05H05N01O03 Total data: 813
#   -Storing C05H05N01O03, no clustering, less than 5 data. DATA: 813
# count: 354
# Working on isomers: C07H07N01O01 Total data: 2127
#   -Storing C07H07N01O01, no clustering, less than 5 data. DATA: 2127
# count: 355
# Working on isomers: C06H06N02O01 Total data: 1769
#   -Storing C06H06N02O01, no clustering, less than 5 data. DATA: 1769
# count: 356
# Working on isomers: C05H05N03O01 Total data: 844
#   -Storing C05H05N03O01, no clustering, less than 5 data. DATA: 844
# count: 357
# Working on isomers: C04H06N04O01 Total data: 716
#   -Storing C04H06N04O01, no clustering, less than 5 data. DATA: 716
# count: 358
# Working on isomers: C04H05N03O02 Total data: 755
#   -Storing C04H05N03O02, no clustering, less than 5 data. DATA: 755
# count: 359
# Working on isomers: C03H05N05O01 Total data: 184
#   -Storing C03H05N05O01, no clustering, less than 5 data. DATA: 184
# count: 360
# Working on isomers: C03H04N04O02 Total data: 190
#   -Storing C03H04N04O02, no clustering, less than 5 data. DATA: 190
# count: 361
# Working on isomers: C05F01H05N02O01 Total data: 222
#   -Storing C05F01H05N02O01, no clustering, less than 5 data. DATA: 222
# count: 362
# Working on isomers: C05F01H04N01O02 Total data: 85
#   -Storing C05F01H04N01O02, no clustering, less than 5 data. DATA: 85
# count: 363
# Working on isomers: C04F01H04N03O01 Total data: 161
#   -Storing C04F01H04N03O01, no clustering, less than 5 data. DATA: 161
# count: 364
# Working on isomers: C07H15N01O01 Total data: 392
#   -Storing C07H15N01O01, no clustering, less than 5 data. DATA: 392
# count: 365
# Working on isomers: C06H13N01O02 Total data: 616
#   -Storing C06H13N01O02, no clustering, less than 5 data. DATA: 616
# count: 366
# Working on isomers: C07H11N01O01 Total data: 5859
#   -Storing C07H11N01O01, no clustering, less than 5 data. DATA: 5859
# count: 367
# Working on isomers: C06H09N01O02 Total data: 5794
#   -Storing C06H09N01O02, no clustering, less than 5 data. DATA: 5794
# count: 368
# Working on isomers: C06H10N02O01 Total data: 2782
#   -Storing C06H10N02O01, no clustering, less than 5 data. DATA: 2782
# count: 369
# Working on isomers: C06H11N01O02 Total data: 2951
#   -Storing C06H11N01O02, no clustering, less than 5 data. DATA: 2951
# count: 370
# Working on isomers: C05H11N01O03 Total data: 235
#   -Storing C05H11N01O03, no clustering, less than 5 data. DATA: 235
# count: 371
# Working on isomers: C04H09N03O02 Total data: 87
#   -Storing C04H09N03O02, no clustering, less than 5 data. DATA: 87
# count: 372
# Working on isomers: C05H09N01O03 Total data: 921
#   -Storing C05H09N01O03, no clustering, less than 5 data. DATA: 921
# count: 373
# Working on isomers: C04H08N02O03 Total data: 95
#   -Storing C04H08N02O03, no clustering, less than 5 data. DATA: 95
# count: 374
# Working on isomers: C07H13N01O01 Total data: 2215
#   -Storing C07H13N01O01, no clustering, less than 5 data. DATA: 2215
# count: 375
# Working on isomers: C06H12N02O01 Total data: 598
#   -Storing C06H12N02O01, no clustering, less than 5 data. DATA: 598
# count: 376
# Working on isomers: C05H07N01O03 Total data: 1374
#   -Storing C05H07N01O03, no clustering, less than 5 data. DATA: 1374
# count: 377
# Working on isomers: C05H12N02O02 Total data: 51
#   -Storing C05H12N02O02, no clustering, less than 5 data. DATA: 51
# count: 378
# Working on isomers: C07H09N01O01 Total data: 5231
#   -Storing C07H09N01O01, no clustering, less than 5 data. DATA: 5231
# count: 379
# Working on isomers: C05H09N03O01 Total data: 1019
#   -Storing C05H09N03O01, no clustering, less than 5 data. DATA: 1019
# count: 380
# Working on isomers: C03H06N04O02 Total data: 17
#   -Storing C03H06N04O02, no clustering, less than 5 data. DATA: 17
# count: 381
# Working on isomers: C07H03N01O01 Total data: 46
#   -Storing C07H03N01O01, no clustering, less than 5 data. DATA: 46
# count: 382
# Working on isomers: C06H03N01O02 Total data: 123
#   -Storing C06H03N01O02, no clustering, less than 5 data. DATA: 123
# count: 383
# Working on isomers: C06H05N01O02 Total data: 916
#   -Storing C06H05N01O02, no clustering, less than 5 data. DATA: 916
# count: 384
# Working on isomers: C04H07N01O04 Total data: 28
#   -Storing C04H07N01O04, no clustering, less than 5 data. DATA: 28
# count: 385
# Working on isomers: C04H05N01O04 Total data: 64
#   -Storing C04H05N01O04, no clustering, less than 5 data. DATA: 64
# count: 386
# Working on isomers: C05H04N02O02 Total data: 509
#   -Storing C05H04N02O02, no clustering, less than 5 data. DATA: 509
# count: 387
# Working on isomers: C05H11N03O01 Total data: 89
#   -Storing C05H11N03O01, no clustering, less than 5 data. DATA: 89
# count: 388
# Working on isomers: C04H08N04O01 Total data: 263
#   -Storing C04H08N04O01, no clustering, less than 5 data. DATA: 263
# count: 389
# Working on isomers: C04F03H06N01O01 Total data: 26
#   -Storing C04F03H06N01O01, no clustering, less than 5 data. DATA: 26
# count: 390
# Working on isomers: C05F01H04N01O01 Total data: 22
#   -Storing C05F01H04N01O01, no clustering, less than 5 data. DATA: 22
# count: 391
# Working on isomers: C04F01H04N03 Total data: 33
#   -Storing C04F01H04N03, no clustering, less than 5 data. DATA: 33
# count: 392
# Working on isomers: C04F01H03N02O01 Total data: 40
#   -Storing C04F01H03N02O01, no clustering, less than 5 data. DATA: 40
# count: 393
# Working on isomers: C05F01H03O02 Total data: 6
#   -Storing C05F01H03O02, no clustering, less than 5 data. DATA: 6
# count: 394
# Working on isomers: C04F01H02N01O02 Total data: 18
# ...
# count: 492
# Working on isomers: C08H03N01 Total data: 6
#   -Storing C08H03N01, no clustering, less than 5 data. DATA: 6
# count: 493
# Working on isomers: C07H02N02 Total data: 3
#   -Storing C07H02N02, no clustering, less than 5 data. DATA: 3
# count: 494
# Working on isomers: C06H01N03 Total data: 1
#   -Storing C06H01N03, no clustering, less than 5 data. DATA: 1
# count: 495
# Working on isomers: C05N04 Total data: 1
#   -Storing C05N04, no clustering, less than 5 data. DATA: 1
# count: 496
# Working on isomers: C09H14 Total data: 1238
#   -Storing C09H14, no clustering, less than 5 data. DATA: 1238
# count: 497
# Working on isomers: C09H16 Total data: 695
#   -Storing C09H16, no clustering, less than 5 data. DATA: 695
# count: 498
# Working on isomers: C08H14O01 Total data: 3154
#   -Storing C08H14O01, no clustering, less than 5 data. DATA: 3154
# count: 499
# Working on isomers: C07H12O02 Total data: 4612
#   -Storing C07H12O02, no clustering, less than 5 data. DATA: 4612
# count: 500
# Working on isomers: C08H15N01 Total data: 176
#   -Storing C08H15N01, no clustering, less than 5 data. DATA: 176
# count: 501
# Working on isomers: C06H10O03 Total data: 2355
#   -Storing C06H10O03, no clustering, less than 5 data. DATA: 2355
# count: 502
# Working on isomers: C07H14N02 Total data: 108
#   -Storing C07H14N02, no clustering, less than 5 data. DATA: 108
# count: 503
# Working on isomers: C09H18 Total data: 185
#   -Storing C09H18, no clustering, less than 5 data. DATA: 185
# count: 504
# Working on isomers: C08H16O01 Total data: 966
#   -Storing C08H16O01, no clustering, less than 5 data. DATA: 966
# count: 505
# Working on isomers: C07H14O02 Total data: 1672
#   -Storing C07H14O02, no clustering, less than 5 data. DATA: 1672
# count: 506
# Working on isomers: C06H12O03 Total data: 941
#   -Storing C06H12O03, no clustering, less than 5 data. DATA: 941
# count: 507
# Working on isomers: C04H04O05 Total data: 3
#   -Storing C04H04O05, no clustering, less than 5 data. DATA: 3
# count: 508
# Working on isomers: C05H08O04 Total data: 322
#   -Storing C05H08O04, no clustering, less than 5 data. DATA: 322
# count: 509
# Working on isomers: C03H07N05O01 Total data: 14
#   -Storing C03H07N05O01, no clustering, less than 5 data. DATA: 14
# count: 510
# Working on isomers: C03H05N03O03 Total data: 8
#   -Storing C03H05N03O03, no clustering, less than 5 data. DATA: 8
# count: 511
# Working on isomers: C06H14N02O01 Total data: 27
#   -Storing C06H14N02O01, no clustering, less than 5 data. DATA: 27
# count: 512
# Working on isomers: C09H20 Total data: 35
#   -Storing C09H20, no clustering, less than 5 data. DATA: 35
# count: 513
# Working on isomers: C08H18O01 Total data: 171
#   -Storing C08H18O01, no clustering, less than 5 data. DATA: 171
# count: 514
# Working on isomers: C07H16O02 Total data: 262
#   -Storing C07H16O02, no clustering, less than 5 data. DATA: 262
# count: 515
# Working on isomers: C08H17N01 Total data: 41
#   -Storing C08H17N01, no clustering, less than 5 data. DATA: 41
# count: 516
# Working on isomers: C06H13N03 Total data: 22
#   -Storing C06H13N03, no clustering, less than 5 data. DATA: 22
# count: 517
# Working on isomers: C06H14O03 Total data: 129
#   -Storing C06H14O03, no clustering, less than 5 data. DATA: 129
# count: 518
# Working on isomers: C05H10O04 Total data: 107
#   -Storing C05H10O04, no clustering, less than 5 data. DATA: 107
# count: 519
# Working on isomers: C04H10N04O01 Total data: 2
#   -Storing C04H10N04O01, no clustering, less than 5 data. DATA: 2
# count: 520
# Working on isomers: C05H12N04 Total data: 3
#   -Storing C05H12N04, no clustering, less than 5 data. DATA: 3
# count: 521
# Working on isomers: C04H09N01O04 Total data: 9
#   -Storing C04H09N01O04, no clustering, less than 5 data. DATA: 9
# count: 522
# Working on isomers: C04H10N02O03 Total data: 5
#   -Storing C04H10N02O03, no clustering, less than 5 data. DATA: 5
# count: 523
# Working on isomers: C05H12O04 Total data: 14
#   -Storing C05H12O04, no clustering, less than 5 data. DATA: 14
# count: 524
# Working on isomers: C03H06N06 Total data: 54
#   -Storing C03H06N06, no clustering, less than 5 data. DATA: 54
# count: 525
# Working on isomers: C03H02N06 Total data: 4
#   -Storing C03H02N06, no clustering, less than 5 data. DATA: 4
# count: 526
# Working on isomers: C03H04N06 Total data: 44
#   -Storing C03H04N06, no clustering, less than 5 data. DATA: 44
# count: 527
# Working on isomers: C04H09N05 Total data: 51
#   -Storing C04H09N05, no clustering, less than 5 data. DATA: 51
# count: 528
# Working on isomers: C03H03N05O01 Total data: 69
#   -Storing C03H03N05O01, no clustering, less than 5 data. DATA: 69
# count: 529
# Working on isomers: C02H03N07 Total data: 6
#   -Storing C02H03N07, no clustering, less than 5 data. DATA: 6
# count: 530
# Working on isomers: C02H05N07 Total data: 4
#   -Storing C02H05N07, no clustering, less than 5 data. DATA: 4
# count: 531
# Working on isomers: C02H04N06O01 Total data: 11
#   -Storing C02H04N06O01, no clustering, less than 5 data. DATA: 11
# count: 532
# Working on isomers: C02H03N05O02 Total data: 12
#   -Storing C02H03N05O02, no clustering, less than 5 data. DATA: 12
# count: 533
# Working on isomers: C04H01N05 Total data: 2
#   -Storing C04H01N05, no clustering, less than 5 data. DATA: 2
# count: 534
# Working on isomers: C04N04O01 Total data: 5
#   -Storing C04N04O01, no clustering, less than 5 data. DATA: 5
# count: 535
# Working on isomers: C03H02N04O02 Total data: 51
#   -Storing C03H02N04O02, no clustering, less than 5 data. DATA: 51
# count: 536
# Working on isomers: C02H02N06O01 Total data: 9
#   -Storing C02H02N06O01, no clustering, less than 5 data. DATA: 9
# count: 537
# Working on isomers: C03H01N05O01 Total data: 9
#   -Storing C03H01N05O01, no clustering, less than 5 data. DATA: 9
# count: 538
# Working on isomers: C02H01N05O02 Total data: 7
#   -Storing C02H01N05O02, no clustering, less than 5 data. DATA: 7
# count: 539
# Working on isomers: C03H01N03O03 Total data: 12
#   -Storing C03H01N03O03, no clustering, less than 5 data. DATA: 12
# count: 540
# Working on isomers: C02H02N04O03 Total data: 8
#   -Storing C02H02N04O03, no clustering, less than 5 data. DATA: 8
# count: 541
# Working on isomers: C03H08N06 Total data: 1
#   -Storing C03H08N06, no clustering, less than 5 data. DATA: 1
# count: 542
# Working on isomers: C03N04O02 Total data: 4
#   -Storing C03N04O02, no clustering, less than 5 data. DATA: 4
# count: 543
# Working on isomers: C02N06O01 Total data: 1
#   -Storing C02N06O01, no clustering, less than 5 data. DATA: 1
# count: 544
# Working on isomers: C02N04O03 Total data: 1
#   -Storing C02N04O03, no clustering, less than 5 data. DATA: 1
# count: 545
# Working on isomers: C03N02O04 Total data: 1
#   -Storing C03N02O04, no clustering, less than 5 data. DATA: 1
# count: 546
# Working on isomers: C03H01N01O05 Total data: 3
#   -Storing C03H01N01O05, no clustering, less than 5 data. DATA: 3
# count: 547
# Working on isomers: C02H01N03O04 Total data: 2
#   -Storing C02H01N03O04, no clustering, less than 5 data. DATA: 2
# count: 548
# Working on isomers: C02N02O05 Total data: 1
#   -Storing C02N02O05, no clustering, less than 5 data. DATA: 1
# count: 549
# Working on isomers: C06F01H07N02 Total data: 78
#   -Storing C06F01H07N02, no clustering, less than 5 data. DATA: 78
# count: 550
# Working on isomers: C06F01H06N01O01 Total data: 108
#   -Storing C06F01H06N01O01, no clustering, less than 5 data. DATA: 108
# count: 551
# Working on isomers: C05F01H06N03 Total data: 128
#   -Storing C05F01H06N03, no clustering, less than 5 data. DATA: 128
# count: 552
# Working on isomers: C06F01H05O02 Total data: 24
#   -Storing C06F01H05O02, no clustering, less than 5 data. DATA: 24
# count: 553
# Working on isomers: C04F01H05N04 Total data: 84
#   -Storing C04F01H05N04, no clustering, less than 5 data. DATA: 84
# count: 554
# Working on isomers: C04F01H03N02O02 Total data: 85
#   -Storing C04F01H03N02O02, no clustering, less than 5 data. DATA: 85
# count: 555
# Working on isomers: C05F02H04N02 Total data: 37
#   -Storing C05F02H04N02, no clustering, less than 5 data. DATA: 37
# count: 556
# Working on isomers: C05F02H03N01O01 Total data: 26
#   -Storing C05F02H03N01O01, no clustering, less than 5 data. DATA: 26
# count: 557
# Working on isomers: C04F02H02N02O01 Total data: 29
#   -Storing C04F02H02N02O01, no clustering, less than 5 data. DATA: 29
# count: 558
# Working on isomers: C05F02H02O02 Total data: 10
#   -Storing C05F02H02O02, no clustering, less than 5 data. DATA: 10
# count: 559
# Working on isomers: C04F01H02N01O03 Total data: 21
#   -Storing C04F01H02N01O03, no clustering, less than 5 data. DATA: 21
# count: 560
# Working on isomers: C04F02H01N01O02 Total data: 18
#   -Storing C04F02H01N01O02, no clustering, less than 5 data. DATA: 18
# count: 561
# Working on isomers: C04F02H03N03 Total data: 29
#   -Storing C04F02H03N03, no clustering, less than 5 data. DATA: 29
# count: 562
# Working on isomers: C05F01H03O03 Total data: 4
#   -Storing C05F01H03O03, no clustering, less than 5 data. DATA: 4
# count: 563
# Working on isomers: C03F01H04N05 Total data: 21
#   -Storing C03F01H04N05, no clustering, less than 5 data. DATA: 21
# count: 564
# Working on isomers: C03F01H03N04O01 Total data: 37
#   -Storing C03F01H03N04O01, no clustering, less than 5 data. DATA: 37
# count: 565
# Working on isomers: C03F01H02N03O02 Total data: 27
#   -Storing C03F01H02N03O02, no clustering, less than 5 data. DATA: 27
# count: 566
# Working on isomers: C03F02H01N03O01 Total data: 9
#   -Storing C03F02H01N03O01, no clustering, less than 5 data. DATA: 9
# count: 567
# Working on isomers: C03F01H01N02O03 Total data: 11
#   -Storing C03F01H01N02O03, no clustering, less than 5 data. DATA: 11
# count: 568
# Working on isomers: C03F02N02O02 Total data: 8
#   -Storing C03F02N02O02, no clustering, less than 5 data. DATA: 8
# count: 569
# Working on isomers: C08F01H05 Total data: 3
#   -Storing C08F01H05, no clustering, less than 5 data. DATA: 3
# count: 570
# Working on isomers: C07F01H04N01 Total data: 13
#   -Storing C07F01H04N01, no clustering, less than 5 data. DATA: 13
# count: 571
# Working on isomers: C06F01H03N02 Total data: 21
#   -Storing C06F01H03N02, no clustering, less than 5 data. DATA: 21
# count: 572
# Working on isomers: C05F01H02N03 Total data: 14
#   -Storing C05F01H02N03, no clustering, less than 5 data. DATA: 14
# count: 573
# Working on isomers: C04F01H01N04 Total data: 3
#   -Storing C04F01H01N04, no clustering, less than 5 data. DATA: 3
# count: 574
# Working on isomers: C03F02H02N04 Total data: 3
#   -Storing C03F02H02N04, no clustering, less than 5 data. DATA: 3
# count: 575
# Working on isomers: C08F01H09 Total data: 9
#   -Storing C08F01H09, no clustering, less than 5 data. DATA: 9
# count: 576
# Working on isomers: C07F01H08N01 Total data: 39
#   -Storing C07F01H08N01, no clustering, less than 5 data. DATA: 39
# count: 577
# Working on isomers: C07F01H07O01 Total data: 16
#   -Storing C07F01H07O01, no clustering, less than 5 data. DATA: 16
# count: 578
# Working on isomers: C07F02H06 Total data: 6
#   -Storing C07F02H06, no clustering, less than 5 data. DATA: 6
# count: 579
# Working on isomers: C06F02H05N01 Total data: 22
#   -Storing C06F02H05N01, no clustering, less than 5 data. DATA: 22
# count: 580
# Working on isomers: C06F02H04O01 Total data: 6
#   -Storing C06F02H04O01, no clustering, less than 5 data. DATA: 6
# count: 581
# Working on isomers: C06F03H03 Total data: 7
#   -Storing C06F03H03, no clustering, less than 5 data. DATA: 7
# count: 582
# Working on isomers: C05F03H02N01 Total data: 9
#   -Storing C05F03H02N01, no clustering, less than 5 data. DATA: 9
# count: 583
# Working on isomers: C04F03H01N02 Total data: 4
#   -Storing C04F03H01N02, no clustering, less than 5 data. DATA: 4
# count: 584
# Working on isomers: C03F03N03 Total data: 1
#   -Storing C03F03N03, no clustering, less than 5 data. DATA: 1
# count: 585
# Working on isomers: C07F01H05O01 Total data: 3
#   -Storing C07F01H05O01, no clustering, less than 5 data. DATA: 3
# count: 586
# Working on isomers: C06F01H04N01O01 Total data: 10
#   -Storing C06F01H04N01O01, no clustering, less than 5 data. DATA: 10
# count: 587
# Working on isomers: C05F01H03N02O01 Total data: 11
#   -Storing C05F01H03N02O01, no clustering, less than 5 data. DATA: 11
# count: 588
# Working on isomers: C04F01H02N03O01 Total data: 3
#   -Storing C04F01H02N03O01, no clustering, less than 5 data. DATA: 3
# count: 589
# Working on isomers: C04F01H01O04 Total data: 1
#   -Storing C04F01H01O04, no clustering, less than 5 data. DATA: 1
# count: 590
# Working on isomers: C03F01N01O04 Total data: 1
#   -Storing C03F01N01O04, no clustering, less than 5 data. DATA: 1
# count: 591
# Working on isomers: C05F03H04N01 Total data: 7
#   -Storing C05F03H04N01, no clustering, less than 5 data. DATA: 7
# count: 592
# Working on isomers: C05F03H03O01 Total data: 12
#   -Storing C05F03H03O01, no clustering, less than 5 data. DATA: 12
# count: 593
# Working on isomers: C04F03H03N02 Total data: 8
#   -Storing C04F03H03N02, no clustering, less than 5 data. DATA: 8
# count: 594
# Working on isomers: C04F03H02N01O01 Total data: 10
#   -Storing C04F03H02N01O01, no clustering, less than 5 data. DATA: 10
# count: 595
# Working on isomers: C03F03H01N02O01 Total data: 5
#   -Storing C03F03H01N02O01, no clustering, less than 5 data. DATA: 5
# count: 596
# Working on isomers: C03F03H02N03 Total data: 3
#   -Storing C03F03H02N03, no clustering, less than 5 data. DATA: 3
# count: 597
# Working on isomers: C02F03N03O01 Total data: 1
#   -Storing C02F03N03O01, no clustering, less than 5 data. DATA: 1
# count: 598
# Working on isomers: C06F03H07 Total data: 18
#   -Storing C06F03H07, no clustering, less than 5 data. DATA: 18
# count: 599
# Working on isomers: C05F03H06N01 Total data: 21
#   -Storing C05F03H06N01, no clustering, less than 5 data. DATA: 21
# count: 600
# Working on isomers: C05F03H05O01 Total data: 26
#   -Storing C05F03H05O01, no clustering, less than 5 data. DATA: 26
# count: 601
# Working on isomers: C04F03H03O02 Total data: 8
#   -Storing C04F03H03O02, no clustering, less than 5 data. DATA: 8
# count: 602
# Working on isomers: C03F03H03N02O01 Total data: 3
#   -Storing C03F03H03N02O01, no clustering, less than 5 data. DATA: 3
# count: 603
# Working on isomers: C05F03H07O01 Total data: 42
#   -Storing C05F03H07O01, no clustering, less than 5 data. DATA: 42
# count: 604
# Working on isomers: C04F03H05O02 Total data: 23
#   -Storing C04F03H05O02, no clustering, less than 5 data. DATA: 23
# count: 605
# Working on isomers: C03F03H05N02O01 Total data: 2
#   -Storing C03F03H05N02O01, no clustering, less than 5 data. DATA: 2
# count: 606
# Working on isomers: C03F03H04N01O02 Total data: 2
#   -Storing C03F03H04N01O02, no clustering, less than 5 data. DATA: 2
# count: 607
# Working on isomers: C06F03H05 Total data: 3
#   -Storing C06F03H05, no clustering, less than 5 data. DATA: 3
# count: 608
# Working on isomers: C04F03H05N02 Total data: 9
#   -Storing C04F03H05N02, no clustering, less than 5 data. DATA: 9
# count: 609
# Working on isomers: C04F03H04N01O01 Total data: 18
#   -Storing C04F03H04N01O01, no clustering, less than 5 data. DATA: 18
# count: 610
# Working on isomers: C03F03H04N03 Total data: 1
#   -Storing C03F03H04N03, no clustering, less than 5 data. DATA: 1
# count: 611
# Working on isomers: C03F03H02N01O02 Total data: 2
#   -Storing C03F03H02N01O02, no clustering, less than 5 data. DATA: 2
# count: 612
# Working on isomers: C06F03H09 Total data: 14
#   -Storing C06F03H09, no clustering, less than 5 data. DATA: 14
# count: 613
# Working on isomers: C05F03H08N01 Total data: 26
#   -Storing C05F03H08N01, no clustering, less than 5 data. DATA: 26
# count: 614
# Working on isomers: C06F03H11 Total data: 8
#   -Storing C06F03H11, no clustering, less than 5 data. DATA: 8
# count: 615
# Working on isomers: C03F06H02 Total data: 1
#   -Storing C03F06H02, no clustering, less than 5 data. DATA: 1
# count: 616
# Working on isomers: C05F03H09O01 Total data: 21
#   -Storing C05F03H09O01, no clustering, less than 5 data. DATA: 21
# count: 617
# Working on isomers: C04F03H07N02 Total data: 5
#   -Storing C04F03H07N02, no clustering, less than 5 data. DATA: 5
# count: 618
# Working on isomers: C05F03H10N01 Total data: 10
#   -Storing C05F03H10N01, no clustering, less than 5 data. DATA: 10
# count: 619
# Working on isomers: C04F03H08N01O01 Total data: 6
#   -Storing C04F03H08N01O01, no clustering, less than 5 data. DATA: 6
# count: 620
# Working on isomers: C04F03H07O02 Total data: 8
#   -Storing C04F03H07O02, no clustering, less than 5 data. DATA: 8
# 0 133885

# %%
plt.hist(iso_len,bins=100)
plt.yscale('log', nonposy='clip')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-56b2c881a125> in <module>()
# ----> 1 plt.hist(iso_len,bins=100)
#       2 plt.yscale('log', nonposy='clip')
#       3 plt.show()
#
# NameError: name 'iso_len' is not defined

# %%
cluster_count
# Out:
# 0

# %%
adl = pyt.anidataloader(h5out)
data_count = 0
true_cluster_count = 0
for data in adl:
    data_count += data['energies'].size
    true_cluster_count += data['cluster_mask'].max()+1

# %%
print(true_cluster_count,data_count)
# Out:
# 621 133885

# %%
files = [f for f in os.listdir(h5dir) if '.h5' in f]
total_data=0
for i,f in enumerate(files): 
    print ('Working on file:',i,f)
    adl = pyt.anidataloader(h5dir+f)
    for data in adl:
        total_data += data['energies'].size
# Out:
# Working on file: 0 qm9_data.h5

# %%
total_data
# Out:
# 133885
