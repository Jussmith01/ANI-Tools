# %%
import xml.etree.ElementTree as ET

# %%
file = '/nh/nest/u/jsmith/Research/confs_test/DrugBank/fulldatabase.xml'

# %%
tree = ET.parse(file)
root = tree.getroot()

# %%
for child in root:
    print(child.tag, child.attrib['type'])
# Out:
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug small molecule
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug small molecule
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# {http://www.drugbank.ca}drug biotech
# ...

# %%
for neighbor in root.iter('neighbor'):
.     print(neighbor.attrib)
