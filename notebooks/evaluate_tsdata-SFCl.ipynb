# %%
import aniensemblestats as aes
import hdnntools as hdt
import pandas as pd
import os

import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib.colors import ListedColormap

import numpy as np


import seaborn as sns
pd.options.display.float_format = '{:.2f}'.format

# %%
errdir = '/home/jujuman/Scratch/Research/ANI-2x_models/error_stats/'

efiles = [errdir+f for f in os.listdir(errdir)]
tsname = [
#            'TriPep    (S)',
#            'TriPep (CHNO)',
#            'DrugBk (SFCl)',
#            'DrugBk (CHNO)',
#            'GDB-07to09 (SFCl)',
#            'GDB-10to11 (SFCl)',
#            'GDB07to09 (CHNO)',
#            'GDB10to13 (CHNO)',
#            'MDBenchmark',
#            's66x8',
          #'r10_ccsd',
#           'GDB-10to13',
         'DrugBank',
         'Tripeptide',
         'GDB07to09',
         'MDBenchmark',
         'GDB10to13',
         's66x8',
         ]

'''
efiles = [errdir+f for f in os.listdir(errdir)]
tsname = ['DrugBk (SFCl)',
          'DrugBk (CHNO)',
          'GDB-07 (SFCl)',
          'GDB-08 (SFCl)',
          'GDB-09 (SFCl)',
          'GDB-10 (SFCl)',
          'GDB-11 (SFCl)',
          'GDB-07 (CHNO)',
          'GDB-08 (CHNO)',
          'GDB-09 (CHNO)',
          'GDB-10 (CHNO)',
          'GDB-11 (CHNO)',
         ]
'''

for i in efiles:
    print(i)
# Out:
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt6.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt5.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt7-2.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt4.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt3.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt7.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt2.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_v62518.h5
# /home/jujuman/Scratch/Research/ANI-2x_models/error_stats/tsdata_ANI-2x_sspt1.h5

# %%
eed = aes.evaluate_ensemble_data(efiles)

# %%
#aes.plot_corr_dist(hdt.hatokcal*eed.fdata['ANI-2x_sspt1']['DrugBk']['Erel'],eed.fdata['ANI-2x_sspt4']['DrugBk']['dEani'],inset=False)

# %%
eed.get_totalerror_table()
# Out:
#                 $\Delta$E$_\mathrm{MAE}$$\mu$  $\Delta$E$_\mathrm{MAE}$$\sigma$  $\Delta$E$_\mathrm{RMS}$$\mu$  $\Delta$E$_\mathrm{RMS}$$\sigma$  E$_\mathrm{MAE}$$\mu$  E$_\mathrm{MAE}$$\sigma$  E$_\mathrm{RMS}$$\mu$  E$_\mathrm{RMS}$$\sigma$  F$_\mathrm{MAE}$$\mu$  F$_\mathrm{MAE}$$\sigma$  F$_\mathrm{RMS}$$\mu$  F$_\mathrm{RMS}$$\sigma$
# ANI-2x_sspt1                             1.54                              0.02                           2.57                              0.29                   1.75                      0.05                   2.88                      0.24                   2.92                      0.04                   4.76                      0.15
# ANI-2x_sspt2                             1.54                              0.03                           2.53                              0.11                   1.74                      0.08                   2.92                      0.17                   2.92                      0.06                   4.72                      0.10
# ANI-2x_sspt3                             1.51                              0.02                           2.47                              0.15                   1.71                      0.04                   2.83                      0.15                   2.87                      0.04                   4.66                      0.11
# ANI-2x_sspt4                             4.48                              0.21                           9.89                              0.58              131704.35                      2.11              257161.51                      3.42                   6.11                      0.16                  15.30                      0.54
# ANI-2x_sspt5                             1.51                              0.02                           2.47                              0.15                   1.71                      0.04                   2.83                      0.15                   2.87                      0.04                   4.66                      0.11
# ANI-2x_sspt6                             1.46                              0.02                           2.71                              0.26                   1.66                      0.04                   3.04                      0.21                   2.75                      0.05                   4.66                      0.33
# ANI-2x_sspt7                             1.43                              0.06                           2.43                              0.28                   1.64                      0.06                   2.93                      0.22                   2.68                      0.13                   4.45                      0.26
# ANI-2x_sspt7-2                           1.42                              0.02                           2.42                              0.28                   1.65                      0.03                   2.90                      0.25                   2.67                      0.03                   4.44                      0.24
# ANI-2x_v62518                            1.37                              0.01                           2.19                              0.05                   1.58                      0.03                   2.53                      0.12                   2.73                      0.06                   4.46                      0.09

# %%
#eed.get_ntwrk_error_table('ANI-2x_3')

# %% [markdown]
# # ANI-1x trained to different datasets tested for extensibility

# %%
tb = eed.get_totalerror_table() # All errors combined

# %%
meanMAE = np.mean(np.stack([tb['$\Delta$E$_\mathrm{MAE}$$\mu$'].values,
                            tb['E$_\mathrm{MAE}$$\mu$'].values,
                            tb['F$_\mathrm{MAE}$$\mu$'].values]),axis=0)

tb['MeanMAE'] = meanMAE

meanRMS = np.mean(np.stack([tb['$\Delta$E$_\mathrm{RMS}$$\mu$'].values,
                            tb['E$_\mathrm{RMS}$$\mu$'].values,
                            tb['F$_\mathrm{RMS}$$\mu$'].values]),axis=0)

tb['MeanRMS'] = meanRMS

tb['TotalMean'] = np.mean([meanMAE,meanRMS],axis=0)

# %%
# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7f7f9')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '11px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# Set colormap equal to seaborns light green color palette
cm = ListedColormap(sns.color_palette("Greens"))

(tb.style
  .background_gradient(cmap=cm, subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                                        '$\Delta$E$_\mathrm{RMS}$$\mu$',
                                        'E$_\mathrm{MAE}$$\mu$',
                                        'E$_\mathrm{RMS}$$\mu$',
                                        'F$_\mathrm{MAE}$$\mu$',
                                        'F$_\mathrm{RMS}$$\mu$',
                                        'MeanRMS',
                                        'MeanMAE',
                                        'TotalMean'])
  .highlight_min(subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                         '$\Delta$E$_\mathrm{RMS}$$\mu$',
                         'E$_\mathrm{MAE}$$\mu$',
                         'E$_\mathrm{RMS}$$\mu$',
                         'F$_\mathrm{MAE}$$\mu$',
                         'F$_\mathrm{RMS}$$\mu$',
                         'MeanRMS',
                         'MeanMAE',
                         'TotalMean'])
  .set_caption('COMP6')
  .format({'total_amt_usd_pct_diff': "{:.2%}"})
  .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5 td {
#           font-size: 11px;
#     }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row0_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row1_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row2_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col4 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col6 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col13 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row3_col14 {
#             background-color:  #05712f;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row4_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row5_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row6_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_7f53e7f6_4a5f_11e9_82d4_9cb6d00a72f5row7_col0 {
#             background-color:  #e1f3dc;

# %%
tb = eed.get_error_table(tskey='DrugBk')

# %%
meanMAE = np.mean(np.stack([tb['$\Delta$E$_\mathrm{MAE}$$\mu$'].values,
                            tb['E$_\mathrm{MAE}$$\mu$'].values,
                            tb['F$_\mathrm{MAE}$$\mu$'].values]),axis=0)

tb['MeanMAE'] = meanMAE

meanRMS = np.mean(np.stack([tb['$\Delta$E$_\mathrm{RMS}$$\mu$'].values,
                            tb['E$_\mathrm{RMS}$$\mu$'].values,
                            tb['F$_\mathrm{RMS}$$\mu$'].values]),axis=0)

tb['MeanRMS'] = meanRMS

tb['TotalMean'] = np.mean([meanMAE,meanRMS],axis=0)

# %%
# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7f7f9')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '11px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# Set colormap equal to seaborns light green color palette
cm = ListedColormap(sns.color_palette("Greens"))

(tb.style
  .background_gradient(cmap=cm, subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                                        '$\Delta$E$_\mathrm{RMS}$$\mu$',
                                        'E$_\mathrm{MAE}$$\mu$',
                                        'E$_\mathrm{RMS}$$\mu$',
                                        'F$_\mathrm{MAE}$$\mu$',
                                        'F$_\mathrm{RMS}$$\mu$',
                                        'MeanRMS',
                                        'MeanMAE',
                                        'TotalMean'])
  .highlight_min(subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                         '$\Delta$E$_\mathrm{RMS}$$\mu$',
                         'E$_\mathrm{MAE}$$\mu$',
                         'E$_\mathrm{RMS}$$\mu$',
                         'F$_\mathrm{MAE}$$\mu$',
                         'F$_\mathrm{RMS}$$\mu$',
                         'MeanRMS',
                         'MeanMAE',
                         'TotalMean'])
  .set_caption('Drugbank')
  .format({'total_amt_usd_pct_diff': "{:.2%}"})
  .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5 td {
#           font-size: 11px;
#     }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row0_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row1_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row2_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col4 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col6 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col13 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row3_col14 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row4_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row5_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col8 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col10 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row6_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a6_4a5f_11e9_82d4_9cb6d00a72f5row7_col0 {

# %%
tb = eed.get_error_table(tskey='TriPep')

# %%
meanMAE = np.mean(np.stack([tb['$\Delta$E$_\mathrm{MAE}$$\mu$'].values,
                            tb['E$_\mathrm{MAE}$$\mu$'].values,
                            tb['F$_\mathrm{MAE}$$\mu$'].values]),axis=0)

tb['MeanMAE'] = meanMAE

meanRMS = np.mean(np.stack([tb['$\Delta$E$_\mathrm{RMS}$$\mu$'].values,
                            tb['E$_\mathrm{RMS}$$\mu$'].values,
                            tb['F$_\mathrm{RMS}$$\mu$'].values]),axis=0)

tb['MeanRMS'] = meanRMS

tb['TotalMean'] = np.mean([meanMAE,meanRMS],axis=0)

# %%
# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7f7f9')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '11px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# Set colormap equal to seaborns light green color palette
cm = ListedColormap(sns.color_palette("Greens"))

(tb.style
  .background_gradient(cmap=cm, subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                                        '$\Delta$E$_\mathrm{RMS}$$\mu$',
                                        'E$_\mathrm{MAE}$$\mu$',
                                        'E$_\mathrm{RMS}$$\mu$',
                                        'F$_\mathrm{MAE}$$\mu$',
                                        'F$_\mathrm{RMS}$$\mu$',
                                        'MeanRMS',
                                        'MeanMAE',
                                        'TotalMean'])
  .highlight_min(subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                         '$\Delta$E$_\mathrm{RMS}$$\mu$',
                         'E$_\mathrm{MAE}$$\mu$',
                         'E$_\mathrm{RMS}$$\mu$',
                         'F$_\mathrm{MAE}$$\mu$',
                         'F$_\mathrm{RMS}$$\mu$',
                         'MeanRMS',
                         'MeanMAE',
                         'TotalMean'])
  .set_caption('Tripeptides')
  .format({'total_amt_usd_pct_diff': "{:.2%}"})
  .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5 td {
#           font-size: 11px;
#     }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col8 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row0_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col8 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row1_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row2_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col4 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col6 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col13 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row3_col14 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row4_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row5_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row6_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a7_4a5f_11e9_82d4_9cb6d00a72f5row7_col0 {
#             background-color:  #e1f3dc;

# %%
tb = eed.get_error_table(tskey='MDBenchmark')

# %%
meanMAE = np.mean(np.stack([tb['$\Delta$E$_\mathrm{MAE}$$\mu$'].values,
                            tb['E$_\mathrm{MAE}$$\mu$'].values,
                            tb['F$_\mathrm{MAE}$$\mu$'].values]),axis=0)

tb['MeanMAE'] = meanMAE

meanRMS = np.mean(np.stack([tb['$\Delta$E$_\mathrm{RMS}$$\mu$'].values,
                            tb['E$_\mathrm{RMS}$$\mu$'].values,
                            tb['F$_\mathrm{RMS}$$\mu$'].values]),axis=0)

tb['MeanRMS'] = meanRMS

tb['TotalMean'] = np.mean([meanMAE,meanRMS],axis=0)

# %%
# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7f7f9')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '11px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# Set colormap equal to seaborns light green color palette
cm = ListedColormap(sns.color_palette("Greens"))

(tb.style
  .background_gradient(cmap=cm, subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                                        '$\Delta$E$_\mathrm{RMS}$$\mu$',
                                        'E$_\mathrm{MAE}$$\mu$',
                                        'E$_\mathrm{RMS}$$\mu$',
                                        'F$_\mathrm{MAE}$$\mu$',
                                        'F$_\mathrm{RMS}$$\mu$',
                                        'MeanRMS',
                                        'MeanMAE',
                                        'TotalMean'])
  .highlight_min(subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                         '$\Delta$E$_\mathrm{RMS}$$\mu$',
                         'E$_\mathrm{MAE}$$\mu$',
                         'E$_\mathrm{RMS}$$\mu$',
                         'F$_\mathrm{MAE}$$\mu$',
                         'F$_\mathrm{RMS}$$\mu$',
                         'MeanRMS',
                         'MeanMAE',
                         'TotalMean'])
  .set_caption('MDBenchMark')
  .format({'total_amt_usd_pct_diff': "{:.2%}"})
  .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5 td {
#           font-size: 11px;
#     }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col2 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col4 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col6 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col12 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col13 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row0_col14 {
#             background-color:  #56b567;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col4 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col12 {
#             background-color:  #56b567;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col13 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row1_col14 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col0 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col2 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col4 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col8 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col12 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col13 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row2_col14 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col0 {
#             background-color:  #56b567;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col2 {
#             background-color:  #56b567;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col4 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col6 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col8 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col10 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col12 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col13 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row3_col14 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col0 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col2 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col4 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col8 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col12 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col13 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row4_col14 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col0 {
#             background-color:  #56b567;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col2 {
#             background-color:  #56b567;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col8 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col10 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col12 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col13 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row5_col14 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col0 {
#             background-color:  #8ed08b;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col2 {
#             background-color:  #bce4b5;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col4 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col6 {
#             background-color:  #56b567;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col13 {
#             background-color:  #2c944c;
#             : ;
#         }    #T_811e57a8_4a5f_11e9_82d4_9cb6d00a72f5row6_col14 {
#             background-color:  #2c944c;

# %%
tb = eed.get_error_table(tskey='s66x8')

# %%
meanMAE = np.mean(np.stack([tb['$\Delta$E$_\mathrm{MAE}$$\mu$'].values,
                            tb['E$_\mathrm{MAE}$$\mu$'].values,
                            tb['F$_\mathrm{MAE}$$\mu$'].values]),axis=0)

tb['MeanMAE'] = meanMAE

meanRMS = np.mean(np.stack([tb['$\Delta$E$_\mathrm{RMS}$$\mu$'].values,
                            tb['E$_\mathrm{RMS}$$\mu$'].values,
                            tb['F$_\mathrm{RMS}$$\mu$'].values]),axis=0)

tb['MeanRMS'] = meanRMS

tb['TotalMean'] = np.mean([meanMAE,meanRMS],axis=0)

# %%
# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7f7f9')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '11px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# Set colormap equal to seaborns light green color palette
cm = ListedColormap(sns.color_palette("Greens"))

(tb.style
  .background_gradient(cmap=cm, subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                                        '$\Delta$E$_\mathrm{RMS}$$\mu$',
                                        'E$_\mathrm{MAE}$$\mu$',
                                        'E$_\mathrm{RMS}$$\mu$',
                                        'F$_\mathrm{MAE}$$\mu$',
                                        'F$_\mathrm{RMS}$$\mu$',
                                        'MeanRMS',
                                        'MeanMAE',
                                        'TotalMean'])
  .highlight_min(subset=['$\Delta$E$_\mathrm{MAE}$$\mu$',
                         '$\Delta$E$_\mathrm{RMS}$$\mu$',
                         'E$_\mathrm{MAE}$$\mu$',
                         'E$_\mathrm{RMS}$$\mu$',
                         'F$_\mathrm{MAE}$$\mu$',
                         'F$_\mathrm{RMS}$$\mu$',
                         'MeanRMS',
                         'MeanMAE',
                         'TotalMean'])
  .set_caption('MDBenchMark')
  .format({'total_amt_usd_pct_diff': "{:.2%}"})
  .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5 td {
#           font-size: 11px;
#     }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col4 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col6 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col13 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row0_col14 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col4 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col6 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col13 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row1_col14 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col4 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col6 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col13 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row2_col14 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row3_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col0 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col2 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col4 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col6 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col8 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col10 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col12 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col13 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row4_col14 {
#             background-color:  #05712f;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col8 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row5_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col0 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col2 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col4 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col6 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col8 {
#             background-color:  #e1f3dc;
#             background-color:  yellow;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col10 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col12 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col13 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row6_col14 {
#             background-color:  #e1f3dc;
#             : ;
#         }    #T_811e57a9_4a5f_11e9_82d4_9cb6d00a72f5row7_col0 {
#             background-c

# %%
eed.get_error_table(tskey='GDB-10to13')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-63a9fd426500> in <module>()
# ----> 1 eed.get_error_table(tskey='GDB-10to13')
#
# ~/Gits/ANI-Tools/lib/aniensemblestats.py in get_error_table(self, tskey)
#     536         errors = dict()
#     537         for k in self.fdata.keys():
# --> 538             errors[k] = pd.Series(self.generate_total_errors(k,tskey))
#     539         pd.set_option('expand_frame_repr', False)
#     540         edat = pd.DataFrame(errors).transpose()
#
# ~/Gits/ANI-Tools/lib/aniensemblestats.py in generate_total_errors(self, ntkey, tskey)
#     403     def generate_total_errors(self, ntkey, tskey):
#     404         #idx = np.nonzero(self.fdata[ntkey][tskey]['Erdft'])
# --> 405         Nn = self.fdata[ntkey][tskey]['Eani'].shape[0]-1
#     406         return {names[0]: hdt.calculatemeanabserror(self.fdata[ntkey][tskey]['Eani'][Nn,:], self.fdata[ntkey][tskey]['Edft']),
#     407                 names[1]: np.std(hdt.calculatemeanabserror(self.fdata[ntkey][tskey]['Eani'][0:Nn,:], self.fdata[ntkey][tskey]['Edft'], axis=1)),
#
# KeyError: 'GDB-10to13'

# %%
eed.get_error_table(tskey='MDBenchmark')

# %%
eed.get_error_table(tskey='s66x8')
# Out:
#                $\Delta$E$_\mathrm{MAE}$$\mu$  $\Delta$E$_\mathrm{MAE}$$\sigma$  $\Delta$E$_\mathrm{RMS}$$\mu$  $\Delta$E$_\mathrm{RMS}$$\sigma$  E$_\mathrm{MAE}$$\mu$  E$_\mathrm{MAE}$$\sigma$  E$_\mathrm{RMS}$$\mu$  E$_\mathrm{RMS}$$\sigma$  F$_\mathrm{MAE}$$\mu$  F$_\mathrm{MAE}$$\sigma$  F$_\mathrm{RMS}$$\mu$  F$_\mathrm{RMS}$$\sigma$
# ANI-2x_sspt1                            1.29                              0.09                           1.90                              0.16                   1.31                      0.10                   1.83                      0.18                   1.45                      0.11                   2.58                      0.19
# ANI-2x_sspt2                            1.24                              0.10                           1.78                              0.18                   1.36                      0.13                   1.82                      0.18                   1.47                      0.09                   2.58                      0.17
# ANI-2x_sspt3                            1.25                              0.06                           1.92                              0.09                   1.39                      0.08                   1.94                      0.12                   1.52                      0.10                   2.64                      0.18
# ANI-2x_sspt4                            0.49                              0.02                           0.67                              0.04                   0.45                      0.06                   0.61                      0.08                   1.03                      0.04                   1.63                      0.07
# ANI-2x_sspt5                            1.25                              0.06                           1.92                              0.09                   1.39                      0.08                   1.94                      0.12                   1.52                      0.10                   2.64                      0.18
# ANI-2x_sspt6                            0.53                              0.03                           0.74                              0.05                   0.48                      0.06                   0.63                      0.08                   1.04                      0.04                   1.69                      0.05
# ANI-2x_v62518                           0.41                              0.04                           0.56                              0.06                   0.42                      0.06                   0.54                      0.08                   0.98                      0.11                   1.54                      0.17

# %%
#eed.get_error_table(tskey='s66x8')

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(xls_store, engine='xlsxwriter')

# Build latex document
header = r'\documentclass{article}'+'\n'+r'\usepackage{booktabs}'+'\n'+r'\usepackage[margin=1.0in]{geometry}'+'\n'+r'\begin{document}'+'\n'

begtab = r'\begin{table}'+'\n'+r'\centering'+'\n'+r'\tiny'+'\n'
endtab = r'\end{table}'+'\n'
enddoc = r'\end{document}'
styles = []
with open(tex_store, "w") as text_file:
    text_file.write(header)
    print('Stats for: Complete benchmark')
    etab = eed.get_totalerror_table()
    styles.append(etab.style)
    text_file.write(begtab+r'\caption{Data set: Complete benchmark}'+'\n'+etab.to_latex(escape=False)+endtab)

    # Convert the dataframe to an XlsxWriter Excel object.
    etab.to_excel(writer, sheet_name="Complete Benchmark")

    paetab = eed.get_totalerrorperatom_table()
    text_file.write(begtab+r'\caption{Data set: Complete benchmark per atom}'+'\n'+paetab.to_latex(escape=False)+endtab)
    paetab.to_excel(writer, sheet_name="Complete Benchmark per atom")
    
    
    for k in tsname:
        print('Stats for:',k)
        etab = eed.get_error_table(k)
        etab.to_excel(writer, sheet_name=k)
        styles.append(etab.style)
        text_file.write(begtab+r'\caption{Data set: '+k+r'}'+'\n'+etab.to_latex(escape=False)+endtab)
    text_file.write(enddoc)
styles[0]

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
cmap = mpl.cm.nipy_spectral
for i in range(1,16):
    print('Models:',str(i+1).zfill(2))
    eed.determine_min_error_by_sigma('ANI-1xTL'+str(i+1).zfill(2),
                                     0.5, 50.0,
                                     labelx=r'$\mathrm{\rho}$ [$\mathrm{kcal \times mol^{-1} \times (\sqrt{N_a})^{-1}}}$]',
                                     labely=r'$\mathrm{\mathcal{E}}$ [$\mathrm{kcal \times mol^{-1} \times (\sqrt{N_a})^{-1}}$]',
                                     xyrange=(0.0,2.0,0.0,12.0),
                                     figsize=(12.0, 9.0),
                                     cmap=cmap,
                                     tskeys=['GDB-10to13'],
                                     #storepath='/home/jsmith48/scratch/error_stats/rho_selection_6.0.0.pdf',
                                     )

# %%
cmap = mpl.cm.nipy_spectral
eed.determine_min_error_by_sigma('ANI-1xTL_lr-5',
                                 0.5, 50.0,
                                 labelx=r'$\mathrm{\rho}$ [$\mathrm{kcal \times mol^{-1} \times (\sqrt{N_a})^{-1}}}$]',
                                 labely=r'$\mathrm{\mathcal{E}}$ [$\mathrm{kcal \times mol^{-1} \times (\sqrt{N_a})^{-1}}$]',
                                 xyrange=(0.0,2.0,0.0,12.0),
                                 figsize=(12.0, 9.0),
                                 cmap=cmap,
                                 tskeys=['GDB-10to13'],
                                 #storepath='/home/jsmith48/scratch/error_stats/rho_selection_6.0.0.pdf',
                                 )

# %%
print(eed.get_net_keys())
#print(eed.get_size("9.0.5","MDBenchmark"))
#print(eed.get_size("9.0.4","Tripeptide"))
#print(eed.get_size("9.0.4","GDB07to09"))
#print(eed.get_size("9.0.4","GDB10to13"))

# %%
# cmap = mpl.cm.nipy_spectral
# Erms  = []
# dErms = []
# for i in range(1,17):
#     print('Models:',str(i).zfill(2))
#     Erms.append(eed.generate_rmserror('ANI-1xTL'+str(i).zfill(2),'GDB-10to13','Eani','Edft'))
#     dErms.append(eed.generate_rmserror('ANI-1xTL'+str(i).zfill(2),'GDB-10to13','dEani','dEdft'))

eed.generate_correlation_plot('ANI-2x_sspt1','MDBenchmark','dEani','dEdft')
eed.generate_correlation_plot('ANI-2x_v62518','MDBenchmark','dEani','dEdft')
#eed.generate_correlation_plot('ANI-2x_3-100','DrugBk (CHNO)','dEani','dEdft')

#eed.generate_correlation_plot('6.0.0','MDBenchmark','Fani','Fdft')
#cmap = mpl.cm.nipy_spectral
#eed.generate_correlation_plot('ANI-0707.0001.0410_bt5','GDB-11 (SFCl)','Fani','Fdft',cmap=cmap)
#eed.generate_correlation_plot('0707.0001.0402','GDB-07 (SFCl)','dEani','dEdft')
#eed.generate_correlation_plot('0707.0001.0402','GDB-08 (SFCl)','dEani','dEdft')
#eed.generate_correlation_plot('0707.0001.0402','GDB-09 (SFCl)','dEani','dEdft')
#eed.generate_correlation_plot('0707.0001.0402','GDB-10 (SFCl)','dEani','dEdft')
#eed.generate_correlation_plot('0707.0001.0402','GDB-11 (SFCl)','dEani','dEdft')
#eed.generate_correlation_plot('AL6','DrugBank','Fani','Fdft')
#eed.generate_correlation_plot('ARC1','MDBenchmark','Fani','Fdft')
#eed.generate_correlation_plot('ARC8','MDBenchmark','Fani','Fdft')

# %%
import numpy as np
from matplotlib import gridspec 

fig = plt.subplots(figsize=[15,6])
gs  = gridspec.GridSpec(1, 2, width_ratios=[0.5, 0.5])

ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.plot(np.arange(1,17),Erms,marker='o')
ax1.set_title(r'E improvment with ensemble size')
ax1.set_xlabel('Number of members')
ax1.set_ylabel('RMSE error (kcal/mol)')

ax2.plot(np.arange(1,17),dErms,marker='o')
ax2.set_title(r'$\Delta$E improvment with ensemble size')
ax2.set_xlabel('Number of members')
ax2.set_ylabel('RMSE error (kcal/mol)')

plt.show()

# %%
#eed.plot_bar_propsbynet([('Total Energy',r'RMSE ($kcal \times mol^{-1}$)','Eani','Edft',[0.0,23.0]),
#                         ('Relative Energy',r'RMSE ($kcal \times mol^{-1}$)','dEani', 'dEdft',[0.0,12.0]),
#                         ('Force',r'RMSE ($kcal \times mol^{-1} \times \AA^{-1}$)','Fani', 'Fdft',[0.0,10.0])], 
#                         ['GDB07to09', 'GDB10to13', 'DrugBank', 'Tripeptide', 's66x8'],
#                         ntwks=['6.0.0','7.0.4','8.0.6','8.3.6','9.0.4','ANI-1'],
#                         fontsize=30, bbox_to_anchor=(0.3, 1.0), figsize=(40.0, 32.0), ncol=2, errortype='RMSE')

# %%
eed.plot_error_by_net([(r'$E (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Eani','Edft'),
                       (r'$\Delta E (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','dEani','dEdft'),
                       (r'$F (kcal \times mol^{-1}\AA^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Fani','Fdft'),], 
                         ['DHL_DAT.0001', 'DHL_DAT.0002','DHL_DAT.0003',],
                         ntwks=['ANI-1x-DHL-0000.0000','ANI-1x-DHL-0000.0001','ANI-1x-DHL-0000.0002'],
                         fontsize=20, bbox_to_anchor=(1.0, 1.0), figsize=(30.0, 15.0), ncol=1, errortype='RMSE',
                        #storepath='/home/jujuman/Dropbox/ANAKIN-ME-RESEARCH/PUBLICATION-ActiveLearning/Figures/figure_TSALvsANI_RMSE.pdf',
                      )

# %%
eed.plot_error_by_net([(r'$E (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Eani','Edft'),
                       (r'$\Delta E (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','dEani','dEdft'),
                       (r'$F (kcal \times mol^{-1}\AA^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Fani','Fdft'),], 
                         ['GDB07to09', 'GDB10to13', 'DrugBank', 'Tripeptide', 'MDBenchmark', 's66x8'],
                         ntwks=['AL1', 'AL2', 'AL3', 'AL4', 'AL5', 'AL6', 'ANI-1'],
                         fontsize=20, bbox_to_anchor=(1.0, 1.0), figsize=(30.0, 15.0), ncol=1, errortype='RMSE',
                        #storepath='/home/jujuman/Dropbox/ANAKIN-ME-RESEARCH/PUBLICATION-ActiveLearning/Figures/figure_TSALvsANI_RMSE.pdf')

# %%
eed.plot_error_by_net([(r'$E (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Eani','Edft'),
                       (r'$\Delta E (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','dEani','dEdft'),
                       (r'$F (kcal \times mol^{-1}\AA^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Fani','Fdft'),], 
                         ['GDB07to09', 'GDB10to13', 'DrugBank', 'Tripeptide', 'MDBenchmark', 's66x8'],
                         ntwks=['AL1', 'AL2', 'AL3', 'AL4', 'AL5', 'AL6', 'ANI-1'],
                         fontsize=20, bbox_to_anchor=(1.0, 1.0), figsize=(30.0, 15.0), ncol=1, errortype='MAE',
                        #storepath='/home/jujuman/Dropbox/ANAKIN-ME-RESEARCH/PUBLICATION-ActiveLearning/Figures/figure_TSALvsANI_MAE.pdf')
#eed.generate_violin_distribution('GDB10to13')

# %%
'''
eed.plot_error_by_net([(r'$E_T (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Eani','Edft'),
                       (r'$\Delta E (kcal \times mol^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','dEani','dEdft'),
                       (r'$F (kcal \times mol^{-1}\AA^{-1})$',r'RMSE ($kcal \times mol^{-1}$)','Fani','Fdft'),], 
                         ['GDB07to09', 'GDB10to13', 'DrugBank', 'Tripeptide', 'MDBenchmark', 's66x8'],
                         ntwks=['ARC1','ARC2','ARC3','ARC4','ARC5','ARC6','ARC7','ARC8'],
                        fontsize=20, bbox_to_anchor=(1.0, 1.0), figsize=(20.0, 30.0), ncol=1, errortype='RMSE',
                        storepath='/home/jujuman/Research/DataReductionMethods/train_test/tables/figure_TSALvsANI_RMSE.pdf')
'''

# %%
Edft1 = eed.get_range_stats(tslist=['DHL_DAT.0002'],dkey='Fdft')
plt.hist(Edft1,bins=20, log=True, edgecolor='black')
plt.show()

# %%
Edft1 = eed.get_range_stats(tslist=['GDB-10to13 (CHNO)'],dkey='Na')
plt.hist(Edft1,bins=18, log=True, edgecolor='black')
plt.show()

# %%
Edft2 = eed.get_range_stats(tslist=['r10_ccsd'],dkey='Edft')
plt.hist(Edft2,bins=16,color='r', log=True, edgecolor='black')
plt.show()

# %%
Edft2 = eed.get_range_stats(tslist=['r10_ccsd'],dkey='Na')
plt.hist(Edft2,bins=16, log=True,color='r', edgecolor='black')
plt.show()
