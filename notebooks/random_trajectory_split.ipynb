# %%
import hdnntools as hdt
import numpy as np
import os

# %%
lfile = '/home/jujuman/Research/conjugation_check/data_files/'
sfile = '/home/jujuman/Research/conjugation_check/split_files/'

# %%
files = [f for f in os.listdir(lfile) if "_md.xyz" in f]
print(len(files))
# Out:
# 11

# %%
for f in files:
    print(f)
    X,S,Na,c = hdt.readxyz2(lfile+f)
    idx = np.arange(X.shape[0])
    np.random.shuffle(idx)
    ridx = idx[0:256].copy()
    ridx.sort()
    print(ridx)
    Xn = X[ridx]
    hdt.writexyzfile(sfile+f,Xn,S)
# Out:
# C04_md.xyz
# [   5    6    7   14   15   23   28   33   35   48   61   73   82   84   85
#    86   91   96  102  103  107  108  110  134  137  141  155  160  169  172
#   174  176  179  181  183  187  190  209  219  220  225  231  241  252  254
#   262  271  277  279  296  301  305  309  312  314  334  339  356  366  369
#   376  383  386  387  403  405  410  412  419  423  424  436  441  448  453
#   456  468  470  473  475  478  485  489  493  497  500  508  510  515  535
#   541  593  609  613  616  622  625  652  657  658  660  669  673  693  694
#   695  698  710  721  728  735  736  745  749  750  755  758  760  786  799
#   805  809  814  815  823  828  829  845  847  850  862  873  875  876  877
#   880  890  891  903  904  906  914  915  917  930  932  933  945  947  953
#   954  955  960  969  973  979  984  994  996  999 1002 1023 1026 1029 1037
#  1046 1050 1054 1058 1067 1077 1080 1081 1093 1094 1097 1106 1113 1131 1135
# ...
