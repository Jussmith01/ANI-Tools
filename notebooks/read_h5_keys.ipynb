# %%
import pyanitools as pyt
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
h5 = '/home/jsmith48/scratch/CCSD_Water_train/h5files/CCSD-al_wat-2-partial.h5'

# %%
adl = pyt.anidataloader(h5)

# %%
for i,data in enumerate(adl):
    print(i,data['path'],data.keys())
# Out:
# 0 /10000 dict_keys(['path', 'DFT_energies', 'Nccsd(t)_dz_dipoles', 'Nccsd(t)_dz_energies', 'Nccsd(t)_tz_dipoles', 'Nccsd(t)_tz_energies', 'Tccsd(t)_dz_dipoles', 'Tccsd(t)_dz_energies', 'coordinates', 'energies', 'mp2_dz_dipoles', 'mp2_dz_energies', 'mp2_dz_grad', 'mp2_qz_dipoles', 'mp2_qz_energies', 'mp2_tz_dipoles', 'mp2_tz_energies', 'mp2_tz_grad', 'species'])
# 1 /100000 dict_keys(['path', 'DFT_energies', 'Nccsd(t)_dz_dipoles', 'Nccsd(t)_dz_energies', 'Nccsd(t)_tz_dipoles', 'Nccsd(t)_tz_energies', 'Tccsd(t)_dz_dipoles', 'Tccsd(t)_dz_energies', 'coordinates', 'energies', 'mp2_dz_dipoles', 'mp2_dz_energies', 'mp2_dz_grad', 'mp2_qz_dipoles', 'mp2_qz_energies', 'mp2_tz_dipoles', 'mp2_tz_energies', 'mp2_tz_grad', 'species'])
# ...
