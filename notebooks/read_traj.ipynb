# %%
import numpy as np

import matplotlib
import matplotlib as mpl

import matplotlib.pyplot as plt

# %%
traj = '/home/jsmith48/scratch/CCSD_Water_train/traj.dat'

# %%
data = np.loadtxt(traj)

# %%
plt.plot(data[60:,1])
plt.show()
